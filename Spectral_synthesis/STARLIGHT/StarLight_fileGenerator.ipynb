# %%
import re
import os
import numpy as np
from astropy.io import ascii
from astropy.io import fits
from astropy.table import Table
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from io import StringIO
from matplotlib.ticker import AutoMinorLocator
from astropy.constants import L_sun
from matplotlib import gridspec
import astropy.units as u
from math import pi

# %%
storage_dir = os.path.join(os.path.expanduser("~"),'Data_storageHII/')
os.makedirs(storage_dir, exist_ok=True)
tex_folder = storage_dir + '/specTx_Tab5ID/'
spec_list = os.listdir(tex_folder)
#spec_list.remove('DOWNspec_listDR7.txt')
spec_list = sorted(spec_list)
len(spec_list)
# Out:
# 121

# %% [markdown]
# ## Prefit

# %%
n_spec = '4'
base_dir = '/home/holman/BASES/MILESM.Sbmm/'
obs_dir = f'{tex_folder}'.replace('//','/')
mask_dir = '/home/holman/StarLightv05/'
out_dir = '/home/holman/StarLightv05/outputs/prefit/'
phone_number = '-2007200'
llow_SN = '4570.0'
lupp_SN = '4650.0'
Olsyn_ini = '3400.0'
Olsyn_fin = '8500.0'
Odlsyn = '1.0'
fscale_chi2 = '1.0'
fit_method = 'FIT'
errors = '0'
flags = '0'

ext_laws = ['CAL','GD1','GD2','GD3']
config_file = 'Prefit_HII.config'
BASE = 'Base_45Prefit.Sbmm'

# %%
input_folder = '/home/holman/StarLightv05/inputs/prefit/'

mask_list =[ (lambda x: 'Mask_Prefit.txt')(x) for x in range(len(spec_list)) ]#os.listdir(mask_folder)

#mask_list.sort()



for i in range(len(spec_list)):
    with open(f"{input_folder}/grid_Prefit{spec_list[i][0:3]}.in", 'w') as file:
        file.write(f"{n_spec}                                               [Number of fits to run]\n")
        file.write(f"{base_dir}                 [base_dir]\n")
        file.write(f"{obs_dir}                  [obs_dir]\n")
        file.write(f"{mask_dir}                    [mask_dir]\n")
        file.write(f"{out_dir}               [out_dir]\n")
        file.write(f"{phone_number}                                         [your phone number]\n")
        file.write(f"{llow_SN}                                           [llow_SN]   lower-lambda of S/N window\n")
        file.write(f"{lupp_SN}                                           [lupp_SN]   upper-lambda of S/N window\n")
        file.write(f"{Olsyn_ini}                                           [Olsyn_ini] lower-lambda for fit\n")
        file.write(f"{Olsyn_fin}                                           [Olsyn_fin] upper-lambda for fit\n")
        file.write(f"{Odlsyn}                                              [Odlsyn]    delta-lambda for fit\n")
        file.write(f"{fscale_chi2}                                              [fscale_chi2] fudge-factor for chi2\n")
        file.write(f"{fit_method}                                              [FIT/FXK] Fit or Fix kinematics\n")
        file.write(f"{errors}                                                [IsErrSpecAvailable]  1/0 = Yes/No\n")
        file.write(f"{flags}                                                [IsFlagSpecAvailable] 1/0 = Yes/No\n")

        n_spec = int(n_spec)

        for aux in range(n_spec):
            file.write(f"{spec_list[i]}  {config_file}  {BASE}  {mask_list[i]}  {ext_laws[aux]}  0.0  150.0  {spec_list[i][0:4]+ext_laws[aux]+'.MILES45'}.out\n")

# %%
#servidor de Papaqui

# %%
storage_dir = os.path.join(os.path.expanduser("~"),'Data_storageHII/')
os.makedirs(storage_dir, exist_ok=True)
tex_folder = storage_dir + '/specTx_Tab5ID/'
spec_list = os.listdir(tex_folder)
#spec_list.remove('DOWNspec_listDR7.txt')
spec_list = sorted(spec_list)
len(spec_list)
tex_folder = '/home/hollman/Data_storageHII/specTx_Tab5ID/'

# %%
n_spec = '4'
base_dir = '/home/hollman/BASES/MILESM.Sbmm/'
obs_dir = f'{tex_folder}'.replace('//','/')
mask_dir = '/home/hollman/StarLightv05/'
out_dir = '/home/hollman/StarLightv05/outputs/prefit/'
phone_number = '-2007200'
llow_SN = '4570.0'
lupp_SN = '4650.0'
Olsyn_ini = '3400.0'
Olsyn_fin = '8500.0'
Odlsyn = '1.0'
fscale_chi2 = '1.0'
fit_method = 'FIT'
errors = '0'
flags = '0'

ext_laws = ['CAL','GD1','GD2','GD3']
config_file = 'Prefit_HII.config'
BASE = 'Base_45Prefit.Sbmm'

# %%
input_folder = '/home/holman/StarLightv05/inputs/prefit/'

mask_list =[ (lambda x: 'Mask_Prefit.txt')(x) for x in range(len(spec_list)) ]#os.listdir(mask_folder)

#mask_list.sort()



for i in range(len(spec_list)):
    with open(f"{input_folder}/grid_Prefit{spec_list[i][0:3]}.in", 'w') as file:
        file.write(f"{n_spec}                                               [Number of fits to run]\n")
        file.write(f"{base_dir}                 [base_dir]\n")
        file.write(f"{obs_dir}                  [obs_dir]\n")
        file.write(f"{mask_dir}                    [mask_dir]\n")
        file.write(f"{out_dir}               [out_dir]\n")
        file.write(f"{phone_number}                                         [your phone number]\n")
        file.write(f"{llow_SN}                                           [llow_SN]   lower-lambda of S/N window\n")
        file.write(f"{lupp_SN}                                           [lupp_SN]   upper-lambda of S/N window\n")
        file.write(f"{Olsyn_ini}                                           [Olsyn_ini] lower-lambda for fit\n")
        file.write(f"{Olsyn_fin}                                           [Olsyn_fin] upper-lambda for fit\n")
        file.write(f"{Odlsyn}                                              [Odlsyn]    delta-lambda for fit\n")
        file.write(f"{fscale_chi2}                                              [fscale_chi2] fudge-factor for chi2\n")
        file.write(f"{fit_method}                                              [FIT/FXK] Fit or Fix kinematics\n")
        file.write(f"{errors}                                                [IsErrSpecAvailable]  1/0 = Yes/No\n")
        file.write(f"{flags}                                                [IsFlagSpecAvailable] 1/0 = Yes/No\n")

        n_spec = int(n_spec)

        for aux in range(n_spec):
            file.write(f"{spec_list[i]}  {config_file}  {BASE}  {mask_list[i]}  {ext_laws[aux]}  0.0  150.0  {spec_list[i][0:4]+ext_laws[aux]+'.MILES45'}.out\n")

# %% [markdown]
# ## Different lnorm

# %%
lnorms = ['4020','4150','5100']

for LN in lnorms:
    n_spec = '4'
    base_dir = '/home/holman/BASES/MILESM.Sbmm/'
    obs_dir = f'{tex_folder}'.replace('//','/')
    mask_dir = '/home/holman/StarLightv05/Starlight_masks/'
    out_dir = f'/home/holman/StarLightv05/outputs/FR{LN}/'
    phone_number = '-2007200'
    llow_SN = '4570.0'
    lupp_SN = '4650.0'
    Olsyn_ini = '3400.0'
    Olsyn_fin = '8500.0'
    Odlsyn = '1.0'
    fscale_chi2 = '1.0'
    fit_method = 'FIT'
    errors = '0'
    flags = '0'

    ext_laws = ['CAL','GD1','GD2','GD3']
    config_file = f'FR{LN}.config'
    BASE = 'Base_MILESM.Sbmm'

    input_folder = f'/home/holman/StarLightv05/inputs/FR{LN}/'
    mask_list = [f for f in os.listdir(mask_dir) if f.endswith('.txt')]
    mask_list.sort()
    for i in range(len(spec_list)):
        with open(f"{input_folder}/grid_FR{LN}{spec_list[i][0:3]}.in", 'w') as file:
            file.write(f"{n_spec}                                               [Number of fits to run]\n")
            file.write(f"{base_dir}                 [base_dir]\n")
            file.write(f"{obs_dir}                  [obs_dir]\n")
            file.write(f"{mask_dir}                    [mask_dir]\n")
            file.write(f"{out_dir}               [out_dir]\n")
            file.write(f"{phone_number}                                         [your phone number]\n")
            file.write(f"{llow_SN}                                           [llow_SN]   lower-lambda of S/N window\n")
            file.write(f"{lupp_SN}                                           [lupp_SN]   upper-lambda of S/N window\n")
            file.write(f"{Olsyn_ini}                                           [Olsyn_ini] lower-lambda for fit\n")
            file.write(f"{Olsyn_fin}                                           [Olsyn_fin] upper-lambda for fit\n")
            file.write(f"{Odlsyn}                                              [Odlsyn]    delta-lambda for fit\n")
            file.write(f"{fscale_chi2}                                              [fscale_chi2] fudge-factor for chi2\n")
            file.write(f"{fit_method}                                              [FIT/FXK] Fit or Fix kinematics\n")
            file.write(f"{errors}                                                [IsErrSpecAvailable]  1/0 = Yes/No\n")
            file.write(f"{flags}                                                [IsFlagSpecAvailable] 1/0 = Yes/No\n")

            n_spec = int(n_spec)

            for aux in range(n_spec):
                msk_idx = mask_list.index(f"Mask_{spec_list[0][0:3]}.{ext_laws[aux]}.MILES45.txt")
                file.write(f"{spec_list[i]}  {config_file}  {BASE}  {mask_list[msk_idx]}  {ext_laws[aux]}  0.0  150.0  {spec_list[i][0:4]+ext_laws[aux]+'.MILES150'}.out\n")

# %%
input_folder = '/home/holman/StarLightv05/inputs/FR4020/'
mask_list = [f for f in os.listdir(mask_dir) if f.endswith('.txt')]
mask_list.sort()
for i in range(len(spec_list)):
    with open(f"{input_folder}/grid_FR4020{spec_list[i][0:3]}.in", 'w') as file:
        file.write(f"{n_spec}                                               [Number of fits to run]\n")
        file.write(f"{base_dir}                 [base_dir]\n")
        file.write(f"{obs_dir}                  [obs_dir]\n")
        file.write(f"{mask_dir}                    [mask_dir]\n")
        file.write(f"{out_dir}               [out_dir]\n")
        file.write(f"{phone_number}                                         [your phone number]\n")
        file.write(f"{llow_SN}                                           [llow_SN]   lower-lambda of S/N window\n")
        file.write(f"{lupp_SN}                                           [lupp_SN]   upper-lambda of S/N window\n")
        file.write(f"{Olsyn_ini}                                           [Olsyn_ini] lower-lambda for fit\n")
        file.write(f"{Olsyn_fin}                                           [Olsyn_fin] upper-lambda for fit\n")
        file.write(f"{Odlsyn}                                              [Odlsyn]    delta-lambda for fit\n")
        file.write(f"{fscale_chi2}                                              [fscale_chi2] fudge-factor for chi2\n")
        file.write(f"{fit_method}                                              [FIT/FXK] Fit or Fix kinematics\n")
        file.write(f"{errors}                                                [IsErrSpecAvailable]  1/0 = Yes/No\n")
        file.write(f"{flags}                                                [IsFlagSpecAvailable] 1/0 = Yes/No\n")

        n_spec = int(n_spec)

        for aux in range(n_spec):
            msk_idx = mask_list.index(f"Mask_{spec_list[0][0:3]}.{ext_laws[aux]}.MILES45.txt")
            file.write(f"{spec_list[i]}  {config_file}  {BASE}  {mask_list[msk_idx]}  {ext_laws[aux]}  0.0  150.0  {spec_list[i][0:4]+ext_laws[aux]+'.MILES150'}.out\n")

# %%
home = os.path.expanduser("~")

mask_folder = home + '/Starlight_masks/'
spectra_folder = home + '/HIIGs/Tex_spectra/'

spectra_list = os.listdir(spectra_folder)

spectra_list.sort()

lambda_first_values = []

for i in range(len(spectra_list)):
    with open(spectra_folder + spectra_list[i], 'r') as file:
        data = file.read()
        first_lambda = data[0:6]
        lambda_first_values.append(first_lambda)
        file.close()
        del data
    
    with open(f"{mask_folder + spectra_list[i][0:5]}mskFR.txt", 'w') as file:
        file.write("16\n")
        file.write(f"{lambda_first_values[i]}  4000.0  2.0  NoisyDATA         Trying best fit\n")
        file.write("4087.0  4117.0  0.0  Hdelta         4102 emission line\n")
        file.write("4290.0  4400.0  0.0  Hgamma         4340.000\n")
        file.write("4455.0  4495.0  0.0  Unknow\n")
        file.write("4640.0  4740.0  0.0  Unknow\n")
        file.write("4805.0  4947.0  0.0  Hbeta          4861.325\n")
        file.write("4943.0  4974.0  0.0  [OIII]         4958.911\n")
        file.write("4987.0  5027.0  0.0  [OIII]         5006.843\n")
        file.write("5150.0  5205.0  0.0  Unknow\n")
        file.write("5840.0  5934.0  0.0  HeI            5875.666\n")
        file.write("5866.0  5916.0  0.0  HeI & NaD      5876 emission line & ~ 5890 ISM absorption\n")
        file.write("6280.0  6320.0  0.0  [OI]           6300 emission line\n")
        file.write("6528.0  6608.0  0.0  Halpha & [NII] 6563, 6548 & 6583 emission lines\n")
        file.write("6696.0  6752.0  0.0  [SII]          6717 & 6731 emission lines\n")
        file.write("7299.0  7351.0  0.0  [OII]          7320 & 7330 emission lines\n")
        file.write("8500.0  9000.0  2.0  NoisyDATA         Trying best fit\n")

# %%
n_spec = '10'
base_dir = '/home/holman/BASES/MILESM.Sbmm/ '
obs_dir = '/home/holman/HIIGs/Tex_spectra/'
mask_dir = '/home/holman/Starlight_masks/'
out_dir = '/home/holman/StarLightv05/outputs/'
phone_number = '-2007200'
llow_SN = '4730.0'
lupp_SN = '4780.0'
Olsyn_ini = '-'
Olsyn_fin = '9000.0'
Odlsyn = '1.0'
fscale_chi2 = '1.0'
fit_method = 'FIT'
errors = '0'
flags = '0'

ext_laws = ['CCM','CAL','GD1','GD2','GD3','HZ1','HZ2','HZ3','HZ4','HZ5']
config_file = 'FR.config'
BASE = 'Base_MILESM.Sbmm'

# %%
input_folder = home + '/StarLightv05/inputs/'

mask_list = os.listdir(mask_folder)

mask_list.sort()



for i in range(len(spectra_list)):
    with open(f"{input_folder}/grid_FR{spectra_list[i][0:5]}.in", 'w') as file:
        file.write(f"{n_spec}                                               [Number of fits to run]\n")
        file.write(f"{base_dir}                 [base_dir]\n")
        file.write(f"{obs_dir}                  [obs_dir]\n")
        file.write(f"{mask_dir}                    [mask_dir]\n")
        file.write(f"{out_dir}               [out_dir]\n")
        file.write(f"{phone_number}                                         [your phone number]\n")
        file.write(f"{llow_SN}                                           [llow_SN]   lower-lambda of S/N window\n")
        file.write(f"{lupp_SN}                                           [lupp_SN]   upper-lambda of S/N window\n")
        file.write(f"{lambda_first_values[i]}                                           [Olsyn_ini] lower-lambda for fit\n")
        file.write(f"{Olsyn_fin}                                           [Olsyn_fin] upper-lambda for fit\n")
        file.write(f"{Odlsyn}                                              [Odlsyn]    delta-lambda for fit\n")
        file.write(f"{fscale_chi2}                                              [fscale_chi2] fudge-factor for chi2\n")
        file.write(f"{fit_method}                                              [FIT/FXK] Fit or Fix kinematics\n")
        file.write(f"{errors}                                                [IsErrSpecAvailable]  1/0 = Yes/No\n")
        file.write(f"{flags}                                                [IsFlagSpecAvailable] 1/0 = Yes/No\n")

        n_spec = int(n_spec)

        for aux in range(n_spec):
            file.write(f"{spectra_list[i]}  {config_file}  {BASE}  {mask_list[i]}  {ext_laws[aux]}  0.0  150.0  {spectra_list[i][0:5]+ext_laws[aux]+'.MILES150'}.out\n")

# %%
bases = pd.read_csv('Base_45PrefitIN.Sbmm.csv')
bases45 = bases[((bases['met']==0.004) | (bases['met']==0.02) | (bases['met']==0.05)) & ((bases['age [yr]']!=3.16000e6) & (bases['age [yr]']!=6.61e6) & (bases['age [yr]']!=1.445e7) & (bases['age [yr]']!=4.0e7) & (bases['age [yr]']!=1.609e8) & (bases['age [yr]']!=2.8612e8) & (bases['age [yr]']!=1.434e9)  & (bases['age [yr]']!=4.25e9)  & (bases['age [yr]']!=1.5e10)  & (bases['age [yr]']!=1.8e10))]
bases45.to_csv('Base_45Prefit.Sbmm.csv',index=False)

# %%
len(bases45)
# Out:
# 75

# %%
bases45 = bases[((bases['met']==0.004) | (bases['met']==0.02) | (bases['met']==0.05)) & ((bases['age [yr]']!=3.16e6) | (bases['age [yr]']!=6.61e6) | (bases['age [yr]']!=1.445e7) | (bases['age [yr]']!=4.0e7) | (bases['age [yr]']!=1.609e8) | (bases['age [yr]']!=2.8612e8) | (bases['age [yr]']!=1.434e9)  | (bases['age [yr]']!=4.25e9)  | (bases['age [yr]']!=1.5e10)  | (bases['age [yr]']!=1.8e10))]

# %%
bases45[(bases['met']==0.004)]
# Out:
# /tmp/ipykernel_3690007/3268706172.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bases45[(bases['met']==0.004)]
#                                 spec-names      age [yr]    met    SSP_code  \
# 50  bc2003_hr_milesm_m42_chab_ssp_020.spec  1.000000e+06  0.004  age020_m42
# 51  bc2003_hr_milesm_m42_chab_ssp_045.spec  3.160000e+06  0.004  age045_m42
# 52  bc2003_hr_milesm_m42_chab_ssp_055.spec  5.010000e+06  0.004  age055_m42
# 53  bc2003_hr_milesm_m42_chab_ssp_061.spec  6.610000e+06  0.004  age061_m42
# 54  bc2003_hr_milesm_m42_chab_ssp_067.spec  8.710000e+06  0.004  age067_m42
# 55  bc2003_hr_milesm_m42_chab_ssp_070.spec  1.000000e+07  0.004  age070_m42
# 56  bc2003_hr_milesm_m42_chab_ssp_078.spec  1.445000e+07  0.004  age078_m42
# 57  bc2003_hr_milesm_m42_chab_ssp_090.spec  2.512000e+07  0.004  age090_m42
# 58  bc2003_hr_milesm_m42_chab_ssp_104.spec  4.000000e+07  0.004  age104_m42
# ...

# %%
len(bases45[(bases['met']==0.004)])
# Out:
# /tmp/ipykernel_3690007/504983945.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(bases45[(bases['met']==0.004)])
# 25
