# %%
import os
import sys
import glob
import numpy as np
import  scipy.optimize as op
import matplotlib.pyplot as plt
import urllib.request
from astropy.io import fits as fits
from astropy.table import Table
import pandas as pd
import urllib.request
import requests
import astropy.units as u
from astropy.coordinates import SkyCoord
from pathlib import Path
from numpy import savetxt
from PyAstronomy import pyasl
from scipy.interpolate import interp1d
from dustmaps.sfd import SFDQuery

# %%
DATA_URL="http://das.sdss.org/spectro/ss_tar_26/"
file="gal_info_dr7_v5_2.fit.gz"
local_dir="/home/hollman/DataHII/"
local_file = os.path.join(local_dir,file)

if not os.path.exists(local_file):
        print("downloading DR7 quasar dataset from %s to %s"
              % (DATA_URL+file, local_file ))
        tmp = urllib.request.urlretrieve(DATA_URL+local_file, local_file)
        print ("Downloaded file"+local_file)
else:
    print("%s already exist"%(local_file))
# Out:
# /home/hollman/DataHII/gal_info_dr7_v5_2.fit.gz already exist

# %%
catalog=Table.read(local_file)
w=((catalog['RA']!=catalog['DEC']) & (catalog['RA']>0) & ((catalog['DEC']>=-90) | (catalog['DEC']<=90)))
reduced_cat=catalog[w]
reduced_cat
# Out:
# <Table length=927547>
# PLATEID  MJD  FIBERID ...        KCOR_MAG        KCOR_MODEL_MAG   RELEASE
#  int16  int32  int16  ...       float32[3]         float32[5]     bytes12
# ------- ----- ------- ... ---------------------- -------------- ------------
#     266 51602       1 ... 16.865944 .. 15.630484     0.0 .. 0.0 extra
#     266 51602       2 ...  19.301968 .. 18.27566     0.0 .. 0.0 extra
#     266 51602       4 ... 19.283243 .. 17.644012     0.0 .. 0.0 extra
#     266 51602       5 ...   19.955645 .. -9999.0     0.0 .. 0.0 extra
#     266 51602       6 ...  19.511303 .. 18.61065     0.0 .. 0.0 extra
#     266 51602       8 ... 18.462776 .. 17.328947     0.0 .. 0.0 extra
#     ...   ...     ... ...                    ...            ...          ...
#    2974 54592     628 ... 18.958431 .. 17.859001     0.0 .. 0.0 dr7.2
#    2974 54592     632 ... 18.506687 .. 17.414982     0.0 .. 0.0 dr7.2
#    2974 54592     633 ...  17.472298 .. 16.37964     0.0 .. 0.0 dr7.2
#    2974 54592     635 ... 18.565151 .. 17.500992     0.0 .. 0.0 dr7.2
#    2974 54592     636 ... 18.756723 .. 17.337044     0.0 .. 0.0 dr7.2
#    2974 54592     637 ... 18.153984 .. 16.979458     0.0 .. 0.0 dr7.2
#    2974 54592     638 ...  18.84978 .. 17.756882     0.0 .. 0.0 dr7.2

# %%
plt.hist(reduced_cat['DEC'])
# Out:
# (array([2.63980e+04, 1.88833e+05, 1.42622e+05, 1.52399e+05, 1.39928e+05,
#         1.14575e+05, 8.54820e+04, 6.69360e+04, 1.03110e+04, 6.30000e+01]),
#  array([-16.67872238,  -6.57781792,   3.52308655,  13.62399101,
#          23.72489548,  33.82579803,  43.92670441,  54.02761078,
#          64.12850952,  74.22941589,  84.33032227]),
#  <BarContainer object of 10 artists>)

# %%
NED = pd.read_csv('table_objsearch_div.csv', sep=",", header=0)

# %%
ra1 = np.array(reduced_cat['RA'])
dec1 = np.array(reduced_cat['DEC'])
ra2 = np.array(NED['RA'])
dec2 = np.array(NED['Dec'])
c = SkyCoord(ra=ra2*u.degree, dec=dec2*u.degree)
catalog = SkyCoord(ra=ra1*u.degree, dec=dec1*u.degree)
idx, d2d, d3d = c.match_to_catalog_sky(catalog)

# %%
FOLDER = ['1d_23','1d_25','1d_26']
PLATE = '0266'
URL = "https://data.sdss.org/sas/dr7/das2/spectro/"

# %%
def check_link(path): # Function that takes care of seeing if the file exists on the web or not
    r = requests.head(path)
    status = r.status_code == requests.codes.ok
    if (status == True):
        return True
    else:
        return False

# %%
download_list = []
for n in range(len(idx)):
#for n in range(20):
    plateid = str(reduced_cat['PLATEID'][idx[n]])
    mjd = str(reduced_cat['MJD'][idx[n]])
    fiberid = str(reduced_cat['FIBERID'][idx[n]])
    

    if (len(plateid)<4) or (len(mjd)<5) or (len(fiberid)<3):
        if (len(plateid)<4):
            for x in range(4-len(plateid)):
                plateid = '0' + plateid
        if (len(mjd)<5):
            for y in range(5-len(mjd)):
                mjd = '0' + mjd
        if (len(fiberid)<3):
            for z in range(3-len(fiberid)):
                fiberid = '0' + fiberid
    #print(plateid,mjd,fiberid)

    pre_link = URL + FOLDER[0] + '/' + plateid +"/1d/spSpec" + '-' + mjd + '-' + plateid + '-' + fiberid + '.fit'

    if check_link(pre_link)==False:
        pre_link = URL + FOLDER[1] + '/' + plateid +"/1d/spSpec" + '-' + mjd + '-' + plateid + '-' + fiberid + '.fit'
        if check_link(pre_link)==False:
            pre_link = URL + FOLDER[2] + '/' + plateid +"/1d/spSpec" + '-' + mjd + '-' + plateid + '-' + fiberid + '.fit'
            if check_link(pre_link)==False:
                download_list.append('Not Found')
            else:
                download_list.append(pre_link)
        else:
            download_list.append(pre_link)
    else:
        download_list.append(pre_link)

download_list
# Out:
# ['https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0686/1d/spSpec-52519-0686-406.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0692/1d/spSpec-52201-0692-394.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0697/1d/spSpec-52226-0697-571.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0934/1d/spSpec-52672-0934-369.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0556/1d/spSpec-51991-0556-224.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0284/1d/spSpec-51662-0284-277.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0341/1d/spSpec-51690-0341-606.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2689/1d/spSpec-54149-2689-190.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0384/1d/spSpec-51821-0384-281.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2426/1d/spSpec-53795-2426-015.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1216/1d/spSpec-52709-1216-619.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1981/1d/spSpec-53463-1981-438.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0337/1d/spSpec-51997-0337-097.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/2112/1d/spSpec-53534-2112-557.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2489/1d/spSpec-53857-2489-123.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1947/1d/spSpec-53431-1947-448.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1946/1d/spSpec-53432-1946-609.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1594/1d/spSpec-52992-1594-563.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1983/1d/spSpec-53442-1983-308.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_26/2942/1d/spSpec-54521-2942-246.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_26/2827/1d/spSpec-54422-2827-283.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_26/2708/1d/spSpec-54561-2708-193.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1003/1d/spSpec-52641-1003-327.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_26/2708/1d/spSpec-54561-2708-032.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0854/1d/spSpec-52373-0854-514.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_26/0769/1d/spSpec-54530-0769-086.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0410/1d/spSpec-51877-0410-217.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0549/1d/spSpec-51981-0549-629.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0490/1d/spSpec-51929-0490-128.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0652/1d/spSpec-52138-0652-090.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1781/1d/spSpec-53297-1781-055.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0941/1d/spSpec-52709-0941-109.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0899/1d/spSpec-52620-0899-594.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0753/1d/spSpec-52233-0753-094.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0418/1d/spSpec-51817-0418-302.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1612/1d/spSpec-53149-1612-073.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0999/1d/spSpec-52636-0999-517.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1695/1d/spSpec-53473-1695-627.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1749/1d/spSpec-53357-1749-499.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0502/1d/spSpec-51957-0502-007.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0485/1d/spSpec-51909-0485-550.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0415/1d/spSpec-51810-0415-141.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0480/1d/spSpec-51989-0480-004.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0275/1d/spSpec-51910-0275-445.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0653/1d/spSpec-52145-0653-462.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0658/1d/spSpec-52146-0658-312.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0668/1d/spSpec-52162-0668-152.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0640/1d/spSpec-52178-0640-267.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0639/1d/spSpec-52146-0639-143.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0472/1d/spSpec-51955-0472-546.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0382/1d/spSpec-51816-0382-328.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0662/1d/spSpec-52178-0662-466.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0429/1d/spSpec-51820-0429-495.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0668/1d/spSpec-52162-0668-089.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0455/1d/spSpec-51909-0455-073.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0456/1d/spSpec-51910-0456-195.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0458/1d/spSpec-51929-0458-185.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0459/1d/spSpec-51924-0459-253.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0465/1d/spSpec-51910-0465-524.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0442/1d/spSpec-51882-0442-156.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0447/1d/spSpec-51877-0447-361.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0474/1d/spSpec-52000-0474-610.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0481/1d/spSpec-51908-0481-483.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0308/1d/spSpec-51662-0308-081.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0637/1d/spSpec-52174-0637-399.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0637/1d/spSpec-52174-0637-523.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0381/1d/spSpec-51811-0381-370.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0639/1d/spSpec-52146-0639-242.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0578/1d/spSpec-52339-0578-060.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0580/1d/spSpec-52368-0580-302.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0664/1d/spSpec-52174-0664-355.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0735/1d/spSpec-52519-0735-461.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1027/1d/spSpec-52557-1027-385.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1001/1d/spSpec-52670-1001-380.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1177/1d/spSpec-52824-1177-556.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1195/1d/spSpec-52724-1195-060.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1240/1d/spSpec-52734-1240-340.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1302/1d/spSpec-52763-1302-639.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0488/1d/spSpec-51914-0488-439.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0501/1d/spSpec-52235-0501-602.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0375/1d/spSpec-52140-0375-118.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0507/1d/spSpec-52353-0507-087.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0507/1d/spSpec-52353-0507-521.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0375/1d/spSpec-52140-0375-348.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0575/1d/spSpec-52319-0575-521.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0566/1d/spSpec-52238-0566-497.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0564/1d/spSpec-52224-0564-216.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0564/1d/spSpec-52224-0564-283.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0741/1d/spSpec-52261-0741-279.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0742/1d/spSpec-52263-0742-179.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0742/1d/spSpec-52263-0742-161.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0740/1d/spSpec-52263-0740-259.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0861/1d/spSpec-52318-0861-489.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0859/1d/spSpec-52317-0859-070.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0976/1d/spSpec-52413-0976-600.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1269/1d/spSpec-52937-1269-177.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1585/1d/spSpec-52962-1585-261.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1582/1d/spSpec-52939-1582-335.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1601/1d/spSpec-53115-1601-168.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1745/1d/spSpec-53061-1745-475.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1758/1d/spSpec-53084-1758-338.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1745/1d/spSpec-53061-1745-463.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1922/1d/spSpec-53315-1922-588.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1872/1d/spSpec-53386-1872-526.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1749/1d/spSpec-53357-1749-026.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1921/1d/spSpec-53317-1921-281.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1935/1d/spSpec-53387-1935-204.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1927/1d/spSpec-53321-1927-006.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1945/1d/spSpec-53387-1945-346.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/2132/1d/spSpec-53493-2132-241.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0283/1d/spSpec-51959-0283-389.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/0505/1d/spSpec-52317-0505-228.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_23/1697/1d/spSpec-53142-1697-415.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2483/1d/spSpec-53852-2483-254.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2430/1d/spSpec-53815-2430-117.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2427/1d/spSpec-53815-2427-117.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2373/1d/spSpec-53768-2373-560.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2372/1d/spSpec-53768-2372-508.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2439/1d/spSpec-53795-2439-372.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2293/1d/spSpec-53730-2293-005.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2278/1d/spSpec-53711-2278-411.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2356/1d/spSpec-53786-2356-172.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2353/1d/spSpec-53794-2353-585.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2347/1d/spSpec-53757-2347-501.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2208/1d/spSpec-53880-2208-306.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2284/1d/spSpec-53708-2284-545.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_25/2361/1d/spSpec-53762-2361-523.fit',
#  'https://data.sdss.org/sas/dr7/das2/spectro/1d_26/2318/1d/spSpec-54628-2318-286.fit']

# %%
idx
# Out:
# array([203249, 205383, 207347, 307270, 144228,  10595,  38538, 890006,
#         54603, 818359, 402018, 688108,  35830, 729425, 831389, 677398,
#        677044, 537012, 688756, 920100, 916604, 890103, 339673, 890101,
#        275398, 237909,  71925, 141218, 113132, 187838, 620376, 310103,
#        292251, 230168,  79914, 545636, 337987, 580883, 606193, 118743,
#        111253,  77717, 108532,   5447, 188556, 190971, 196341, 182301,
#        181774, 106432,  53749, 193582,  87236, 196303,  99421,  99882,
#        100733, 101184, 104068,  93316,  95989, 107236, 109304,  26407,
#        181109, 181194,  53407, 181845, 152737, 153895, 194531, 221705,
#        351025, 338737, 387468, 392495, 413239, 431356, 112567, 118717,
#         50344, 121172, 121447,  50516, 151541, 147671, 146670, 146718,
#        224329, 224745, 224729, 223849, 278246, 277211, 328204, 416834,
#        532914, 531864, 540129, 604149, 610216, 604140, 666368, 661628,
#        605823, 665738, 671729, 668074, 676407, 739622,  10194, 120270,
#        581695, 828481, 819969, 818816, 813582, 813089, 824543, 795877,
#        790335, 806001, 804966, 802030, 766150, 792770, 808306, 798968])

# %%
reduced_cat[798968]
# Out:
# <Row index=798968>
# PLATEID  MJD  FIBERID   PHOTOID        RA       DEC         PLUG_MAG    PRIMTARGET SECTARGET      TARGETTYPE     SPECTROTYPE        SUBCLASS             Z          Z_ERR     Z_WARNING  V_DISP V_DISP_ERR SN_MEDIAN  E_BV_SFD   ZTWEAK ZTWEAK_ERR      SPECTRO_MAG              KCOR_MAG        KCOR_MODEL_MAG   RELEASE
#  int16  int32  int16    int16[5]    float32   float32      float32[5]     int16      int16         bytes19          bytes6          bytes21           float32      float32      int16   float32  float32    float32   float32   float32  float32         float32[3]             float32[3]         float32[5]     bytes12
# ------- ----- ------- ------------ --------- ---------- --------------- ---------- --------- ------------------- ----------- --------------------- ------------- ------------ --------- ------- ---------- --------- ---------- ------- ---------- ---------------------- ---------------------- -------------- ------------
#    2318 54628     286 5421 .. 1912 300.77002 -12.181815 21.848 .. 20.18          0         0 SERENDIPITY_BLUE         GALAXY                       -0.0002894696 7.661426e-05         4    70.0      -50.0 5.4420753 0.18147376     0.0        0.0 20.312202 .. 19.705383 20.312214 .. 19.704857     0.0 .. 0.0 special

# %%
for f in range(len(download_list)):
    print(f"({f+1}/{len(download_list)}) Downloading {download_list[f][-25:]} ...")
    direc = '/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/' + download_list[f][-25:]
    DOWNLOAD = urllib.request.urlretrieve(download_list[f], direc)
# Out:
# (1/128) Downloading spSpec-52519-0686-406.fit ...
# (2/128) Downloading spSpec-52201-0692-394.fit ...
# (3/128) Downloading spSpec-52226-0697-571.fit ...
# (4/128) Downloading spSpec-52672-0934-369.fit ...
# (5/128) Downloading spSpec-51991-0556-224.fit ...
# (6/128) Downloading spSpec-51662-0284-277.fit ...
# (7/128) Downloading spSpec-51690-0341-606.fit ...
# (8/128) Downloading spSpec-54149-2689-190.fit ...
# (9/128) Downloading spSpec-51821-0384-281.fit ...
# (10/128) Downloading spSpec-53795-2426-015.fit ...
# (11/128) Downloading spSpec-52709-1216-619.fit ...
# (12/128) Downloading spSpec-53463-1981-438.fit ...
# (13/128) Downloading spSpec-51997-0337-097.fit ...
# (14/128) Downloading spSpec-53534-2112-557.fit ...
# (15/128) Downloading spSpec-53857-2489-123.fit ...
# (16/128) Downloading spSpec-53431-1947-448.fit ...
# (17/128) Downloading spSpec-53432-1946-609.fit ...
# (18/128) Downloading spSpec-52992-1594-563.fit ...
# (19/128) Downloading spSpec-53442-1983-308.fit ...
# (20/128) Downloading spSpec-54521-2942-246.fit ...
# (21/128) Downloading spSpec-54422-2827-283.fit ...
# (22/128) Downloading spSpec-54561-2708-193.fit ...
# (23/128) Downloading spSpec-52641-1003-327.fit ...
# (24/128) Downloading spSpec-54561-2708-032.fit ...
# (25/128) Downloading spSpec-52373-0854-514.fit ...
# (26/128) Downloading spSpec-54530-0769-086.fit ...
# (27/128) Downloading spSpec-51877-0410-217.fit ...
# (28/128) Downloading spSpec-51981-0549-629.fit ...
# (29/128) Downloading spSpec-51929-0490-128.fit ...
# (30/128) Downloading spSpec-52138-0652-090.fit ...
# (31/128) Downloading spSpec-53297-1781-055.fit ...
# (32/128) Downloading spSpec-52709-0941-109.fit ...
# (33/128) Downloading spSpec-52620-0899-594.fit ...
# (34/128) Downloading spSpec-52233-0753-094.fit ...
# (35/128) Downloading spSpec-51817-0418-302.fit ...
# (36/128) Downloading spSpec-53149-1612-073.fit ...
# (37/128) Downloading spSpec-52636-0999-517.fit ...
# (38/128) Downloading spSpec-53473-1695-627.fit ...
# (39/128) Downloading spSpec-53357-1749-499.fit ...
# (40/128) Downloading spSpec-51957-0502-007.fit ...
# (41/128) Downloading spSpec-51909-0485-550.fit ...
# (42/128) Downloading spSpec-51810-0415-141.fit ...
# (43/128) Downloading spSpec-51989-0480-004.fit ...
# (44/128) Downloading spSpec-51910-0275-445.fit ...
# (45/128) Downloading spSpec-52145-0653-462.fit ...
# (46/128) Downloading spSpec-52146-0658-312.fit ...
# (47/128) Downloading spSpec-52162-0668-152.fit ...
# (48/128) Downloading spSpec-52178-0640-267.fit ...
# (49/128) Downloading spSpec-52146-0639-143.fit ...
# (50/128) Downloading spSpec-51955-0472-546.fit ...
# (51/128) Downloading spSpec-51816-0382-328.fit ...
# (52/128) Downloading spSpec-52178-0662-466.fit ...
# (53/128) Downloading spSpec-51820-0429-495.fit ...
# (54/128) Downloading spSpec-52162-0668-089.fit ...
# (55/128) Downloading spSpec-51909-0455-073.fit ...
# (56/128) Downloading spSpec-51910-0456-195.fit ...
# (57/128) Downloading spSpec-51929-0458-185.fit ...
# (58/128) Downloading spSpec-51924-0459-253.fit ...
# (59/128) Downloading spSpec-51910-0465-524.fit ...
# (60/128) Downloading spSpec-51882-0442-156.fit ...
# (61/128) Downloading spSpec-51877-0447-361.fit ...
# (62/128) Downloading spSpec-52000-0474-610.fit ...
# (63/128) Downloading spSpec-51908-0481-483.fit ...
# (64/128) Downloading spSpec-51662-0308-081.fit ...
# (65/128) Downloading spSpec-52174-0637-399.fit ...
# (66/128) Downloading spSpec-52174-0637-523.fit ...
# (67/128) Downloading spSpec-51811-0381-370.fit ...
# (68/128) Downloading spSpec-52146-0639-242.fit ...
# (69/128) Downloading spSpec-52339-0578-060.fit ...
# (70/128) Downloading spSpec-52368-0580-302.fit ...
# (71/128) Downloading spSpec-52174-0664-355.fit ...
# (72/128) Downloading spSpec-52519-0735-461.fit ...
# (73/128) Downloading spSpec-52557-1027-385.fit ...
# (74/128) Downloading spSpec-52670-1001-380.fit ...
# (75/128) Downloading spSpec-52824-1177-556.fit ...
# (76/128) Downloading spSpec-52724-1195-060.fit ...
# (77/128) Downloading spSpec-52734-1240-340.fit ...
# (78/128) Downloading spSpec-52763-1302-639.fit ...
# (79/128) Downloading spSpec-51914-0488-439.fit ...
# (80/128) Downloading spSpec-52235-0501-602.fit ...
# (81/128) Downloading spSpec-52140-0375-118.fit ...
# (82/128) Downloading spSpec-52353-0507-087.fit ...
# (83/128) Downloading spSpec-52353-0507-521.fit ...
# (84/128) Downloading spSpec-52140-0375-348.fit ...
# (85/128) Downloading spSpec-52319-0575-521.fit ...
# (86/128) Downloading spSpec-52238-0566-497.fit ...
# (87/128) Downloading spSpec-52224-0564-216.fit ...
# (88/128) Downloading spSpec-52224-0564-283.fit ...
# (89/128) Downloading spSpec-52261-0741-279.fit ...
# (90/128) Downloading spSpec-52263-0742-179.fit ...
# (91/128) Downloading spSpec-52263-0742-161.fit ...
# (92/128) Downloading spSpec-52263-0740-259.fit ...
# (93/128) Downloading spSpec-52318-0861-489.fit ...
# (94/128) Downloading spSpec-52317-0859-070.fit ...
# (95/128) Downloading spSpec-52413-0976-600.fit ...
# (96/128) Downloading spSpec-52937-1269-177.fit ...
# (97/128) Downloading spSpec-52962-1585-261.fit ...
# (98/128) Downloading spSpec-52939-1582-335.fit ...
# (99/128) Downloading spSpec-53115-1601-168.fit ...
# (100/128) Downloading spSpec-53061-1745-475.fit ...
# (101/128) Downloading spSpec-53084-1758-338.fit ...
# (102/128) Downloading spSpec-53061-1745-463.fit ...
# (103/128) Downloading spSpec-53315-1922-588.fit ...
# (104/128) Downloading spSpec-53386-1872-526.fit ...
# (105/128) Downloading spSpec-53357-1749-026.fit ...
# (106/128) Downloading spSpec-53317-1921-281.fit ...
# (107/128) Downloading spSpec-53387-1935-204.fit ...
# (108/128) Downloading spSpec-53321-1927-006.fit ...
# (109/128) Downloading spSpec-53387-1945-346.fit ...
# (110/128) Downloading spSpec-53493-2132-241.fit ...
# (111/128) Downloading spSpec-51959-0283-389.fit ...
# (112/128) Downloading spSpec-52317-0505-228.fit ...
# (113/128) Downloading spSpec-53142-1697-415.fit ...
# (114/128) Downloading spSpec-53852-2483-254.fit ...
# (115/128) Downloading spSpec-53815-2430-117.fit ...
# (116/128) Downloading spSpec-53815-2427-117.fit ...
# (117/128) Downloading spSpec-53768-2373-560.fit ...
# (118/128) Downloading spSpec-53768-2372-508.fit ...
# (119/128) Downloading spSpec-53795-2439-372.fit ...
# (120/128) Downloading spSpec-53730-2293-005.fit ...
# (121/128) Downloading spSpec-53711-2278-411.fit ...
# (122/128) Downloading spSpec-53786-2356-172.fit ...
# (123/128) Downloading spSpec-53794-2353-585.fit ...
# (124/128) Downloading spSpec-53757-2347-501.fit ...
# (125/128) Downloading spSpec-53880-2208-306.fit ...
# (126/128) Downloading spSpec-53708-2284-545.fit ...
# (127/128) Downloading spSpec-53762-2361-523.fit ...
# (128/128) Downloading spSpec-54628-2318-286.fit ...

# %%
Spec = fits.open('/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/' + 'spSpec-52263-0742-161.fit')

# %%
def spec_plotter(name,RL=4000,LL=7000):
    local_dirspc="/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/"
    spc = os.path.join(local_dirspc,name)  
    file = fits.open(spc)
    DATA = file[0].data
    zz = file[0].header['Z']
    RA = file[0].header['RA']
    DEC = file[0].header['DEC']
    c = SkyCoord(ra=RA*u.degree, dec=DEC*u.degree, frame='icrs')
    c.galactic
    sfd = SFDQuery()
    ebv01 = sfd(c.galactic)
    flux = DATA[0]
    wav00 = file[0].header['COEFF0']
    wavdiff = file[0].header['COEFF1']
    waveair = 10**(wav00 + wavdiff*np.arange(len(flux)))
    waveobs = waveair/(1.0+2.735182E-4+131.4182/(waveair)**2 +2.76249E8/(waveair)**4)
    file.close()
    wave = waveobs/(1.0+zz)
    fluxUnred = pyasl.unred(wave, flux, ebv=ebv01, R_V=3.1)
    flux_final = fluxUnred*(1.0+zz)**3
    wave_in = int(wave[2])             #initial wavelength
    wave_fin = int(wave[len(wave)-2])  #final wavelength
    wave_new = np.arange(wave_in, wave_fin, 1)
    flux_interpolate = interp1d(wave, flux_final, kind='quadratic')
    flux_starlight = flux_interpolate(wave_new)
    plt.rcParams['axes.spines.left'] = True
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.bottom'] = True
    plt.figure(figsize=(20,8),dpi=70)
    plt.plot(wave,flux_final,label = 'Flux',lw=0.7, color ='#1C448E')
    plt.ylabel(r"$F_{\lambda}\ \left[ 10^{-17}\ {\rm erg\ s}^{-1}\ {\rm cm}^{-2}\ \AA^{-1} \right]$", style = 'oblique', family = 'serif', size = 25)
    plt.xlabel('Wavelength [$\AA$]', style = 'oblique', family = 'serif', size = 25)
    plt.yticks(fontsize = 15)
    plt.xticks(fontsize = 15)
    plot_lim = [RL,LL]
    plt.xlim(plot_lim)
    plt.ylim(0,max(flux)+15)
    plt.grid(True, which="both", ls=":", color = 'gray', linewidth = 0.5)
    txt_prop = {'style' : 'oblique', 'family' : 'serif', 'size' :15}       
    plt.legend(title = f'z = {round((zz),3)}', prop = txt_prop, loc= 'upper right')
    plt.show()

# %%
spec_plotter('spSpec-52992-1594-563.fit')
