# %%
import prospect
print(prospect.__version__)
# Out:
# 1.4.0

# %%
import fsps
import dynesty
import sedpy
import h5py, astropy
import numpy as np
import astroquery
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import fsps
#       2 import dynesty
#       3 import sedpy
#
# File ~/miniconda3/lib/python3.13/site-packages/fsps/__init__.py:4
#       1 # Check the that SPS_HOME variable is set properly
#       2 from fsps.sps_home import check_sps_home
# ----> 4 check_sps_home()
#       6 del check_sps_home
#       7 # End check
#
# File ~/miniconda3/lib/python3.13/site-packages/fsps/sps_home.py:15, in check_sps_home()
#      12     raise RuntimeError(f"SPS_HOME environment variable '{path}' is not a directory")
#      14 if not os.path.exists(os.path.join(path, "data", "emlines_info.dat")):
# ---> 15     raise RuntimeError(
#      16         f"The FSPS directory at {path} doesn't seem to have the right data "
#      17         "files installed"
#      18     )
#
# ...
