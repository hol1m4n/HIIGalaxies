# %%
import os
import sys
import glob
from pathlib import Path
from astropy.io import fits
import numpy as np
from numpy import savetxt
import matplotlib
import matplotlib.pyplot as plt
from PyAstronomy import pyasl
from scipy.interpolate import interp1d
from astropy import units as u
from astropy.coordinates import SkyCoord
#install dustmaps from https://github.com/gregreen/dustmaps
from dustmaps.sfd import SFDQuery
import pandas as pd
from astropy.table import Table
import gc
matplotlib.use("Agg")
plt.ioff()

# %%
path = '/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/'

if (os.path.exists(path) == True):
    print('Folder for HII Galaxies tex format \n')
else:
    print(f'Folder for HII Galaxies tex format created ({path}) \n')
    os.mkdir(path)
# Out:
# Folder for HII Galaxies tex format

# %%
spec_list = os.listdir(path[:-12])
spec_list.remove('Tex_spectra')
spec_list.remove('Spectra_plots')

# %%
def sdss_dust_correction(NAME):
    hdu = fits.open('/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/'+NAME)
    data = hdu[0].data
    ##############################################################
    #Read the header
    
    zz = hdu[0].header['Z']
    RA = hdu[0].header['RA']
    DEC = hdu[0].header['DEC']
    
    c = SkyCoord(ra=RA*u.degree, dec=DEC*u.degree, frame='icrs')
    c.galactic
    
    sfd = SFDQuery()
    ebv01 = sfd(c.galactic)
    
    ##############################################################
    #Read the spectra, flux and wavelength
    
    flux = data[0]
    wav00 = hdu[0].header['COEFF0']
    wavdiff = hdu[0].header['COEFF1']

    hdu.close()
    
    waveair = 10**(wav00 + wavdiff*np.arange(len(flux)))
    
    waveobs = waveair/(1.0+2.735182E-4+131.4182/(waveair)**2 +2.76249E8/(waveair)**4)
    
    ##############################################################
    #redshift correction
    
    wave = waveobs/(1.0+zz)
    
    ##############################################################
    #Unredding the spectra
    
    fluxUnred = pyasl.unred(wave, flux, ebv=ebv01, R_V=3.1)
    
    ##############################################################
    #cosmoiogical flux corrextion
    
    flux_final = fluxUnred*(1.0+zz)**3
    
    ##############################################################
    #Change the wavelength to starlight input
    
    wave_in = int(wave[2])             #initial wavelength
    wave_fin = int(wave[len(wave)-2])  #final wavelength
    
    wave_new = np.arange(wave_in, wave_fin, 1)
    
    flux_interpolate = interp1d(wave, flux_final, kind='quadratic')
    flux_starlight = flux_interpolate(wave_new)
    
    ##############################################################
    #Crate an output array
    
    table = list(zip(wave_new, flux_starlight))
    
    # Save the file
    new_name  = path + (NAME.replace('.fit',""))
    savetxt(new_name + '.tex', table, fmt='%8.4f', delimiter='    ')
    print(NAME+ ' spectra saved in '+new_name + '.tex')

# %%
for i in range(len(spec_list)):
    sdss_dust_correction(spec_list[i])
# Out:
# spSpec-52339-0578-060.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52339-0578-060.tex
# spSpec-52937-1269-177.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52937-1269-177.tex
# spSpec-53297-1781-055.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53297-1781-055.tex
# spSpec-52962-1585-261.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52962-1585-261.tex
# spSpec-53473-1695-627.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53473-1695-627.tex
# spSpec-52353-0507-521.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52353-0507-521.tex
# spSpec-53534-2112-557.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53534-2112-557.tex
# spSpec-51929-0490-128.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51929-0490-128.tex
# spSpec-54561-2708-193.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54561-2708-193.tex
# spSpec-51821-0384-281.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51821-0384-281.tex
# spSpec-53768-2372-508.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53768-2372-508.tex
# spSpec-54628-2318-286.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54628-2318-286.tex
# spSpec-51882-0442-156.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51882-0442-156.tex
# spSpec-53386-1872-526.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53386-1872-526.tex
# spSpec-52174-0637-523.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52174-0637-523.tex
# spSpec-52224-0564-216.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52224-0564-216.tex
# spSpec-52636-0999-517.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52636-0999-517.tex
# spSpec-51957-0502-007.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51957-0502-007.tex
# spSpec-53084-1758-338.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53084-1758-338.tex
# spSpec-52413-0976-600.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52413-0976-600.tex
# spSpec-52178-0640-267.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52178-0640-267.tex
# spSpec-53463-1981-438.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53463-1981-438.tex
# spSpec-52641-1003-327.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52641-1003-327.tex
# spSpec-53768-2373-560.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53768-2373-560.tex
# spSpec-52939-1582-335.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52939-1582-335.tex
# spSpec-51816-0382-328.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51816-0382-328.tex
# spSpec-53317-1921-281.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53317-1921-281.tex
# spSpec-53142-1697-415.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53142-1697-415.tex
# spSpec-52138-0652-090.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52138-0652-090.tex
# spSpec-52238-0566-497.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52238-0566-497.tex
# spSpec-53786-2356-172.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53786-2356-172.tex
# spSpec-52174-0664-355.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52174-0664-355.tex
# spSpec-53852-2483-254.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53852-2483-254.tex
# spSpec-54521-2942-246.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54521-2942-246.tex
# spSpec-51909-0455-073.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51909-0455-073.tex
# spSpec-52992-1594-563.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52992-1594-563.tex
# spSpec-51811-0381-370.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51811-0381-370.tex
# spSpec-52263-0742-179.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52263-0742-179.tex
# spSpec-53387-1935-204.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53387-1935-204.tex
# spSpec-51909-0485-550.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51909-0485-550.tex
# spSpec-51877-0447-361.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51877-0447-361.tex
# spSpec-53815-2430-117.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53815-2430-117.tex
# spSpec-51662-0284-277.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51662-0284-277.tex
# spSpec-52146-0639-242.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52146-0639-242.tex
# spSpec-53061-1745-463.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53061-1745-463.tex
# spSpec-51877-0410-217.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51877-0410-217.tex
# spSpec-51914-0488-439.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51914-0488-439.tex
# spSpec-51929-0458-185.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51929-0458-185.tex
# spSpec-52140-0375-118.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52140-0375-118.tex
# spSpec-52145-0653-462.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52145-0653-462.tex
# spSpec-51924-0459-253.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51924-0459-253.tex
# spSpec-53815-2427-117.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53815-2427-117.tex
# spSpec-52318-0861-489.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52318-0861-489.tex
# spSpec-52263-0740-259.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52263-0740-259.tex
# spSpec-54149-2689-190.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54149-2689-190.tex
# spSpec-53115-1601-168.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53115-1601-168.tex
# spSpec-53880-2208-306.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53880-2208-306.tex
# spSpec-53708-2284-545.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53708-2284-545.tex
# spSpec-51820-0429-495.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51820-0429-495.tex
# spSpec-53794-2353-585.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53794-2353-585.tex
# spSpec-53149-1612-073.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53149-1612-073.tex
# spSpec-53757-2347-501.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53757-2347-501.tex
# spSpec-52368-0580-302.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52368-0580-302.tex
# spSpec-52373-0854-514.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52373-0854-514.tex
# spSpec-53730-2293-005.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53730-2293-005.tex
# spSpec-54422-2827-283.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54422-2827-283.tex
# spSpec-52353-0507-087.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52353-0507-087.tex
# spSpec-51959-0283-389.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51959-0283-389.tex
# spSpec-53442-1983-308.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53442-1983-308.tex
# spSpec-52233-0753-094.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52233-0753-094.tex
# spSpec-52000-0474-610.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52000-0474-610.tex
# spSpec-52709-1216-619.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52709-1216-619.tex
# spSpec-52146-0639-143.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52146-0639-143.tex
# spSpec-52235-0501-602.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52235-0501-602.tex
# spSpec-54530-0769-086.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54530-0769-086.tex
# spSpec-51991-0556-224.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51991-0556-224.tex
# spSpec-51997-0337-097.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51997-0337-097.tex
# spSpec-51981-0549-629.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51981-0549-629.tex
# spSpec-53357-1749-499.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53357-1749-499.tex
# spSpec-52174-0637-399.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52174-0637-399.tex
# spSpec-52724-1195-060.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52724-1195-060.tex
# spSpec-51662-0308-081.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51662-0308-081.tex
# spSpec-52146-0658-312.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52146-0658-312.tex
# spSpec-54561-2708-032.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-54561-2708-032.tex
# spSpec-52319-0575-521.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52319-0575-521.tex
# spSpec-51910-0456-195.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51910-0456-195.tex
# spSpec-51908-0481-483.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51908-0481-483.tex
# spSpec-53321-1927-006.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53321-1927-006.tex
# spSpec-52620-0899-594.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52620-0899-594.tex
# spSpec-52519-0735-461.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52519-0735-461.tex
# spSpec-52140-0375-348.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52140-0375-348.tex
# spSpec-52162-0668-152.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52162-0668-152.tex
# spSpec-52519-0686-406.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52519-0686-406.tex
# spSpec-53431-1947-448.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53431-1947-448.tex
# spSpec-52672-0934-369.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52672-0934-369.tex
# spSpec-52263-0742-161.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52263-0742-161.tex
# spSpec-53061-1745-475.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53061-1745-475.tex
# spSpec-51817-0418-302.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51817-0418-302.tex
# spSpec-53432-1946-609.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53432-1946-609.tex
# spSpec-53357-1749-026.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53357-1749-026.tex
# spSpec-51810-0415-141.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51810-0415-141.tex
# spSpec-52763-1302-639.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52763-1302-639.tex
# spSpec-52734-1240-340.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52734-1240-340.tex
# spSpec-53711-2278-411.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53711-2278-411.tex
# spSpec-53387-1945-346.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53387-1945-346.tex
# spSpec-52670-1001-380.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52670-1001-380.tex
# spSpec-52317-0505-228.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52317-0505-228.tex
# spSpec-52201-0692-394.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52201-0692-394.tex
# spSpec-52317-0859-070.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52317-0859-070.tex
# spSpec-52178-0662-466.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52178-0662-466.tex
# spSpec-51955-0472-546.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51955-0472-546.tex
# spSpec-53762-2361-523.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53762-2361-523.tex
# spSpec-52709-0941-109.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52709-0941-109.tex
# spSpec-53493-2132-241.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53493-2132-241.tex
# spSpec-53315-1922-588.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53315-1922-588.tex
# spSpec-52824-1177-556.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52824-1177-556.tex
# spSpec-53795-2439-372.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53795-2439-372.tex
# spSpec-52261-0741-279.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52261-0741-279.tex
# spSpec-53795-2426-015.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53795-2426-015.tex
# spSpec-52162-0668-089.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52162-0668-089.tex
# spSpec-53857-2489-123.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-53857-2489-123.tex
# spSpec-51989-0480-004.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51989-0480-004.tex
# spSpec-52226-0697-571.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52226-0697-571.tex
# spSpec-51910-0465-524.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51910-0465-524.tex
# spSpec-52224-0564-283.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52224-0564-283.tex
# spSpec-52557-1027-385.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-52557-1027-385.tex
# spSpec-51690-0341-606.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51690-0341-606.tex
# spSpec-51910-0275-445.fit spectra saved in /home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/spSpec-51910-0275-445.tex

# %%
# Opcional: evita trazados gigantes en Agg con paths muy largos
plt.rcParams['agg.path.chunksize'] = 10000

DATA_URL = "http://das.sdss.org/spectro/ss_tar_26/"
catalog_name = "gal_info_dr7_v5_2.fit.gz"
local_dir = "/home/hollman/DataHII/"

# Lee el catálogo una sola vez, con mapeo de memoria
with fits.open(os.path.join(local_dir, catalog_name), memmap=True) as hdul:
    catalog = Table(hdul[1].data)

ll = ['HB','O[III]a','O[III]b','Ha']
lines = {
  "HB": [4862.721, r'H-$\beta$', 4862.0000],
  "O[III]a": [4960.295, r'O[III]$\lambda$4959', 4960.0000],
  "O[III]b": [5008.239, r'O[III]$\lambda$5007', 5007.0000],
  "Ha": [6562.801, r'H-$\alpha$', 6562.0000]
}

# %%
def spec_plotter(name,
                 figsize=(48, 18),        # << mucho más pequeño
                 render_dpi=120,          # DPI de canvas
                 save_dpi=150,            # DPI del archivo final
                 tol=1.0):                # tolerancia en Å para localizar líneas

    # Construye paths/nombres como en tu versión
    base = (name.replace('.fit', '')) + ".tex"
    local_dirspc = "/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/"
    spc = os.path.join(local_dirspc, base)

    # Extrae IDs desde el nombre, como en tu código
    plateid, mjd, fiberid = [int(base[13:17]), int(base[7:12]), int(base[18:21])]

    # Selección de fila en el catálogo
    z_finder = (catalog['PLATEID'] == plateid) & (catalog['MJD'] == mjd) & (catalog['FIBERID'] == fiberid)
    reduced_cat = catalog[z_finder]
    Z = float(reduced_cat['Z'][0])

    # Lee espectro (rápido y sobrio en memoria)
    data = Table.read(spc, format='ascii', fast_reader=True)
    lam = np.asarray(data['col1'], dtype=float)
    flux = np.asarray(data['col2'], dtype=float)

    # Prepara figura/axes (OO) y estilos básicos
    fig, ax = plt.subplots(figsize=figsize, dpi=render_dpi)
    ax.spines.right.set_visible(False)
    ax.spines.top.set_visible(False)

    # Trazado principal
    ax.plot(lam, flux, label='Flux', lw=1.2)

    ax.set_ylabel(r"$F_{\lambda}\ \left[10^{-17}\ {\rm erg\ s}^{-1}\ {\rm cm}^{-2}\ \AA^{-1}\right]$",
                  style='oblique', family='serif')
    ax.set_xlabel(r'Wavelength at rest $\lambda$ [$\AA$]',
                  style='oblique', family='serif')

    # Anotación de líneas (con tolerancia en lugar de igualdad exacta)
    for key in ll:
        rest = lines[key][2]
        idx = np.where(np.abs(lam - rest) <= tol)[0]
        if idx.size:
            i0 = idx[len(idx)//2]
            i1, i2 = max(i0 - 10, 0), min(i0 + 10, flux.size)
            selec_flux_max = float(flux[i1:i2].max()) + 0.05 * (flux.max() - flux.min())
            x = rest - (100 if key in ('O[III]a', 'O[III]b') else 30)
            ax.text(x, selec_flux_max, f"{lines[key][1]}",
                    fontsize=11,
                    bbox={'facecolor': '#F4F1BB', 'alpha': 0.5, 'boxstyle': "round,pad=0.2", 'ec': 'none'})

    ax.tick_params(axis='x', labelrotation=90)
    ax.set_xlim(3500, 8000)
    ax.set_ylim(0, max(float(flux.max()), 1.0) * 1.05)
    ax.grid(True, which="both", ls=":", linewidth=0.8)

    leg_title = f"{base[:-4]}\nZ = {Z}\nPLATEID = {plateid}\nMJD = {mjd}\nFIBERID = {fiberid}"
    ax.legend(title=leg_title, loc='upper right', prop={'size': 10}, title_fontsize=11)

    outdir = "/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Spectra_plots/"
    os.makedirs(outdir, exist_ok=True)
    outfile = os.path.join(outdir, base.replace('.tex', '') + ".png")

    # Guarda (si "tight" no es imprescindible, quítalo para ahorrar un poco más)
    fig.savefig(outfile, dpi=save_dpi, bbox_inches='tight', transparent=False)

    # Cierra y limpia SOLO esta figura
    plt.close(fig)
    del fig, ax, data, lam, flux, reduced_cat
    gc.collect()
    print('Done for ' + base.replace('.tex', ''))

# Bucle principal (usa directamente la lista)
for name in spec_list:
    try:
        spec_plotter(name)
    except Exception as e:
        print(f"[WARN] Falló {name}: {e}")
# Out:
# Done for spSpec-52339-0578-060
# Done for spSpec-52937-1269-177
# Done for spSpec-53297-1781-055
# Done for spSpec-52962-1585-261
# Done for spSpec-53473-1695-627
# Done for spSpec-52353-0507-521
# Done for spSpec-53534-2112-557
# Done for spSpec-51929-0490-128
# Done for spSpec-54561-2708-193
# Done for spSpec-51821-0384-281
# Done for spSpec-53768-2372-508
# Done for spSpec-54628-2318-286
# Done for spSpec-51882-0442-156
# Done for spSpec-53386-1872-526
# Done for spSpec-52174-0637-523
# Done for spSpec-52224-0564-216
# Done for spSpec-52636-0999-517
# Done for spSpec-51957-0502-007
# Done for spSpec-53084-1758-338
# Done for spSpec-52413-0976-600
# Done for spSpec-52178-0640-267
# Done for spSpec-53463-1981-438
# Done for spSpec-52641-1003-327
# Done for spSpec-53768-2373-560
# Done for spSpec-52939-1582-335
# Done for spSpec-51816-0382-328
# Done for spSpec-53317-1921-281
# Done for spSpec-53142-1697-415
# Done for spSpec-52138-0652-090
# Done for spSpec-52238-0566-497
# Done for spSpec-53786-2356-172
# Done for spSpec-52174-0664-355
# Done for spSpec-53852-2483-254
# Done for spSpec-54521-2942-246
# Done for spSpec-51909-0455-073
# Done for spSpec-52992-1594-563
# Done for spSpec-51811-0381-370
# Done for spSpec-52263-0742-179
# Done for spSpec-53387-1935-204
# Done for spSpec-51909-0485-550
# Done for spSpec-51877-0447-361
# Done for spSpec-53815-2430-117
# Done for spSpec-51662-0284-277
# Done for spSpec-52146-0639-242
# Done for spSpec-53061-1745-463
# Done for spSpec-51877-0410-217
# Done for spSpec-51914-0488-439
# Done for spSpec-51929-0458-185
# Done for spSpec-52140-0375-118
# Done for spSpec-52145-0653-462
# Done for spSpec-51924-0459-253
# Done for spSpec-53815-2427-117
# Done for spSpec-52318-0861-489
# Done for spSpec-52263-0740-259
# Done for spSpec-54149-2689-190
# Done for spSpec-53115-1601-168
# Done for spSpec-53880-2208-306
# Done for spSpec-53708-2284-545
# Done for spSpec-51820-0429-495
# Done for spSpec-53794-2353-585
# Done for spSpec-53149-1612-073
# Done for spSpec-53757-2347-501
# Done for spSpec-52368-0580-302
# Done for spSpec-52373-0854-514
# Done for spSpec-53730-2293-005
# Done for spSpec-54422-2827-283
# Done for spSpec-52353-0507-087
# Done for spSpec-51959-0283-389
# Done for spSpec-53442-1983-308
# Done for spSpec-52233-0753-094
# Done for spSpec-52000-0474-610
# Done for spSpec-52709-1216-619
# Done for spSpec-52146-0639-143
# Done for spSpec-52235-0501-602
# Done for spSpec-54530-0769-086
# Done for spSpec-51991-0556-224
# Done for spSpec-51997-0337-097
# Done for spSpec-51981-0549-629
# Done for spSpec-53357-1749-499
# Done for spSpec-52174-0637-399
# Done for spSpec-52724-1195-060
# Done for spSpec-51662-0308-081
# Done for spSpec-52146-0658-312
# Done for spSpec-54561-2708-032
# Done for spSpec-52319-0575-521
# Done for spSpec-51910-0456-195
# Done for spSpec-51908-0481-483
# Done for spSpec-53321-1927-006
# Done for spSpec-52620-0899-594
# Done for spSpec-52519-0735-461
# Done for spSpec-52140-0375-348
# Done for spSpec-52162-0668-152
# Done for spSpec-52519-0686-406
# Done for spSpec-53431-1947-448
# Done for spSpec-52672-0934-369
# Done for spSpec-52263-0742-161
# Done for spSpec-53061-1745-475
# Done for spSpec-51817-0418-302
# Done for spSpec-53432-1946-609
# Done for spSpec-53357-1749-026
# Done for spSpec-51810-0415-141
# Done for spSpec-52763-1302-639
# Done for spSpec-52734-1240-340
# Done for spSpec-53711-2278-411
# Done for spSpec-53387-1945-346
# Done for spSpec-52670-1001-380
# Done for spSpec-52317-0505-228
# Done for spSpec-52201-0692-394
# Done for spSpec-52317-0859-070
# Done for spSpec-52178-0662-466
# Done for spSpec-51955-0472-546
# Done for spSpec-53762-2361-523
# Done for spSpec-52709-0941-109
# Done for spSpec-53493-2132-241
# Done for spSpec-53315-1922-588
# Done for spSpec-52824-1177-556
# Done for spSpec-53795-2439-372
# Done for spSpec-52261-0741-279
# Done for spSpec-53795-2426-015
# Done for spSpec-52162-0668-089
# Done for spSpec-53857-2489-123
# Done for spSpec-51989-0480-004
# Done for spSpec-52226-0697-571
# Done for spSpec-51910-0465-524
# Done for spSpec-52224-0564-283
# Done for spSpec-52557-1027-385
# Done for spSpec-51690-0341-606
# Done for spSpec-51910-0275-445

# %% [markdown]
# # Version vieja no optimizada

# %%
DATA_URL="http://das.sdss.org/spectro/ss_tar_26/"
catalog_name="gal_info_dr7_v5_2.fit.gz"
local_dir="/home/hollman/DataHII/"
local_file = fits.open(os.path.join(local_dir,catalog_name))
catalog=Table.read(local_file[1])
local_file.close()

ll = ['HB','O[III]a','O[III]b','Ha']
# Lines dictionary
lines = {
  "HB": [4862.721,r'H-$\beta$',4862.0000], #4862
  "O[III]a": [4960.295,r'O[III]$\lambda$4959',4960.0000],#4960
  "O[III]b": [5008.239,r'O[III]$\lambda$5007',5007.0000],#5007
  "Ha": [6562.801,r'H-$\alpha$',6562.0000] ##6550
}

# %%
def spec_plotter(name):
    name = (name.replace('.fit',"")) + ".tex"
    local_dirspc="/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Tex_spectra/"
    spc = os.path.join(local_dirspc,name)
    plateid, mjd, fiberid = [int(name[13:17]), int(name[7:12]), int(name[18:21])]
    z_finder = (catalog['PLATEID']==plateid) & (catalog['MJD']==mjd) & (catalog['FIBERID']==fiberid)
    reduced_cat = catalog[z_finder]
    Z = round(float(reduced_cat['Z'][0]),6)
    data = Table.read(spc, format='ascii')
    data.rename_column('col1', r'$\lambda$')
    data.rename_column('col2', 'Flux')
    plt.rcParams['axes.spines.left'] = True
    plt.rcParams['axes.spines.right'] = False
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.bottom'] = True
    plt.figure(figsize=(40,18),dpi=200)
    plt.plot(data[r'$\lambda$'],data['Flux'],label = 'Flux',lw=1.3, color ='#1C448E')
    plt.ylabel(r"$F_{\lambda}\ \left[ 10^{-17}\ {\rm erg\ s}^{-1}\ {\rm cm}^{-2}\ \AA^{-1} \right]$", style = 'oblique', family = 'serif', size = 25)
    plt.xlabel(r'Wavelength at rest $\lambda$ [$\AA$]', style = 'oblique', family = 'serif', size = 25)
    # Lineas a mostrar
    for a in range(len(ll)):#len(ll)
        v_lambda = lines[ll[a]][2] 
        flux_line = data[(data[r'$\lambda$'])==v_lambda]
        selec_flux_idx = np.where(data[r'$\lambda$'] == v_lambda)
        selec_flux_max = max(data['Flux'][(selec_flux_idx[0][0])-10:(selec_flux_idx[0][0])+10]) + 70
        if (a==1) or (a==2):
            v_lambda = v_lambda- 100
        else:
            v_lambda = v_lambda - 30
        plt.text(v_lambda, selec_flux_max, f'{lines[ll[a]][1]}', 
                fontsize = 25,bbox = {'facecolor': '#F4F1BB', 'alpha': 0.5, 'boxstyle': "round,pad=0.3", 'ec': 'none'}, rotation = 0)
    plt.yticks(fontsize = 20)
    plt.xticks(fontsize = 20,rotation=90)
    plt.ylim(0,max(data['Flux'],)+15)
    plt.xlim(4000,7000)
    plt.grid(True, which="both", ls=":", color = 'gray', linewidth = 0.8)
    txt_prop = {'style' : 'oblique', 'family' : 'serif', 'size' :30}       
    plt.legend(title = f'{name[:-4]} \n Z = {Z} \n PLATEID = {plateid} \n MJD = {mjd} \n FIBERID = {fiberid}', prop = txt_prop, loc= 'upper right', title_fontsize=35)
    plt.savefig("/home/hollman/DataHII/HIIGalaxy_Spectra(Chavez2012)/Spectra_plots/" + (name.replace('.tex',"")) + ".png" ,
                bbox_inches='tight', transparent=False,dpi=150)
    #plt.show()
    plt.close('all')
    print('Done for '+ (name.replace('.tex',"")))
    gc.collect()
    del name, plateid, mjd, fiberid,z_finder,reduced_cat, Z, data
    
#spSpec-52339-0578-060.tex
#spec_plotter(spec_list[0])

# %%
for i in range(len(spec_list)):
    spec_plotter(spec_list[i])
# Out:
# Done for spSpec-52339-0578-060
# Done for spSpec-52937-1269-177
# Done for spSpec-53297-1781-055
# Done for spSpec-52962-1585-261
# Done for spSpec-53473-1695-627
# Done for spSpec-52353-0507-521
# Done for spSpec-53534-2112-557
# Done for spSpec-51929-0490-128
# Done for spSpec-54561-2708-193
# Done for spSpec-51821-0384-281
# Done for spSpec-53768-2372-508
# Done for spSpec-54628-2318-286
# Done for spSpec-51882-0442-156
# Done for spSpec-53386-1872-526
# Done for spSpec-52174-0637-523
# Done for spSpec-52224-0564-216
# Done for spSpec-52636-0999-517
# Done for spSpec-51957-0502-007
# Done for spSpec-53084-1758-338
# Done for spSpec-52413-0976-600
# Done for spSpec-52178-0640-267
# Done for spSpec-53463-1981-438
# Done for spSpec-52641-1003-327
# Done for spSpec-53768-2373-560
# Done for spSpec-52939-1582-335
# Done for spSpec-51816-0382-328
# Done for spSpec-53317-1921-281
# Done for spSpec-53142-1697-415
# Done for spSpec-52138-0652-090
# Done for spSpec-52238-0566-497
# Done for spSpec-53786-2356-172
# Done for spSpec-52174-0664-355
# Done for spSpec-53852-2483-254
# Done for spSpec-54521-2942-246
# Done for spSpec-51909-0455-073
# Done for spSpec-52992-1594-563
# Done for spSpec-51811-0381-370
# Done for spSpec-52263-0742-179
# Done for spSpec-53387-1935-204
# Done for spSpec-51909-0485-550
# Done for spSpec-51877-0447-361
# Done for spSpec-53815-2430-117
# Done for spSpec-51662-0284-277
# Done for spSpec-52146-0639-242
# Done for spSpec-53061-1745-463
# Done for spSpec-51877-0410-217
# Done for spSpec-51914-0488-439
# Done for spSpec-51929-0458-185
# Done for spSpec-52140-0375-118
# Done for spSpec-52145-0653-462
# Done for spSpec-51924-0459-253
# Done for spSpec-53815-2427-117
# Done for spSpec-52318-0861-489
# Done for spSpec-52263-0740-259
# Done for spSpec-54149-2689-190
# Done for spSpec-53115-1601-168
# Done for spSpec-53880-2208-306
# Done for spSpec-53708-2284-545
# Done for spSpec-51820-0429-495
