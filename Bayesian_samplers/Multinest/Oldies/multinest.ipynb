# %%
from __future__ import absolute_import, unicode_literals, print_function
import numpy
from numpy import pi, cos
from pymultinest.solve import solve
import os
try: os.mkdir('chains')
except OSError: pass

# %%
# probability function, taken from the eggbox problem.

def myprior(cube):
	return cube * 10 * pi

def myloglike(cube):
	chi = (cos(cube / 2.)).prod()
	return (2. + chi)**5

# number of dimensions our problem has
parameters = ["x", "y"]
n_params = len(parameters)
# name of the output files
prefix = "chains/3-"

# run MultiNest
result = solve(LogLikelihood=myloglike, Prior=myprior, 
	n_dims=n_params, outputfiles_basename=prefix, verbose=True)

print()
print('evidence: %(logZ).1f +- %(logZerr).1f' % result)
print()
print('parameter values:')
for name, col in zip(parameters, result['samples'].transpose()):
	print('%15s : %.3f +- %.3f' % (name, col.mean(), col.std()))

# make marginal plots by running:
# $ python multinest_marginals.py chains/3-
# For that, we need to store the parameter names:
import json
with open('%sparams.json' % prefix, 'w') as f:
	json.dump(parameters, f, indent=2)
# Out:
#  MultiNest Warning: no resume file found, starting from scratch
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    2
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.993377
# Replacements:                                450
# Total Samples:                               453
# Nested Sampling ln(Z):                  1.245072
# Importance Nested Sampling ln(Z):     231.900995 +/-  0.996633
# Acceptance Rate:                        0.970874
# Replacements:                                500
# Total Samples:                               515
# Nested Sampling ln(Z):                  6.334321
# Importance Nested Sampling ln(Z):     231.772991 +/-  0.996496
# Acceptance Rate:                        0.943396
# Replacements:                                550
# Total Samples:                               583
# Nested Sampling ln(Z):                 11.180380
# Importance Nested Sampling ln(Z):     231.650679 +/-  0.994908
# Acceptance Rate:                        0.896861
# Replacements:                                600
# Total Samples:                               669
# Nested Sampling ln(Z):                 17.490369
# Importance Nested Sampling ln(Z):     235.281110 +/-  0.878475
# Acceptance Rate:                        0.858653
# Replacements:                                650
# Total Samples:                               757
# Nested Sampling ln(Z):                 22.158915
# Importance Nested Sampling ln(Z):     235.173207 +/-  0.864976
# Acceptance Rate:                        0.817757
# Replacements:                                700
# Total Samples:                               856
# Nested Sampling ln(Z):                 27.808073
# Importance Nested Sampling ln(Z):     235.050300 +/-  0.865064
# Acceptance Rate:                        0.802998
# Replacements:                                750
# Total Samples:                               934
# Nested Sampling ln(Z):                 31.901889
# Importance Nested Sampling ln(Z):     235.048668 +/-  0.767054
# Acceptance Rate:                        0.793651
# Replacements:                                800
# Total Samples:                              1008
# Nested Sampling ln(Z):                 37.984343
# Importance Nested Sampling ln(Z):     234.912934 +/-  0.766039
# Acceptance Rate:                        0.798872
# Replacements:                                850
# Total Samples:                              1064
# Nested Sampling ln(Z):                 44.850439
# Importance Nested Sampling ln(Z):     234.795029 +/-  0.766058
# Acceptance Rate:                        0.796460
# Replacements:                                900
# Total Samples:                              1130
# Nested Sampling ln(Z):                 53.453498
# Importance Nested Sampling ln(Z):     234.662176 +/-  0.765923
# Acceptance Rate:                        0.789692
# Replacements:                                950
# Total Samples:                              1203
# Nested Sampling ln(Z):                 63.255651
# Importance Nested Sampling ln(Z):     234.921496 +/-  0.566172
# Acceptance Rate:                        0.790514
# Replacements:                               1000
# Total Samples:                              1265
# Nested Sampling ln(Z):                 75.242279
# Importance Nested Sampling ln(Z):     234.791352 +/-  0.564158
# Acceptance Rate:                        0.792453
# Replacements:                               1050
# Total Samples:                              1325
# Nested Sampling ln(Z):                 84.193607
# Importance Nested Sampling ln(Z):     235.882824 +/-  0.576012
# Acceptance Rate:                        0.787402
# Replacements:                               1100
# Total Samples:                              1397
# Nested Sampling ln(Z):                 95.548986
# Importance Nested Sampling ln(Z):     235.844980 +/-  0.522444
# Acceptance Rate:                        0.775978
# Replacements:                               1150
# Total Samples:                              1482
# Nested Sampling ln(Z):                105.068335
# Importance Nested Sampling ln(Z):     235.680111 +/-  0.519428
# Acceptance Rate:                        0.770713
# Replacements:                               1200
# Total Samples:                              1557
# Nested Sampling ln(Z):                114.743253
# Importance Nested Sampling ln(Z):     235.666198 +/-  0.473012
# Acceptance Rate:                        0.763592
# Replacements:                               1250
# Total Samples:                              1637
# Nested Sampling ln(Z):                127.727681
# Importance Nested Sampling ln(Z):     235.529683 +/-  0.468641
# Acceptance Rate:                        0.762016
# Replacements:                               1300
# Total Samples:                              1706
# Nested Sampling ln(Z):                136.624959
# Importance Nested Sampling ln(Z):     235.553408 +/-  0.425664
# Acceptance Rate:                        0.760135
# Replacements:                               1350
# Total Samples:                              1776
# Nested Sampling ln(Z):                144.441893
# Importance Nested Sampling ln(Z):     235.593601 +/-  0.378626
# Acceptance Rate:                        0.764192
# Replacements:                               1400
# Total Samples:                              1832
# Nested Sampling ln(Z):                152.923715
# Importance Nested Sampling ln(Z):     235.599287 +/-  0.349499
# Acceptance Rate:                        0.755602
# Replacements:                               1450
# Total Samples:                              1919
# Nested Sampling ln(Z):                161.328489
# Importance Nested Sampling ln(Z):     235.868511 +/-  0.288027
# Acceptance Rate:                        0.752634
# Replacements:                               1500
# Total Samples:                              1993
# Nested Sampling ln(Z):                167.397251
# Importance Nested Sampling ln(Z):     235.773412 +/-  0.285902
# Acceptance Rate:                        0.749879
# Replacements:                               1550
# Total Samples:                              2067
# Nested Sampling ln(Z):                173.896540
# Importance Nested Sampling ln(Z):     235.694671 +/-  0.282556
# Acceptance Rate:                        0.748713
# Replacements:                               1600
# Total Samples:                              2137
# Nested Sampling ln(Z):                181.938312
# Importance Nested Sampling ln(Z):     235.663817 +/-  0.272621
# Acceptance Rate:                        0.747621
# Replacements:                               1650
# Total Samples:                              2207
# Nested Sampling ln(Z):                187.155760
# Importance Nested Sampling ln(Z):     235.715500 +/-  0.261848
# Acceptance Rate:                        0.737527
# Replacements:                               1700
# Total Samples:                              2305
# Nested Sampling ln(Z):                192.428746
# Importance Nested Sampling ln(Z):     235.866251 +/-  0.242224
# Acceptance Rate:                        0.729775
# Replacements:                               1750
# Total Samples:                              2398
# Nested Sampling ln(Z):                196.902626
# Importance Nested Sampling ln(Z):     235.877919 +/-  0.222448
# Acceptance Rate:                        0.725806
# Replacements:                               1800
# Total Samples:                              2480
# Nested Sampling ln(Z):                201.058946
# Importance Nested Sampling ln(Z):     235.803057 +/-  0.221442
# Acceptance Rate:                        0.724922
# Replacements:                               1850
# Total Samples:                              2552
# Nested Sampling ln(Z):                205.501918
# Importance Nested Sampling ln(Z):     235.741273 +/-  0.220884
# Acceptance Rate:                        0.721336
# Replacements:                               1900
# Total Samples:                              2634
# Nested Sampling ln(Z):                209.098097
# Importance Nested Sampling ln(Z):     235.728410 +/-  0.213774
# Acceptance Rate:                        0.716122
# Replacements:                               1950
# Total Samples:                              2723
# Nested Sampling ln(Z):                211.811704
# Importance Nested Sampling ln(Z):     235.753404 +/-  0.207397
# Acceptance Rate:                        0.713012
# Replacements:                               2000
# Total Samples:                              2805
# Nested Sampling ln(Z):                214.695834
# Importance Nested Sampling ln(Z):     235.803766 +/-  0.194482
# Acceptance Rate:                        0.711558
# Replacements:                               2050
# Total Samples:                              2881
# Nested Sampling ln(Z):                217.084988
# Importance Nested Sampling ln(Z):     235.843054 +/-  0.185917
# Acceptance Rate:                        0.707071
# Replacements:                               2100
# Total Samples:                              2970
# Nested Sampling ln(Z):                218.947041
# Importance Nested Sampling ln(Z):     235.772227 +/-  0.188271
# Acceptance Rate:                        0.705612
# Replacements:                               2150
# Total Samples:                              3047
# Nested Sampling ln(Z):                221.153199
# Importance Nested Sampling ln(Z):     235.736997 +/-  0.188793
# Acceptance Rate:                        0.703100
# Replacements:                               2200
# Total Samples:                              3129
# Nested Sampling ln(Z):                222.920494
# Importance Nested Sampling ln(Z):     235.710217 +/-  0.186985
# Acceptance Rate:                        0.699627
# Replacements:                               2250
# Total Samples:                              3216
# Nested Sampling ln(Z):                224.366819
# Importance Nested Sampling ln(Z):     235.707719 +/-  0.182908
# Acceptance Rate:                        0.699726
# Replacements:                               2300
# Total Samples:                              3287
# Nested Sampling ln(Z):                225.607732
# Importance Nested Sampling ln(Z):     235.736951 +/-  0.175807
# Acceptance Rate:                        0.697329
# Replacements:                               2350
# Total Samples:                              3370
# Nested Sampling ln(Z):                226.708752
# Importance Nested Sampling ln(Z):     235.746337 +/-  0.171519
# Acceptance Rate:                        0.695451
# Replacements:                               2400
# Total Samples:                              3451
# Nested Sampling ln(Z):                227.786997
# Importance Nested Sampling ln(Z):     235.782636 +/-  0.164127
# Acceptance Rate:                        0.695627
# Replacements:                               2450
# Total Samples:                              3522
# Nested Sampling ln(Z):                228.627334
# Importance Nested Sampling ln(Z):     235.790107 +/-  0.160958
# Acceptance Rate:                        0.692329
# Replacements:                               2500
# Total Samples:                              3611
# Nested Sampling ln(Z):                229.472411
# Importance Nested Sampling ln(Z):     235.794201 +/-  0.158592
# Acceptance Rate:                        0.688073
# Replacements:                               2550
# Total Samples:                              3706
# Nested Sampling ln(Z):                230.208581
# Importance Nested Sampling ln(Z):     235.811961 +/-  0.154187
# Acceptance Rate:                        0.687104
# Replacements:                               2600
# Total Samples:                              3784
# Nested Sampling ln(Z):                230.863985
# Importance Nested Sampling ln(Z):     235.851681 +/-  0.147683
# Acceptance Rate:                        0.684578
# Replacements:                               2650
# Total Samples:                              3871
# Nested Sampling ln(Z):                231.421806
# Importance Nested Sampling ln(Z):     235.836108 +/-  0.148513
# Acceptance Rate:                        0.681990
# Replacements:                               2700
# Total Samples:                              3959
# Nested Sampling ln(Z):                231.934841
# Importance Nested Sampling ln(Z):     235.847495 +/-  0.145571
# Acceptance Rate:                        0.681537
# Replacements:                               2750
# Total Samples:                              4035
# Nested Sampling ln(Z):                232.405560
# Importance Nested Sampling ln(Z):     235.842128 +/-  0.145211
# Acceptance Rate:                        0.679942
# Replacements:                               2800
# Total Samples:                              4118
# Nested Sampling ln(Z):                232.806170
# Importance Nested Sampling ln(Z):     235.841267 +/-  0.144380
# Acceptance Rate:                        0.677281
# Replacements:                               2850
# Total Samples:                              4208
# Nested Sampling ln(Z):                233.167115
# Importance Nested Sampling ln(Z):     235.844682 +/-  0.143095
# Acceptance Rate:                        0.675518
# Replacements:                               2900
# Total Samples:                              4293
# Nested Sampling ln(Z):                233.487992
# Importance Nested Sampling ln(Z):     235.838091 +/-  0.143265
# Acceptance Rate:                        0.675676
# Replacements:                               2950
# Total Samples:                              4366
# Nested Sampling ln(Z):                233.761886
# Importance Nested Sampling ln(Z):     235.853900 +/-  0.140647
# Acceptance Rate:                        0.674006
# Replacements:                               3000
# Total Samples:                              4451
# Nested Sampling ln(Z):                234.001948
# Importance Nested Sampling ln(Z):     235.859178 +/-  0.139397
# Acceptance Rate:                        0.672992
# Replacements:                               3050
# Total Samples:                              4532
# Nested Sampling ln(Z):                234.209771
# Importance Nested Sampling ln(Z):     235.875883 +/-  0.136801
# Acceptance Rate:                        0.671286
# Replacements:                               3100
# Total Samples:                              4618
# Nested Sampling ln(Z):                234.389502
# Importance Nested Sampling ln(Z):     235.878657 +/-  0.136005
# Acceptance Rate:                        0.670641
# Replacements:                               3150
# Total Samples:                              4697
# Nested Sampling ln(Z):                234.548657
# Importance Nested Sampling ln(Z):     235.891324 +/-  0.134039
# Acceptance Rate:                        0.669596
# Replacements:                               3200
# Total Samples:                              4779
# Nested Sampling ln(Z):                234.693998
# Importance Nested Sampling ln(Z):     235.907640 +/-  0.131682
# Acceptance Rate:                        0.668587
# Replacements:                               3250
# Total Samples:                              4861
# Nested Sampling ln(Z):                234.822984
# Importance Nested Sampling ln(Z):     235.928993 +/-  0.128765
# Acceptance Rate:                        0.668422
# Replacements:                               3300
# Total Samples:                              4937
# Nested Sampling ln(Z):                234.936188
# Importance Nested Sampling ln(Z):     235.945508 +/-  0.126525
# Acceptance Rate:                        0.668930
# Replacements:                               3350
# Total Samples:                              5008
# Nested Sampling ln(Z):                235.036117
# Importance Nested Sampling ln(Z):     235.958893 +/-  0.124728
# Acceptance Rate:                        0.667190
# Replacements:                               3400
# Total Samples:                              5096
# Nested Sampling ln(Z):                235.126291
# Importance Nested Sampling ln(Z):     235.969616 +/-  0.123262
# Acceptance Rate:                        0.666796
# Replacements:                               3450
# Total Samples:                              5174
# Nested Sampling ln(Z):                235.208326
# Importance Nested Sampling ln(Z):     235.981705 +/-  0.121693
# Acceptance Rate:                        0.666032
# Replacements:                               3500
# Total Samples:                              5255
# Nested Sampling ln(Z):                235.281471
# Importance Nested Sampling ln(Z):     235.989799 +/-  0.120611
# Acceptance Rate:                        0.667042
# Replacements:                               3550
# Total Samples:                              5322
# Nested Sampling ln(Z):                235.346108
# Importance Nested Sampling ln(Z):     235.995667 +/-  0.119832
# Acceptance Rate:                        0.666543
# Replacements:                               3600
# Total Samples:                              5401
# Nested Sampling ln(Z):                235.403287
# Importance Nested Sampling ln(Z):     236.001936 +/-  0.119015
# Acceptance Rate:                        0.665937
# Replacements:                               3650
# Total Samples:                              5481
# Nested Sampling ln(Z):                235.454190
# Importance Nested Sampling ln(Z):     236.006147 +/-  0.118454
# Acceptance Rate:                        0.664563
# Replacements:                               3685
# Total Samples:                              5545
# Nested Sampling ln(Z):                235.486343
# Importance Nested Sampling ln(Z):     236.007381 +/-  0.118265
#  ln(ev)=   235.83908639971079      +/-  0.12374597521592390
#   analysing data from chains/3-.txt
#  Total Likelihood Evaluations:         5545
#  Sampling finished. Exiting MultiNest
#
# evidence: 235.8 +- 0.1
#
# parameter values:
#               x : 16.160 +- 8.578
#               y : 15.301 +- 8.624

# %%
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples

samples = result["samples"]     # (Nsamples, 2)
names   = ["x","y"]             # nombres internos
labels  = ["x","y"]             # << SIN $...$ >>

gds = MCSamples(samples=samples, names=names, labels=labels)

g = plots.getSubplotPlotter()
g.triangle_plot([gds], filled=True)  # sin params => usa ambos
plt.savefig("chains/3-triangle-getdist.png", dpi=150, bbox_inches="tight")
print("Guardado: chains/3-triangle-getdist.png")
# Out:
# WARNING:root:auto bandwidth for x very small or failed (h=0.0013360147904114095,N_eff=195.46958585427342). Using fallback (h=0.055005914917091774)
# WARNING:root:auto bandwidth for y very small or failed (h=0.0014595809396721615,N_eff=172.88472363048615). Using fallback (h=0.056879562483389705)
# Removed no burn in
# WARNING:root:fine_bins_2D not large enough for optimal density: x, y
# Guardado: chains/3-triangle-getdist.png

# %% [markdown]
# ## Implementacion para HIIGs (3 primeros parámetros)
#
# ## $$\alpha , \beta , H_0 $$

# %%
from __future__ import annotations
import os
import json
import numpy as np
from astropy.table import Table
from astropy.cosmology import FlatwCDM

import pymultinest
import matplotlib.pyplot as plt
import corner
from getdist import plots, MCSamples
import scipy.optimize as op

# %%
def lnlike(theta, x, y, z, xerr, yerr, zerr):
    alpha, beta, h0 = theta
    Om = 0.3
    w0 = -1.0
    cosmo = FlatwCDM(H0=h0*100, Om0=Om, w0=w0)

    ixG = np.where(z > 10)
    ixH = np.where(z < 10)

    Mum = z*0.0
    MumErr = z*0.0

    Mum[ixG] = z[ixG]
    MumErr[ixG] = zerr[ixG]
    Mum[ixH] = 5.0*np.log10(cosmo.luminosity_distance(z[ixH]).value) + 25.0
    MumErr[ixH] = (5.0/np.log(10.0))*(zerr[ixH]/z[ixH])

    Mu = 2.5*(beta*x + alpha) - 2.5*y - 100.195
    MuErr = 2.5*np.sqrt((yerr)**2 + beta**2*(xerr)**2)

    R = (Mu - Mum)
    W = 1.0/(MuErr**2 + MumErr**2)

    xsq = np.sum(R**2 * W)
    llq = -0.5*xsq
    return llq

# %%
def load_data(dpath):
    Tpath = os.path.join(dpath, 'indat/Union2020v16.dat')
    data = Table.read(Tpath, format='ascii', comment='#')

    vix  = np.asarray(data['col1'])
    vx   = np.asarray(data['col2'])
    vy   = np.asarray(data['col3'])
    vz   = np.asarray(data['col4'])
    vxEr = np.asarray(data['col5'])
    vyEr = np.asarray(data['col6'])
    vzEr = np.asarray(data['col7'])
    vsp  = np.asarray(data['col8'])


    return vix, vx, vy, vz, vxEr, vyEr, vzEr, vsp

# %%
def prior_transform(u):
    alpha = 20.0 + 20.0 * u[0]     # 20->40
    beta  =  0.0 + 10.0 * u[1]     # 0->10
    h0    =  0.5 +  0.5 * u[2]     # 0.5->1.0
    return np.array([alpha, beta, h0])

# %%
HOME = os.path.expanduser("~") + '/HIIGs/'
dpath = os.path.join(HOME, "MCMC/ZEUS/h0wsh2023/dat/")

dpath = '/home/holman//MCMC/ZEUS/h0wsh2023/dat/'
print("Data path:", dpath)

vTg, vx, vy, vz, vxErr, vyErr, vzErr, vsp = load_data(dpath)
# Out:
# Data path: /home/holman//MCMC/ZEUS/h0wsh2023/dat/

# %%
def nll(theta):
    return -lnlike(theta, vx, vy, vz, vxErr, vyErr, vzErr)

res = op.minimize(nll, x0=[32.0, 5.0, 0.75], method="Nelder-Mead")
print("ML guess:", res.x)
# Out:
# ML guess: [33.48268798  4.82632196  0.77453062]

# %%
outdir = os.path.join(dpath, "results_mnest")
os.makedirs(outdir, exist_ok=True)
prefix = os.path.join(outdir, "hii_")

def loglike_for_mnest(theta):
    return lnlike(theta, vx, vy, vz, vxErr, vyErr, vzErr)

# %%
n_dims = 3
result = pymultinest.solve(
    LogLikelihood=loglike_for_mnest,
    Prior=prior_transform,
    n_dims=n_dims,
    outputfiles_basename=prefix,
    evidence_tolerance=0.5,
    n_live_points=600,
    multimodal=True,
    verbose=True
)
# Out:
#  MultiNest Warning: no resume file found, starting from scratch
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  600
#  dimensionality =    3
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        1.000000
# Replacements:                                650
# Total Samples:                               650
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):    -544.418655 +/-  0.999230
# Acceptance Rate:                        0.992908
# Replacements:                                700
# Total Samples:                               705
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):    -544.499881 +/-  0.999291
# Acceptance Rate:                        0.979112
# Replacements:                                750
# Total Samples:                               766
# Nested Sampling ln(Z):            -608739.829251
# Importance Nested Sampling ln(Z):    -498.908727 +/-  0.999347
# Acceptance Rate:                        0.953516
# Replacements:                                800
# Total Samples:                               839
# Nested Sampling ln(Z):            -389856.296517
# Importance Nested Sampling ln(Z):    -498.999755 +/-  0.999404
# Acceptance Rate:                        0.934066
# Replacements:                                850
# Total Samples:                               910
# Nested Sampling ln(Z):            -267465.262833
# Importance Nested Sampling ln(Z):    -499.080989 +/-  0.999450
# Acceptance Rate:                        0.911854
# Replacements:                                900
# Total Samples:                               987
# Nested Sampling ln(Z):            -203607.362871
# Importance Nested Sampling ln(Z):    -499.162215 +/-  0.999493
# Acceptance Rate:                        0.893697
# Replacements:                                950
# Total Samples:                              1063
# Nested Sampling ln(Z):            -158891.514083
# Importance Nested Sampling ln(Z):    -499.236395 +/-  0.999530
# Acceptance Rate:                        0.866551
# Replacements:                               1000
# Total Samples:                              1154
# Nested Sampling ln(Z):            -125618.082575
# Importance Nested Sampling ln(Z):    -448.578898 +/-  0.999567
# Acceptance Rate:                        0.836653
# Replacements:                               1050
# Total Samples:                              1255
# Nested Sampling ln(Z):            -107974.437508
# Importance Nested Sampling ln(Z):    -448.689899 +/-  0.999602
# Acceptance Rate:                        0.823353
# Replacements:                               1100
# Total Samples:                              1336
# Nested Sampling ln(Z):             -92907.625713
# Importance Nested Sampling ln(Z):    -448.830180 +/-  0.999626
# Acceptance Rate:                        0.810430
# Replacements:                               1150
# Total Samples:                              1419
# Nested Sampling ln(Z):             -77048.177333
# Importance Nested Sampling ln(Z):    -448.950193 +/-  0.999648
# Acceptance Rate:                        0.800000
# Replacements:                               1200
# Total Samples:                              1500
# Nested Sampling ln(Z):             -63050.652488
# Importance Nested Sampling ln(Z):    -449.065961 +/-  0.999667
# Acceptance Rate:                        0.793651
# Replacements:                               1250
# Total Samples:                              1575
# Nested Sampling ln(Z):             -54652.831419
# Importance Nested Sampling ln(Z):    -449.171397 +/-  0.999682
# Acceptance Rate:                        0.785498
# Replacements:                               1300
# Total Samples:                              1655
# Nested Sampling ln(Z):             -46962.575031
# Importance Nested Sampling ln(Z):    -449.281864 +/-  0.999698
# Acceptance Rate:                        0.778996
# Replacements:                               1350
# Total Samples:                              1733
# Nested Sampling ln(Z):             -41773.792854
# Importance Nested Sampling ln(Z):    -449.371997 +/-  0.999711
# Acceptance Rate:                        0.775194
# Replacements:                               1400
# Total Samples:                              1806
# Nested Sampling ln(Z):             -35869.100979
# Importance Nested Sampling ln(Z):    -449.468353 +/-  0.999723
# Acceptance Rate:                        0.770867
# Replacements:                               1450
# Total Samples:                              1881
# Nested Sampling ln(Z):             -29356.187146
# Importance Nested Sampling ln(Z):    -449.569194 +/-  0.999734
# Acceptance Rate:                        0.761808
# Replacements:                               1500
# Total Samples:                              1969
# Nested Sampling ln(Z):             -25371.692939
# Importance Nested Sampling ln(Z):    -449.673517 +/-  0.999746
# Acceptance Rate:                        0.759432
# Replacements:                               1550
# Total Samples:                              2041
# Nested Sampling ln(Z):             -21335.739313
# Importance Nested Sampling ln(Z):    -449.771132 +/-  0.999755
# Acceptance Rate:                        0.757217
# Replacements:                               1600
# Total Samples:                              2113
# Nested Sampling ln(Z):             -18923.075236
# Importance Nested Sampling ln(Z):    -449.865195 +/-  0.999763
# Acceptance Rate:                        0.744921
# Replacements:                               1650
# Total Samples:                              2215
# Nested Sampling ln(Z):             -16183.830530
# Importance Nested Sampling ln(Z):    -449.989450 +/-  0.999774
# Acceptance Rate:                        0.738168
# Replacements:                               1700
# Total Samples:                              2303
# Nested Sampling ln(Z):             -13935.087741
# Importance Nested Sampling ln(Z):    -450.085602 +/-  0.999783
# Acceptance Rate:                        0.730384
# Replacements:                               1750
# Total Samples:                              2396
# Nested Sampling ln(Z):             -11969.120700
# Importance Nested Sampling ln(Z):    -450.175225 +/-  0.999791
# Acceptance Rate:                        0.724930
# Replacements:                               1800
# Total Samples:                              2483
# Nested Sampling ln(Z):             -10332.720684
# Importance Nested Sampling ln(Z):    -450.254617 +/-  0.999799
# Acceptance Rate:                        0.719005
# Replacements:                               1850
# Total Samples:                              2573
# Nested Sampling ln(Z):              -8958.186620
# Importance Nested Sampling ln(Z):    -450.334767 +/-  0.999806
# Acceptance Rate:                        0.709485
# Replacements:                               1900
# Total Samples:                              2678
# Nested Sampling ln(Z):              -7824.787092
# Importance Nested Sampling ln(Z):    -450.421178 +/-  0.999813
# Acceptance Rate:                        0.708318
# Replacements:                               1950
# Total Samples:                              2753
# Nested Sampling ln(Z):              -6784.617752
# Importance Nested Sampling ln(Z):    -450.518854 +/-  0.999818
# Acceptance Rate:                        0.708717
# Replacements:                               2000
# Total Samples:                              2822
# Nested Sampling ln(Z):              -6052.853785
# Importance Nested Sampling ln(Z):    -450.598838 +/-  0.999823
# Acceptance Rate:                        0.709097
# Replacements:                               2050
# Total Samples:                              2891
# Nested Sampling ln(Z):              -5255.210158
# Importance Nested Sampling ln(Z):    -444.380111 +/-  0.997990
# Acceptance Rate:                        0.708263
# Replacements:                               2100
# Total Samples:                              2965
# Nested Sampling ln(Z):              -4707.698624
# Importance Nested Sampling ln(Z):    -444.457782 +/-  0.997964
# Acceptance Rate:                        0.705381
# Replacements:                               2150
# Total Samples:                              3048
# Nested Sampling ln(Z):              -4261.725395
# Importance Nested Sampling ln(Z):    -444.549291 +/-  0.997968
# Acceptance Rate:                        0.698634
# Replacements:                               2200
# Total Samples:                              3149
# Nested Sampling ln(Z):              -3948.357179
# Importance Nested Sampling ln(Z):    -444.650894 +/-  0.997973
# Acceptance Rate:                        0.698758
# Replacements:                               2250
# Total Samples:                              3220
# Nested Sampling ln(Z):              -3672.674508
# Importance Nested Sampling ln(Z):    -444.741087 +/-  0.997977
# Acceptance Rate:                        0.698876
# Replacements:                               2300
# Total Samples:                              3291
# Nested Sampling ln(Z):              -3439.176788
# Importance Nested Sampling ln(Z):    -444.830830 +/-  0.997980
# Acceptance Rate:                        0.697743
# Replacements:                               2350
# Total Samples:                              3368
# Nested Sampling ln(Z):              -3196.455094
# Importance Nested Sampling ln(Z):    -444.908130 +/-  0.997073
# Acceptance Rate:                        0.699301
# Replacements:                               2400
# Total Samples:                              3432
# Nested Sampling ln(Z):              -3039.973817
# Importance Nested Sampling ln(Z):    -444.974206 +/-  0.997076
# Acceptance Rate:                        0.699201
# Replacements:                               2450
# Total Samples:                              3504
# Nested Sampling ln(Z):              -2862.716312
# Importance Nested Sampling ln(Z):    -445.052554 +/-  0.997079
# Acceptance Rate:                        0.700280
# Replacements:                               2500
# Total Samples:                              3570
# Nested Sampling ln(Z):              -2655.923764
# Importance Nested Sampling ln(Z):    -445.132883 +/-  0.997082
# Acceptance Rate:                        0.697102
# Replacements:                               2550
# Total Samples:                              3658
# Nested Sampling ln(Z):              -2506.116604
# Importance Nested Sampling ln(Z):    -445.222529 +/-  0.997085
# Acceptance Rate:                        0.697425
# Replacements:                               2600
# Total Samples:                              3728
# Nested Sampling ln(Z):              -2314.539067
# Importance Nested Sampling ln(Z):    -445.292612 +/-  0.997088
# Acceptance Rate:                        0.697185
# Replacements:                               2650
# Total Samples:                              3801
# Nested Sampling ln(Z):              -2172.412943
# Importance Nested Sampling ln(Z):    -445.371111 +/-  0.997090
# Acceptance Rate:                        0.694981
# Replacements:                               2700
# Total Samples:                              3885
# Nested Sampling ln(Z):              -2073.286602
# Importance Nested Sampling ln(Z):    -445.458601 +/-  0.997093
# Acceptance Rate:                        0.694094
# Replacements:                               2750
# Total Samples:                              3962
# Nested Sampling ln(Z):              -1967.755491
# Importance Nested Sampling ln(Z):    -445.534240 +/-  0.997096
# Acceptance Rate:                        0.691871
# Replacements:                               2800
# Total Samples:                              4047
# Nested Sampling ln(Z):              -1868.238481
# Importance Nested Sampling ln(Z):    -445.615097 +/-  0.997098
# Acceptance Rate:                        0.689739
# Replacements:                               2850
# Total Samples:                              4132
# Nested Sampling ln(Z):              -1763.813532
# Importance Nested Sampling ln(Z):    -445.709782 +/-  0.997101
# Acceptance Rate:                        0.690312
# Replacements:                               2900
# Total Samples:                              4201
# Nested Sampling ln(Z):              -1655.576357
# Importance Nested Sampling ln(Z):    -445.785296 +/-  0.997103
# Acceptance Rate:                        0.688770
# Replacements:                               2950
# Total Samples:                              4283
# Nested Sampling ln(Z):              -1574.442642
# Importance Nested Sampling ln(Z):    -445.870214 +/-  0.997105
# Acceptance Rate:                        0.688389
# Replacements:                               3000
# Total Samples:                              4358
# Nested Sampling ln(Z):              -1510.180652
# Importance Nested Sampling ln(Z):    -445.943022 +/-  0.997107
# Acceptance Rate:                        0.687401
# Replacements:                               3050
# Total Samples:                              4437
# Nested Sampling ln(Z):              -1438.748452
# Importance Nested Sampling ln(Z):    -446.024734 +/-  0.997109
# Acceptance Rate:                        0.684780
# Replacements:                               3100
# Total Samples:                              4527
# Nested Sampling ln(Z):              -1391.922995
# Importance Nested Sampling ln(Z):    -446.119146 +/-  0.997111
# Acceptance Rate:                        0.682113
# Replacements:                               3150
# Total Samples:                              4618
# Nested Sampling ln(Z):              -1318.304075
# Importance Nested Sampling ln(Z):    -446.192791 +/-  0.989004
# Acceptance Rate:                        0.682303
# Replacements:                               3200
# Total Samples:                              4690
# Nested Sampling ln(Z):              -1252.257571
# Importance Nested Sampling ln(Z):    -446.258047 +/-  0.989006
# Acceptance Rate:                        0.680059
# Replacements:                               3250
# Total Samples:                              4779
# Nested Sampling ln(Z):              -1189.786892
# Importance Nested Sampling ln(Z):    -446.336550 +/-  0.980090
# Acceptance Rate:                        0.678175
# Replacements:                               3300
# Total Samples:                              4866
# Nested Sampling ln(Z):              -1132.335648
# Importance Nested Sampling ln(Z):    -446.416460 +/-  0.975754
# Acceptance Rate:                        0.677863
# Replacements:                               3350
# Total Samples:                              4942
# Nested Sampling ln(Z):              -1084.136655
# Importance Nested Sampling ln(Z):    -446.485704 +/-  0.975755
# Acceptance Rate:                        0.677561
# Replacements:                               3400
# Total Samples:                              5018
# Nested Sampling ln(Z):              -1028.970429
# Importance Nested Sampling ln(Z):    -446.556918 +/-  0.975757
# Acceptance Rate:                        0.676869
# Replacements:                               3450
# Total Samples:                              5097
# Nested Sampling ln(Z):               -992.651395
# Importance Nested Sampling ln(Z):    -446.629421 +/-  0.975472
# Acceptance Rate:                        0.676067
# Replacements:                               3500
# Total Samples:                              5177
# Nested Sampling ln(Z):               -956.196480
# Importance Nested Sampling ln(Z):    -446.712517 +/-  0.975469
# Acceptance Rate:                        0.675419
# Replacements:                               3550
# Total Samples:                              5256
# Nested Sampling ln(Z):               -911.880348
# Importance Nested Sampling ln(Z):    -446.791194 +/-  0.974872
# Acceptance Rate:                        0.674789
# Replacements:                               3600
# Total Samples:                              5335
# Nested Sampling ln(Z):               -876.309887
# Importance Nested Sampling ln(Z):    -446.858554 +/-  0.974874
# Acceptance Rate:                        0.674427
# Replacements:                               3650
# Total Samples:                              5412
# Nested Sampling ln(Z):               -846.445016
# Importance Nested Sampling ln(Z):    -446.887056 +/-  0.937701
# Acceptance Rate:                        0.673830
# Replacements:                               3700
# Total Samples:                              5491
# Nested Sampling ln(Z):               -822.855585
# Importance Nested Sampling ln(Z):    -446.969140 +/-  0.937704
# Acceptance Rate:                        0.670481
# Replacements:                               3750
# Total Samples:                              5593
# Nested Sampling ln(Z):               -791.858482
# Importance Nested Sampling ln(Z):    -447.057202 +/-  0.937494
# Acceptance Rate:                        0.668308
# Replacements:                               3800
# Total Samples:                              5686
# Nested Sampling ln(Z):               -762.457644
# Importance Nested Sampling ln(Z):    -447.142808 +/-  0.937497
# Acceptance Rate:                        0.667823
# Replacements:                               3850
# Total Samples:                              5765
# Nested Sampling ln(Z):               -739.057627
# Importance Nested Sampling ln(Z):    -447.214712 +/-  0.937488
# Acceptance Rate:                        0.666097
# Replacements:                               3900
# Total Samples:                              5855
# Nested Sampling ln(Z):               -716.679329
# Importance Nested Sampling ln(Z):    -447.299796 +/-  0.937479
# Acceptance Rate:                        0.665095
# Replacements:                               3950
# Total Samples:                              5939
# Nested Sampling ln(Z):               -700.320894
# Importance Nested Sampling ln(Z):    -447.379489 +/-  0.937480
# Acceptance Rate:                        0.664452
# Replacements:                               4000
# Total Samples:                              6020
# Nested Sampling ln(Z):               -679.860957
# Importance Nested Sampling ln(Z):    -447.456380 +/-  0.935016
# Acceptance Rate:                        0.664588
# Replacements:                               4050
# Total Samples:                              6094
# Nested Sampling ln(Z):               -663.353101
# Importance Nested Sampling ln(Z):    -447.532919 +/-  0.934947
# Acceptance Rate:                        0.663753
# Replacements:                               4100
# Total Samples:                              6177
# Nested Sampling ln(Z):               -646.434720
# Importance Nested Sampling ln(Z):    -446.928478 +/-  0.679973
# Acceptance Rate:                        0.660302
# Replacements:                               4150
# Total Samples:                              6285
# Nested Sampling ln(Z):               -631.723333
# Importance Nested Sampling ln(Z):    -447.019176 +/-  0.676215
# Acceptance Rate:                        0.659237
# Replacements:                               4200
# Total Samples:                              6371
# Nested Sampling ln(Z):               -616.923009
# Importance Nested Sampling ln(Z):    -447.096382 +/-  0.676214
# Acceptance Rate:                        0.658302
# Replacements:                               4250
# Total Samples:                              6456
# Nested Sampling ln(Z):               -601.897102
# Importance Nested Sampling ln(Z):    -447.169796 +/-  0.676213
# Acceptance Rate:                        0.657693
# Replacements:                               4300
# Total Samples:                              6538
# Nested Sampling ln(Z):               -591.159256
# Importance Nested Sampling ln(Z):    -447.221558 +/-  0.666737
# Acceptance Rate:                        0.657100
# Replacements:                               4350
# Total Samples:                              6620
# Nested Sampling ln(Z):               -582.619907
# Importance Nested Sampling ln(Z):    -447.241299 +/-  0.636223
# Acceptance Rate:                        0.654957
# Replacements:                               4400
# Total Samples:                              6718
# Nested Sampling ln(Z):               -573.970256
# Importance Nested Sampling ln(Z):    -447.119349 +/-  0.543033
# Acceptance Rate:                        0.652301
# Replacements:                               4450
# Total Samples:                              6822
# Nested Sampling ln(Z):               -563.824434
# Importance Nested Sampling ln(Z):    -447.198239 +/-  0.543034
# Acceptance Rate:                        0.649819
# Replacements:                               4500
# Total Samples:                              6925
# Nested Sampling ln(Z):               -555.057879
# Importance Nested Sampling ln(Z):    -447.272134 +/-  0.542996
# Acceptance Rate:                        0.648610
# Replacements:                               4550
# Total Samples:                              7015
# Nested Sampling ln(Z):               -548.022753
# Importance Nested Sampling ln(Z):    -447.109935 +/-  0.474788
# Acceptance Rate:                        0.646885
# Replacements:                               4600
# Total Samples:                              7111
# Nested Sampling ln(Z):               -541.154225
# Importance Nested Sampling ln(Z):    -447.201638 +/-  0.474744
# Acceptance Rate:                        0.646552
# Replacements:                               4650
# Total Samples:                              7192
# Nested Sampling ln(Z):               -532.617657
# Importance Nested Sampling ln(Z):    -447.255063 +/-  0.466082
# Acceptance Rate:                        0.646404
# Replacements:                               4700
# Total Samples:                              7271
# Nested Sampling ln(Z):               -524.888211
# Importance Nested Sampling ln(Z):    -447.322913 +/-  0.462730
# Acceptance Rate:                        0.645819
# Replacements:                               4750
# Total Samples:                              7355
# Nested Sampling ln(Z):               -518.902244
# Importance Nested Sampling ln(Z):    -447.389075 +/-  0.458366
# Acceptance Rate:                        0.644815
# Replacements:                               4800
# Total Samples:                              7444
# Nested Sampling ln(Z):               -512.846327
# Importance Nested Sampling ln(Z):    -447.444140 +/-  0.448140
# Acceptance Rate:                        0.643834
# Replacements:                               4850
# Total Samples:                              7533
# Nested Sampling ln(Z):               -508.506079
# Importance Nested Sampling ln(Z):    -447.450545 +/-  0.419468
# Acceptance Rate:                        0.643129
# Replacements:                               4900
# Total Samples:                              7619
# Nested Sampling ln(Z):               -503.821098
# Importance Nested Sampling ln(Z):    -447.542041 +/-  0.418801
# Acceptance Rate:                        0.642023
# Replacements:                               4950
# Total Samples:                              7710
# Nested Sampling ln(Z):               -500.186745
# Importance Nested Sampling ln(Z):    -447.621428 +/-  0.416450
# Acceptance Rate:                        0.640287
# Replacements:                               5000
# Total Samples:                              7809
# Nested Sampling ln(Z):               -496.974266
# Importance Nested Sampling ln(Z):    -447.674291 +/-  0.403791
# Acceptance Rate:                        0.639970
# Replacements:                               5050
# Total Samples:                              7891
# Nested Sampling ln(Z):               -494.017138
# Importance Nested Sampling ln(Z):    -447.587354 +/-  0.361924
# Acceptance Rate:                        0.639338
# Replacements:                               5100
# Total Samples:                              7977
# Nested Sampling ln(Z):               -490.755333
# Importance Nested Sampling ln(Z):    -447.432875 +/-  0.347300
# Acceptance Rate:                        0.639672
# Replacements:                               5150
# Total Samples:                              8051
# Nested Sampling ln(Z):               -488.264788
# Importance Nested Sampling ln(Z):    -447.368976 +/-  0.313478
# Acceptance Rate:                        0.638350
# Replacements:                               5200
# Total Samples:                              8146
# Nested Sampling ln(Z):               -485.837062
# Importance Nested Sampling ln(Z):    -447.401549 +/-  0.296814
# Acceptance Rate:                        0.637213
# Replacements:                               5250
# Total Samples:                              8239
# Nested Sampling ln(Z):               -482.857550
# Importance Nested Sampling ln(Z):    -447.487943 +/-  0.294588
# Acceptance Rate:                        0.638247
# Replacements:                               5300
# Total Samples:                              8304
# Nested Sampling ln(Z):               -480.582828
# Importance Nested Sampling ln(Z):    -447.459482 +/-  0.275251
# Acceptance Rate:                        0.637740
# Replacements:                               5350
# Total Samples:                              8389
# Nested Sampling ln(Z):               -478.563111
# Importance Nested Sampling ln(Z):    -447.443625 +/-  0.258017
# Acceptance Rate:                        0.638222
# Replacements:                               5400
# Total Samples:                              8461
# Nested Sampling ln(Z):               -476.940174
# Importance Nested Sampling ln(Z):    -447.490582 +/-  0.251993
# Acceptance Rate:                        0.638024
# Replacements:                               5450
# Total Samples:                              8542
# Nested Sampling ln(Z):               -475.348932
# Importance Nested Sampling ln(Z):    -447.474617 +/-  0.237708
# Acceptance Rate:                        0.638125
# Replacements:                               5500
# Total Samples:                              8619
# Nested Sampling ln(Z):               -473.373158
# Importance Nested Sampling ln(Z):    -447.487720 +/-  0.226076
# Acceptance Rate:                        0.637711
# Replacements:                               5550
# Total Samples:                              8703
# Nested Sampling ln(Z):               -471.654042
# Importance Nested Sampling ln(Z):    -447.553954 +/-  0.223200
# Acceptance Rate:                        0.637088
# Replacements:                               5600
# Total Samples:                              8790
# Nested Sampling ln(Z):               -469.979676
# Importance Nested Sampling ln(Z):    -447.507320 +/-  0.222181
# Acceptance Rate:                        0.637266
# Replacements:                               5650
# Total Samples:                              8866
# Nested Sampling ln(Z):               -468.527651
# Importance Nested Sampling ln(Z):    -447.559745 +/-  0.217604
# Acceptance Rate:                        0.637441
# Replacements:                               5700
# Total Samples:                              8942
# Nested Sampling ln(Z):               -467.141876
# Importance Nested Sampling ln(Z):    -447.598375 +/-  0.211247
# Acceptance Rate:                        0.638180
# Replacements:                               5750
# Total Samples:                              9010
# Nested Sampling ln(Z):               -465.885574
# Importance Nested Sampling ln(Z):    -447.583541 +/-  0.203255
# Acceptance Rate:                        0.638556
# Replacements:                               5800
# Total Samples:                              9083
# Nested Sampling ln(Z):               -464.733826
# Importance Nested Sampling ln(Z):    -447.576649 +/-  0.197225
# Acceptance Rate:                        0.639274
# Replacements:                               5850
# Total Samples:                              9151
# Nested Sampling ln(Z):               -463.554730
# Importance Nested Sampling ln(Z):    -447.531698 +/-  0.190241
# Acceptance Rate:                        0.639913
# Replacements:                               5900
# Total Samples:                              9220
# Nested Sampling ln(Z):               -462.457705
# Importance Nested Sampling ln(Z):    -447.533126 +/-  0.178547
# Acceptance Rate:                        0.640543
# Replacements:                               5950
# Total Samples:                              9289
# Nested Sampling ln(Z):               -461.450569
# Importance Nested Sampling ln(Z):    -447.456570 +/-  0.166177
# Acceptance Rate:                        0.641780
# Replacements:                               6000
# Total Samples:                              9349
# Nested Sampling ln(Z):               -460.629675
# Importance Nested Sampling ln(Z):    -447.507560 +/-  0.163124
# Acceptance Rate:                        0.642660
# Replacements:                               6050
# Total Samples:                              9414
# Nested Sampling ln(Z):               -459.881341
# Importance Nested Sampling ln(Z):    -447.498121 +/-  0.152716
# Acceptance Rate:                        0.644071
# Replacements:                               6100
# Total Samples:                              9471
# Nested Sampling ln(Z):               -459.201660
# Importance Nested Sampling ln(Z):    -447.494390 +/-  0.146469
# Acceptance Rate:                        0.644722
# Replacements:                               6150
# Total Samples:                              9539
# Nested Sampling ln(Z):               -458.519432
# Importance Nested Sampling ln(Z):    -447.478411 +/-  0.142225
# Acceptance Rate:                        0.644826
# Replacements:                               6200
# Total Samples:                              9615
# Nested Sampling ln(Z):               -457.831975
# Importance Nested Sampling ln(Z):    -447.417512 +/-  0.132778
# Acceptance Rate:                        0.645195
# Replacements:                               6250
# Total Samples:                              9687
# Nested Sampling ln(Z):               -457.168558
# Importance Nested Sampling ln(Z):    -447.462840 +/-  0.128244
# Acceptance Rate:                        0.646220
# Replacements:                               6300
# Total Samples:                              9749
# Nested Sampling ln(Z):               -456.575861
# Importance Nested Sampling ln(Z):    -447.449445 +/-  0.121889
# Acceptance Rate:                        0.647101
# Replacements:                               6350
# Total Samples:                              9813
# Nested Sampling ln(Z):               -456.038291
# Importance Nested Sampling ln(Z):    -447.452814 +/-  0.117997
# Acceptance Rate:                        0.647839
# Replacements:                               6400
# Total Samples:                              9879
# Nested Sampling ln(Z):               -455.558583
# Importance Nested Sampling ln(Z):    -447.459907 +/-  0.112192
# Acceptance Rate:                        0.648763
# Replacements:                               6450
# Total Samples:                              9942
# Nested Sampling ln(Z):               -455.141378
# Importance Nested Sampling ln(Z):    -447.465977 +/-  0.108196
# Acceptance Rate:                        0.649091
# Replacements:                               6500
# Total Samples:                             10014
# Nested Sampling ln(Z):               -454.727649
# Importance Nested Sampling ln(Z):    -447.462680 +/-  0.102162
# Acceptance Rate:                        0.650189
# Replacements:                               6550
# Total Samples:                             10074
# Nested Sampling ln(Z):               -454.341090
# Importance Nested Sampling ln(Z):    -447.465121 +/-  0.099420
# Acceptance Rate:                        0.650374
# Replacements:                               6600
# Total Samples:                             10148
# Nested Sampling ln(Z):               -453.955894
# Importance Nested Sampling ln(Z):    -447.473388 +/-  0.096812
# Acceptance Rate:                        0.651195
# Replacements:                               6650
# Total Samples:                             10212
# Nested Sampling ln(Z):               -453.550690
# Importance Nested Sampling ln(Z):    -447.487293 +/-  0.092173
# Acceptance Rate:                        0.652576
# Replacements:                               6700
# Total Samples:                             10267
# Nested Sampling ln(Z):               -453.166668
# Importance Nested Sampling ln(Z):    -447.503782 +/-  0.088607
# Acceptance Rate:                        0.653563
# Replacements:                               6750
# Total Samples:                             10328
# Nested Sampling ln(Z):               -452.804033
# Importance Nested Sampling ln(Z):    -447.511035 +/-  0.085053
# Acceptance Rate:                        0.654538
# Replacements:                               6800
# Total Samples:                             10389
# Nested Sampling ln(Z):               -452.480674
# Importance Nested Sampling ln(Z):    -447.521518 +/-  0.081434
# Acceptance Rate:                        0.655502
# Replacements:                               6850
# Total Samples:                             10450
# Nested Sampling ln(Z):               -452.180420
# Importance Nested Sampling ln(Z):    -447.532389 +/-  0.078471
# Acceptance Rate:                        0.656330
# Replacements:                               6900
# Total Samples:                             10513
# Nested Sampling ln(Z):               -451.901591
# Importance Nested Sampling ln(Z):    -447.533709 +/-  0.075209
# Acceptance Rate:                        0.657086
# Replacements:                               6950
# Total Samples:                             10577
# Nested Sampling ln(Z):               -451.646391
# Importance Nested Sampling ln(Z):    -447.518996 +/-  0.071889
# Acceptance Rate:                        0.657957
# Replacements:                               7000
# Total Samples:                             10639
# Nested Sampling ln(Z):               -451.406923
# Importance Nested Sampling ln(Z):    -447.553611 +/-  0.069763
# Acceptance Rate:                        0.658448
# Replacements:                               7050
# Total Samples:                             10707
# Nested Sampling ln(Z):               -451.185030
# Importance Nested Sampling ln(Z):    -447.568855 +/-  0.066802
# Acceptance Rate:                        0.659667
# Replacements:                               7100
# Total Samples:                             10763
# Nested Sampling ln(Z):               -450.976787
# Importance Nested Sampling ln(Z):    -447.558650 +/-  0.064433
# Acceptance Rate:                        0.660386
# Replacements:                               7150
# Total Samples:                             10827
# Nested Sampling ln(Z):               -450.776903
# Importance Nested Sampling ln(Z):    -447.563274 +/-  0.062140
# Acceptance Rate:                        0.660854
# Replacements:                               7200
# Total Samples:                             10895
# Nested Sampling ln(Z):               -450.585970
# Importance Nested Sampling ln(Z):    -447.579277 +/-  0.059448
# Acceptance Rate:                        0.661436
# Replacements:                               7250
# Total Samples:                             10961
# Nested Sampling ln(Z):               -450.408147
# Importance Nested Sampling ln(Z):    -447.567418 +/-  0.056587
# Acceptance Rate:                        0.662492
# Replacements:                               7300
# Total Samples:                             11019
# Nested Sampling ln(Z):               -450.235520
# Importance Nested Sampling ln(Z):    -447.523347 +/-  0.054862
# Acceptance Rate:                        0.662998
# Replacements:                               7350
# Total Samples:                             11086
# Nested Sampling ln(Z):               -450.071958
# Importance Nested Sampling ln(Z):    -447.524769 +/-  0.052224
# Acceptance Rate:                        0.663975
# Replacements:                               7400
# Total Samples:                             11145
# Nested Sampling ln(Z):               -449.920953
# Importance Nested Sampling ln(Z):    -447.525333 +/-  0.050009
# Acceptance Rate:                        0.664526
# Replacements:                               7450
# Total Samples:                             11211
# Nested Sampling ln(Z):               -449.781653
# Importance Nested Sampling ln(Z):    -447.544485 +/-  0.047904
# Acceptance Rate:                        0.665306
# Replacements:                               7500
# Total Samples:                             11273
# Nested Sampling ln(Z):               -449.652365
# Importance Nested Sampling ln(Z):    -447.548618 +/-  0.045749
# Acceptance Rate:                        0.666490
# Replacements:                               7550
# Total Samples:                             11328
# Nested Sampling ln(Z):               -449.529378
# Importance Nested Sampling ln(Z):    -447.543074 +/-  0.043819
# Acceptance Rate:                        0.667604
# Replacements:                               7600
# Total Samples:                             11384
# Nested Sampling ln(Z):               -449.414506
# Importance Nested Sampling ln(Z):    -447.537667 +/-  0.042092
# Acceptance Rate:                        0.668122
# Replacements:                               7650
# Total Samples:                             11450
# Nested Sampling ln(Z):               -449.303591
# Importance Nested Sampling ln(Z):    -447.542487 +/-  0.040220
# Acceptance Rate:                        0.669216
# Replacements:                               7700
# Total Samples:                             11506
# Nested Sampling ln(Z):               -449.198311
# Importance Nested Sampling ln(Z):    -447.545317 +/-  0.038614
# Acceptance Rate:                        0.670299
# Replacements:                               7750
# Total Samples:                             11562
# Nested Sampling ln(Z):               -449.098911
# Importance Nested Sampling ln(Z):    -447.539030 +/-  0.037147
# Acceptance Rate:                        0.670852
# Replacements:                               7800
# Total Samples:                             11627
# Nested Sampling ln(Z):               -449.005872
# Importance Nested Sampling ln(Z):    -447.539995 +/-  0.035556
# Acceptance Rate:                        0.671859
# Replacements:                               7850
# Total Samples:                             11684
# Nested Sampling ln(Z):               -448.919126
# Importance Nested Sampling ln(Z):    -447.537966 +/-  0.034160
# Acceptance Rate:                        0.672799
# Replacements:                               7900
# Total Samples:                             11742
# Nested Sampling ln(Z):               -448.837180
# Importance Nested Sampling ln(Z):    -447.533454 +/-  0.032812
# Acceptance Rate:                        0.673900
# Replacements:                               7950
# Total Samples:                             11797
# Nested Sampling ln(Z):               -448.759988
# Importance Nested Sampling ln(Z):    -447.537115 +/-  0.031461
# Acceptance Rate:                        0.674707
# Replacements:                               8000
# Total Samples:                             11857
# Nested Sampling ln(Z):               -448.687920
# Importance Nested Sampling ln(Z):    -447.538628 +/-  0.030208
# Acceptance Rate:                        0.675506
# Replacements:                               8050
# Total Samples:                             11917
# Nested Sampling ln(Z):               -448.620255
# Importance Nested Sampling ln(Z):    -447.539321 +/-  0.028966
# Acceptance Rate:                        0.676466
# Replacements:                               8100
# Total Samples:                             11974
# Nested Sampling ln(Z):               -448.556256
# Importance Nested Sampling ln(Z):    -447.538415 +/-  0.027868
# Acceptance Rate:                        0.677135
# Replacements:                               8150
# Total Samples:                             12036
# Nested Sampling ln(Z):               -448.495371
# Importance Nested Sampling ln(Z):    -447.537601 +/-  0.026730
# Acceptance Rate:                        0.678078
# Replacements:                               8200
# Total Samples:                             12093
# Nested Sampling ln(Z):               -448.438708
# Importance Nested Sampling ln(Z):    -447.537326 +/-  0.025745
# Acceptance Rate:                        0.679124
# Replacements:                               8250
# Total Samples:                             12148
# Nested Sampling ln(Z):               -448.385422
# Importance Nested Sampling ln(Z):    -447.536455 +/-  0.024804
# Acceptance Rate:                        0.680105
# Replacements:                               8300
# Total Samples:                             12204
# Nested Sampling ln(Z):               -448.335005
# Importance Nested Sampling ln(Z):    -447.535853 +/-  0.023903
# Acceptance Rate:                        0.681077
# Replacements:                               8350
# Total Samples:                             12260
# Nested Sampling ln(Z):               -448.287296
# Importance Nested Sampling ln(Z):    -447.534530 +/-  0.023083
# Acceptance Rate:                        0.682040
# Replacements:                               8400
# Total Samples:                             12316
# Nested Sampling ln(Z):               -448.242492
# Importance Nested Sampling ln(Z):    -447.535407 +/-  0.022281
# Acceptance Rate:                        0.682718
# Replacements:                               8450
# Total Samples:                             12377
# Nested Sampling ln(Z):               -448.200542
# Importance Nested Sampling ln(Z):    -447.537884 +/-  0.021492
# Acceptance Rate:                        0.683554
# Replacements:                               8500
# Total Samples:                             12435
# Nested Sampling ln(Z):               -448.161232
# Importance Nested Sampling ln(Z):    -447.537779 +/-  0.020814
# Acceptance Rate:                        0.684712
# Replacements:                               8550
# Total Samples:                             12487
# Nested Sampling ln(Z):               -448.124661
# Importance Nested Sampling ln(Z):    -447.535236 +/-  0.020273
# Acceptance Rate:                        0.685368
# Replacements:                               8600
# Total Samples:                             12548
# Nested Sampling ln(Z):               -448.090480
# Importance Nested Sampling ln(Z):    -447.536276 +/-  0.019672
# Acceptance Rate:                        0.686018
# Replacements:                               8650
# Total Samples:                             12609
# Nested Sampling ln(Z):               -448.058373
# Importance Nested Sampling ln(Z):    -447.536571 +/-  0.019131
# Acceptance Rate:                        0.687041
# Replacements:                               8700
# Total Samples:                             12663
# Nested Sampling ln(Z):               -448.028402
# Importance Nested Sampling ln(Z):    -447.535405 +/-  0.018700
# Acceptance Rate:                        0.687839
# Replacements:                               8750
# Total Samples:                             12721
# Nested Sampling ln(Z):               -448.000396
# Importance Nested Sampling ln(Z):    -447.534625 +/-  0.018284
# Acceptance Rate:                        0.688791
# Replacements:                               8800
# Total Samples:                             12776
# Nested Sampling ln(Z):               -447.974397
# Importance Nested Sampling ln(Z):    -447.535220 +/-  0.017917
# Acceptance Rate:                        0.689736
# Replacements:                               8850
# Total Samples:                             12831
# Nested Sampling ln(Z):               -447.949998
# Importance Nested Sampling ln(Z):    -447.536073 +/-  0.017587
# Acceptance Rate:                        0.690256
# Replacements:                               8876
# Total Samples:                             12859
# Nested Sampling ln(Z):               -447.937941
# Importance Nested Sampling ln(Z):    -447.536421 +/-  0.017433
#   analysing data from /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_mnest/hii_.txt
#  ln(ev)=  -447.63232156104146      +/-  0.13710103631538359
#  Total Likelihood Evaluations:        12859
#  Sampling finished. Exiting MultiNest

# %%
print("\nEvidence lnZ = %.3f ± %.3f" % (result["logZ"], result["logZerr"]))


samples = result["samples"]   # shape = (Nsamples, 3)
parameters = [r"\alpha", r"\beta", r"h"]
print("Posterior means/stdev:")
for name, col in zip(parameters, samples.T):
    print(f"{name:>6s}: {col.mean():.3f} ± {col.std():.3f}")


with open(prefix + "params.json", "w") as f:
    json.dump(parameters, f, indent=2)

fig = corner.corner(
    samples,
    labels=[r"$\alpha$", r"$\beta$", r"$h$"],
    show_titles=True,
    title_fmt=".3f",
    quantiles=[0.16, 0.5, 0.84]
)
fig.savefig(prefix + "corner.png", dpi=150, bbox_inches="tight")
plt.close(fig)
print("Corner guardado en:", prefix + "corner.png")
# Out:
# Evidence lnZ = -447.632 ± 0.137
# Posterior means/stdev:
# \alpha: 33.484 ± 0.106
#  \beta: 4.824 ± 0.086
#      h: 0.777 ± 0.040
# Corner guardado en: /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_mnest/hii_corner.png

# %%
gds = MCSamples(
    samples=samples,
    names=["alpha", "beta", "h"],
    labels=[r"\alpha", r"\beta", r"h"]  
)
g = plots.getSubplotPlotter()
g.settings.num_plot_contours = 2
g.triangle_plot([gds], filled=True, title_limit=1)
g.export(prefix + "triangle_getdist.png")
print("GetDist triangle en:", prefix + "triangle_getdist.png")

print("\nListo. Archivos en:", outdir)
# Out:
# Removed no burn in
# GetDist triangle en: /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_mnest/hii_triangle_getdist.png
#
# Listo. Archivos en: /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_mnest

# %% [markdown]
# ## Implementacion para HIIGs (5 parámetros)
#
# ## $$\alpha , \beta , H_0 , \Omega_{\text{m}} , w_{\text{DE}}$$

# %%
def lnlike(theta, x, y, z, xerr, yerr, zerr):
    alpha, beta, h0, Om, wDE = theta

    
    eps = 1e-6
    Om = np.clip(Om, eps, 1.0 - eps)
    h0 = float(h0)

    try:
        cosmo = FlatwCDM(H0=h0*100.0, Om0=Om, w0=wDE)
    except Exception:
        return -np.inf

    # índices
    ixG = (z >= 10)   
    ixH = (z <  10)

    Mum = np.zeros_like(z, dtype=float)
    MumErr = np.zeros_like(z, dtype=float)

    
    Mum[ixG] = z[ixG]
    MumErr[ixG] = zerr[ixG]

   
    zz = z[ixH]
    zzerr = zerr[ixH]
   
   
    if np.any(zz <= 0):
        return -np.inf

    try:
        DL = cosmo.luminosity_distance(zz).value  # Mpc
        if not np.all(np.isfinite(DL)) or np.any(DL <= 0):
            return -np.inf
        Mum[ixH] = 5.0*np.log10(DL) + 25.0
        MumErr[ixH] = (5.0/np.log(10.0))*(zzerr/zz)
    except Exception:
        return -np.inf

    Mu = 2.5*(beta*x + alpha) - 2.5*y - 100.195
    MuErr = 2.5*np.sqrt(yerr**2 + (beta**2)*(xerr**2))

    
    var = MuErr**2 + MumErr**2
    if np.any(var <= 0) or not np.all(np.isfinite(var)):
        return -np.inf

    R = Mu - Mum
    if not np.all(np.isfinite(R)):
        return -np.inf

    xsq = np.sum((R**2)/var)
    if not np.isfinite(xsq):
        return -np.inf

    return -0.5*xsq

# %%
def load_data(dpath):
    Tpath = os.path.join(dpath, 'indat/Union2020v16.dat')
    data = Table.read(Tpath, format='ascii', comment='#')

    vix  = np.asarray(data['col1'])
    vx   = np.asarray(data['col2'])
    vy   = np.asarray(data['col3'])
    vz   = np.asarray(data['col4'])
    vxEr = np.asarray(data['col5'])
    vyEr = np.asarray(data['col6'])
    vzEr = np.asarray(data['col7'])
    vsp  = np.asarray(data['col8'])

    LSL = 1.83
    ix = np.where((vx - vxEr) <= LSL)
    return vix[ix], vx[ix], vy[ix], vz[ix], vxEr[ix], vyEr[ix], vzEr[ix], vsp[ix]

# %%
def prior_transform(u):
    alpha = 20.0 + 20.0 * u[0]     # 2->40
    beta  =  0.0 + 10.0 * u[1]     # 0->0
    h0    =  0.5 +  0.5 * u[2]     # 0.5->1.0
    Om    =  0.0 +  1.0 * u[3]
    wDE   = -2.0 +  3.0 * u[4]
    return np.array([alpha, beta, h0, Om, wDE])

# %%
HOME = os.path.expanduser("~") + '/HIIGs/'
dpath = os.path.join(HOME, "MCMC/ZEUS/h0wsh2023/dat/")

dpath = '/home/holman//MCMC/ZEUS/h0wsh2023/dat/'
print("Data path:", dpath)

vTg, vx, vy, vz, vxErr, vyErr, vzErr, vsp = load_data(dpath)
# Out:
# Data path: /home/holman//MCMC/ZEUS/h0wsh2023/dat/

# %%
outdir = os.path.join(dpath, "results_5nestHII")
os.makedirs(outdir, exist_ok=True)
prefix = os.path.join(outdir, "hii_")

def loglike_for_mnest(theta):
    return lnlike(theta, vx, vy, vz, vxErr, vyErr, vzErr)

# %%
n_dims = 5
result = pymultinest.solve(
    LogLikelihood=loglike_for_mnest,
    Prior=prior_transform,
    n_dims=n_dims,
    outputfiles_basename=prefix,
    evidence_tolerance=0.5,
    n_live_points=600,
    multimodal=True,
    verbose=True
)
# Out:
#  MultiNest Warning: no resume file found, starting from scratch
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  600
#  dimensionality =    5
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.993884
# Replacements:                                650
# Total Samples:                               654
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):    -473.077502 +/-  0.999235
# Acceptance Rate:                        0.985915
# Replacements:                                700
# Total Samples:                               710
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):    -473.159659 +/-  0.999296
# Acceptance Rate:                        0.975293
# Replacements:                                750
# Total Samples:                               769
# Nested Sampling ln(Z):            -723935.410924
# Importance Nested Sampling ln(Z):    -473.239485 +/-  0.999350
# Acceptance Rate:                        0.963855
# Replacements:                                800
# Total Samples:                               830
# Nested Sampling ln(Z):            -438605.777126
# Importance Nested Sampling ln(Z):    -473.315820 +/-  0.999397
# Acceptance Rate:                        0.944444
# Replacements:                                850
# Total Samples:                               900
# Nested Sampling ln(Z):            -277071.877488
# Importance Nested Sampling ln(Z):    -473.396789 +/-  0.999444
# Acceptance Rate:                        0.927835
# Replacements:                                900
# Total Samples:                               970
# Nested Sampling ln(Z):            -210746.330486
# Importance Nested Sampling ln(Z):    -473.525067 +/-  0.999484
# Acceptance Rate:                        0.910834
# Replacements:                                950
# Total Samples:                              1043
# Nested Sampling ln(Z):            -168990.663112
# Importance Nested Sampling ln(Z):    -473.697510 +/-  0.999520
# Acceptance Rate:                        0.888889
# Replacements:                               1000
# Total Samples:                              1125
# Nested Sampling ln(Z):            -138843.517871
# Importance Nested Sampling ln(Z):    -473.848493 +/-  0.999555
# Acceptance Rate:                        0.880872
# Replacements:                               1050
# Total Samples:                              1192
# Nested Sampling ln(Z):            -109530.180067
# Importance Nested Sampling ln(Z):    -473.971638 +/-  0.999580
# Acceptance Rate:                        0.869565
# Replacements:                               1100
# Total Samples:                              1265
# Nested Sampling ln(Z):             -90347.995364
# Importance Nested Sampling ln(Z):    -474.103101 +/-  0.999605
# Acceptance Rate:                        0.857569
# Replacements:                               1150
# Total Samples:                              1341
# Nested Sampling ln(Z):             -74877.067511
# Importance Nested Sampling ln(Z):    -474.214322 +/-  0.999627
# Acceptance Rate:                        0.849858
# Replacements:                               1200
# Total Samples:                              1412
# Nested Sampling ln(Z):             -63495.484968
# Importance Nested Sampling ln(Z):    -474.311355 +/-  0.999646
# Acceptance Rate:                        0.839490
# Replacements:                               1250
# Total Samples:                              1489
# Nested Sampling ln(Z):             -53071.810422
# Importance Nested Sampling ln(Z):    -474.417634 +/-  0.999664
# Acceptance Rate:                        0.835476
# Replacements:                               1300
# Total Samples:                              1556
# Nested Sampling ln(Z):             -46140.970686
# Importance Nested Sampling ln(Z):    -474.506553 +/-  0.999679
# Acceptance Rate:                        0.825688
# Replacements:                               1350
# Total Samples:                              1635
# Nested Sampling ln(Z):             -39711.795860
# Importance Nested Sampling ln(Z):    -474.600669 +/-  0.999694
# Acceptance Rate:                        0.817280
# Replacements:                               1400
# Total Samples:                              1713
# Nested Sampling ln(Z):             -34959.164558
# Importance Nested Sampling ln(Z):    -474.701916 +/-  0.999708
# Acceptance Rate:                        0.812780
# Replacements:                               1450
# Total Samples:                              1784
# Nested Sampling ln(Z):             -30336.327433
# Importance Nested Sampling ln(Z):    -474.794929 +/-  0.999720
# Acceptance Rate:                        0.805153
# Replacements:                               1500
# Total Samples:                              1863
# Nested Sampling ln(Z):             -24793.848444
# Importance Nested Sampling ln(Z):    -474.892228 +/-  0.996304
# Acceptance Rate:                        0.795688
# Replacements:                               1550
# Total Samples:                              1948
# Nested Sampling ln(Z):             -20830.964914
# Importance Nested Sampling ln(Z):    -475.001321 +/-  0.996316
# Acceptance Rate:                        0.788177
# Replacements:                               1600
# Total Samples:                              2030
# Nested Sampling ln(Z):             -17472.791476
# Importance Nested Sampling ln(Z):    -475.101105 +/-  0.996326
# Acceptance Rate:                        0.782361
# Replacements:                               1650
# Total Samples:                              2109
# Nested Sampling ln(Z):             -14927.754099
# Importance Nested Sampling ln(Z):    -467.380228 +/-  0.999360
# Acceptance Rate:                        0.776256
# Replacements:                               1700
# Total Samples:                              2190
# Nested Sampling ln(Z):             -12926.226868
# Importance Nested Sampling ln(Z):    -467.489778 +/-  0.999369
# Acceptance Rate:                        0.772627
# Replacements:                               1750
# Total Samples:                              2265
# Nested Sampling ln(Z):             -11334.693238
# Importance Nested Sampling ln(Z):    -467.574479 +/-  0.999376
# Acceptance Rate:                        0.767591
# Replacements:                               1800
# Total Samples:                              2345
# Nested Sampling ln(Z):              -9783.754490
# Importance Nested Sampling ln(Z):    -417.156093 +/-  0.999787
# Acceptance Rate:                        0.761944
# Replacements:                               1850
# Total Samples:                              2428
# Nested Sampling ln(Z):              -8390.531762
# Importance Nested Sampling ln(Z):    -417.261028 +/-  0.999794
# Acceptance Rate:                        0.756671
# Replacements:                               1900
# Total Samples:                              2511
# Nested Sampling ln(Z):              -7221.978730
# Importance Nested Sampling ln(Z):    -417.360994 +/-  0.999801
# Acceptance Rate:                        0.754936
# Replacements:                               1950
# Total Samples:                              2583
# Nested Sampling ln(Z):              -6231.550274
# Importance Nested Sampling ln(Z):    -417.445481 +/-  0.999806
# Acceptance Rate:                        0.747384
# Replacements:                               2000
# Total Samples:                              2676
# Nested Sampling ln(Z):              -5628.399644
# Importance Nested Sampling ln(Z):    -417.551623 +/-  0.999813
# Acceptance Rate:                        0.742216
# Replacements:                               2050
# Total Samples:                              2762
# Nested Sampling ln(Z):              -5016.892192
# Importance Nested Sampling ln(Z):    -417.647385 +/-  0.999819
# Acceptance Rate:                        0.736584
# Replacements:                               2100
# Total Samples:                              2851
# Nested Sampling ln(Z):              -4449.369545
# Importance Nested Sampling ln(Z):    -417.745989 +/-  0.999824
# Acceptance Rate:                        0.728567
# Replacements:                               2150
# Total Samples:                              2951
# Nested Sampling ln(Z):              -3999.122265
# Importance Nested Sampling ln(Z):    -409.319714 +/-  0.999632
# Acceptance Rate:                        0.723446
# Replacements:                               2200
# Total Samples:                              3041
# Nested Sampling ln(Z):              -3632.605143
# Importance Nested Sampling ln(Z):    -409.420452 +/-  0.999637
# Acceptance Rate:                        0.721385
# Replacements:                               2250
# Total Samples:                              3119
# Nested Sampling ln(Z):              -3332.280781
# Importance Nested Sampling ln(Z):    -409.505068 +/-  0.999641
# Acceptance Rate:                        0.719424
# Replacements:                               2300
# Total Samples:                              3197
# Nested Sampling ln(Z):              -3091.091254
# Importance Nested Sampling ln(Z):    -409.599973 +/-  0.999645
# Acceptance Rate:                        0.717557
# Replacements:                               2350
# Total Samples:                              3275
# Nested Sampling ln(Z):              -2844.957611
# Importance Nested Sampling ln(Z):    -409.683649 +/-  0.999649
# Acceptance Rate:                        0.714924
# Replacements:                               2400
# Total Samples:                              3357
# Nested Sampling ln(Z):              -2652.141750
# Importance Nested Sampling ln(Z):    -409.774702 +/-  0.999653
# Acceptance Rate:                        0.709323
# Replacements:                               2450
# Total Samples:                              3454
# Nested Sampling ln(Z):              -2475.511904
# Importance Nested Sampling ln(Z):    -409.877457 +/-  0.999657
# Acceptance Rate:                        0.706215
# Replacements:                               2500
# Total Samples:                              3540
# Nested Sampling ln(Z):              -2335.810354
# Importance Nested Sampling ln(Z):    -409.967604 +/-  0.999660
# Acceptance Rate:                        0.701899
# Replacements:                               2550
# Total Samples:                              3633
# Nested Sampling ln(Z):              -2202.618081
# Importance Nested Sampling ln(Z):    -410.064467 +/-  0.999664
# Acceptance Rate:                        0.694259
# Replacements:                               2600
# Total Samples:                              3745
# Nested Sampling ln(Z):              -2092.284445
# Importance Nested Sampling ln(Z):    -410.172304 +/-  0.999668
# Acceptance Rate:                        0.691364
# Replacements:                               2650
# Total Samples:                              3833
# Nested Sampling ln(Z):              -1986.563954
# Importance Nested Sampling ln(Z):    -410.261168 +/-  0.999671
# Acceptance Rate:                        0.690361
# Replacements:                               2700
# Total Samples:                              3911
# Nested Sampling ln(Z):              -1861.075812
# Importance Nested Sampling ln(Z):    -410.329986 +/-  0.999673
# Acceptance Rate:                        0.684932
# Replacements:                               2750
# Total Samples:                              4015
# Nested Sampling ln(Z):              -1777.430779
# Importance Nested Sampling ln(Z):    -410.436385 +/-  0.999677
# Acceptance Rate:                        0.682594
# Replacements:                               2800
# Total Samples:                              4102
# Nested Sampling ln(Z):              -1689.227864
# Importance Nested Sampling ln(Z):    -410.197539 +/-  0.774135
# Acceptance Rate:                        0.677281
# Replacements:                               2850
# Total Samples:                              4208
# Nested Sampling ln(Z):              -1610.278510
# Importance Nested Sampling ln(Z):    -410.249559 +/-  0.739826
# Acceptance Rate:                        0.676148
# Replacements:                               2900
# Total Samples:                              4289
# Nested Sampling ln(Z):              -1540.351241
# Importance Nested Sampling ln(Z):    -410.327709 +/-  0.739834
# Acceptance Rate:                        0.675057
# Replacements:                               2950
# Total Samples:                              4370
# Nested Sampling ln(Z):              -1447.252320
# Importance Nested Sampling ln(Z):    -410.397721 +/-  0.739842
# Acceptance Rate:                        0.672344
# Replacements:                               3000
# Total Samples:                              4462
# Nested Sampling ln(Z):              -1381.416017
# Importance Nested Sampling ln(Z):    -410.482151 +/-  0.738486
# Acceptance Rate:                        0.671806
# Replacements:                               3050
# Total Samples:                              4540
# Nested Sampling ln(Z):              -1314.758675
# Importance Nested Sampling ln(Z):    -410.563399 +/-  0.738492
# Acceptance Rate:                        0.669836
# Replacements:                               3100
# Total Samples:                              4628
# Nested Sampling ln(Z):              -1247.443792
# Importance Nested Sampling ln(Z):    -410.647374 +/-  0.738499
# Acceptance Rate:                        0.667656
# Replacements:                               3150
# Total Samples:                              4718
# Nested Sampling ln(Z):              -1185.213856
# Importance Nested Sampling ln(Z):    -410.731584 +/-  0.738505
# Acceptance Rate:                        0.665696
# Replacements:                               3200
# Total Samples:                              4807
# Nested Sampling ln(Z):              -1123.936431
# Importance Nested Sampling ln(Z):    -410.816773 +/-  0.738510
# Acceptance Rate:                        0.665574
# Replacements:                               3250
# Total Samples:                              4883
# Nested Sampling ln(Z):              -1063.635029
# Importance Nested Sampling ln(Z):    -410.884076 +/-  0.738515
# Acceptance Rate:                        0.661455
# Replacements:                               3300
# Total Samples:                              4989
# Nested Sampling ln(Z):              -1004.468703
# Importance Nested Sampling ln(Z):    -410.987550 +/-  0.738521
# Acceptance Rate:                        0.658930
# Replacements:                               3350
# Total Samples:                              5084
# Nested Sampling ln(Z):               -962.719734
# Importance Nested Sampling ln(Z):    -411.076494 +/-  0.738526
# Acceptance Rate:                        0.656371
# Replacements:                               3400
# Total Samples:                              5180
# Nested Sampling ln(Z):               -920.749235
# Importance Nested Sampling ln(Z):    -411.164824 +/-  0.738524
# Acceptance Rate:                        0.654897
# Replacements:                               3450
# Total Samples:                              5268
# Nested Sampling ln(Z):               -886.258810
# Importance Nested Sampling ln(Z):    -411.250936 +/-  0.738528
# Acceptance Rate:                        0.652742
# Replacements:                               3500
# Total Samples:                              5362
# Nested Sampling ln(Z):               -843.130850
# Importance Nested Sampling ln(Z):    -411.344290 +/-  0.736100
# Acceptance Rate:                        0.651974
# Replacements:                               3550
# Total Samples:                              5445
# Nested Sampling ln(Z):               -804.246587
# Importance Nested Sampling ln(Z):    -411.425569 +/-  0.736101
# Acceptance Rate:                        0.650642
# Replacements:                               3600
# Total Samples:                              5533
# Nested Sampling ln(Z):               -776.299626
# Importance Nested Sampling ln(Z):    -411.519548 +/-  0.734777
# Acceptance Rate:                        0.649697
# Replacements:                               3650
# Total Samples:                              5618
# Nested Sampling ln(Z):               -748.193332
# Importance Nested Sampling ln(Z):    -411.568430 +/-  0.712753
# Acceptance Rate:                        0.647986
# Replacements:                               3700
# Total Samples:                              5710
# Nested Sampling ln(Z):               -727.437904
# Importance Nested Sampling ln(Z):    -411.657394 +/-  0.712691
# Acceptance Rate:                        0.645995
# Replacements:                               3750
# Total Samples:                              5805
# Nested Sampling ln(Z):               -707.554507
# Importance Nested Sampling ln(Z):    -411.750956 +/-  0.712694
# Acceptance Rate:                        0.642869
# Replacements:                               3800
# Total Samples:                              5911
# Nested Sampling ln(Z):               -684.944613
# Importance Nested Sampling ln(Z):    -411.843549 +/-  0.712640
# Acceptance Rate:                        0.640599
# Replacements:                               3850
# Total Samples:                              6010
# Nested Sampling ln(Z):               -666.162744
# Importance Nested Sampling ln(Z):    -411.736564 +/-  0.604490
# Acceptance Rate:                        0.639135
# Replacements:                               3900
# Total Samples:                              6102
# Nested Sampling ln(Z):               -645.313574
# Importance Nested Sampling ln(Z):    -411.817162 +/-  0.604489
# Acceptance Rate:                        0.636481
# Replacements:                               3950
# Total Samples:                              6206
# Nested Sampling ln(Z):               -626.834913
# Importance Nested Sampling ln(Z):    -411.906644 +/-  0.604381
# Acceptance Rate:                        0.633814
# Replacements:                               4000
# Total Samples:                              6311
# Nested Sampling ln(Z):               -607.897773
# Importance Nested Sampling ln(Z):    -411.747191 +/-  0.516149
# Acceptance Rate:                        0.630841
# Replacements:                               4050
# Total Samples:                              6420
# Nested Sampling ln(Z):               -594.723107
# Importance Nested Sampling ln(Z):    -411.830992 +/-  0.508884
# Acceptance Rate:                        0.629510
# Replacements:                               4100
# Total Samples:                              6513
# Nested Sampling ln(Z):               -580.872129
# Importance Nested Sampling ln(Z):    -411.907708 +/-  0.508723
# Acceptance Rate:                        0.625565
# Replacements:                               4150
# Total Samples:                              6634
# Nested Sampling ln(Z):               -569.776331
# Importance Nested Sampling ln(Z):    -411.985432 +/-  0.501266
# Acceptance Rate:                        0.624350
# Replacements:                               4200
# Total Samples:                              6727
# Nested Sampling ln(Z):               -556.823485
# Importance Nested Sampling ln(Z):    -412.003861 +/-  0.477072
# Acceptance Rate:                        0.623807
# Replacements:                               4250
# Total Samples:                              6813
# Nested Sampling ln(Z):               -549.461851
# Importance Nested Sampling ln(Z):    -412.074803 +/-  0.477025
# Acceptance Rate:                        0.622106
# Replacements:                               4300
# Total Samples:                              6912
# Nested Sampling ln(Z):               -539.048257
# Importance Nested Sampling ln(Z):    -408.891407 +/-  0.784472
# Acceptance Rate:                        0.618337
# Replacements:                               4350
# Total Samples:                              7035
# Nested Sampling ln(Z):               -529.844854
# Importance Nested Sampling ln(Z):    -409.002704 +/-  0.784439
# Acceptance Rate:                        0.616765
# Replacements:                               4400
# Total Samples:                              7134
# Nested Sampling ln(Z):               -520.962223
# Importance Nested Sampling ln(Z):    -409.088980 +/-  0.784417
# Acceptance Rate:                        0.614981
# Replacements:                               4450
# Total Samples:                              7236
# Nested Sampling ln(Z):               -514.686532
# Importance Nested Sampling ln(Z):    -409.021638 +/-  0.686429
# Acceptance Rate:                        0.613581
# Replacements:                               4500
# Total Samples:                              7334
# Nested Sampling ln(Z):               -506.888206
# Importance Nested Sampling ln(Z):    -408.867198 +/-  0.566632
# Acceptance Rate:                        0.609838
# Replacements:                               4550
# Total Samples:                              7461
# Nested Sampling ln(Z):               -500.999220
# Importance Nested Sampling ln(Z):    -408.961854 +/-  0.561455
# Acceptance Rate:                        0.606780
# Replacements:                               4600
# Total Samples:                              7581
# Nested Sampling ln(Z):               -494.203084
# Importance Nested Sampling ln(Z):    -409.047689 +/-  0.557523
# Acceptance Rate:                        0.604446
# Replacements:                               4650
# Total Samples:                              7693
# Nested Sampling ln(Z):               -489.337547
# Importance Nested Sampling ln(Z):    -408.832542 +/-  0.486778
# Acceptance Rate:                        0.601331
# Replacements:                               4700
# Total Samples:                              7816
# Nested Sampling ln(Z):               -484.474169
# Importance Nested Sampling ln(Z):    -408.906592 +/-  0.479873
# Acceptance Rate:                        0.598991
# Replacements:                               4750
# Total Samples:                              7930
# Nested Sampling ln(Z):               -480.115883
# Importance Nested Sampling ln(Z):    -408.587320 +/-  0.461928
# Acceptance Rate:                        0.595829
# Replacements:                               4800
# Total Samples:                              8056
# Nested Sampling ln(Z):               -475.750211
# Importance Nested Sampling ln(Z):    -408.564749 +/-  0.425573
# Acceptance Rate:                        0.594873
# Replacements:                               4850
# Total Samples:                              8153
# Nested Sampling ln(Z):               -471.556187
# Importance Nested Sampling ln(Z):    -408.578626 +/-  0.404030
# Acceptance Rate:                        0.592790
# Replacements:                               4900
# Total Samples:                              8266
# Nested Sampling ln(Z):               -468.508293
# Importance Nested Sampling ln(Z):    -408.653407 +/-  0.398722
# Acceptance Rate:                        0.589637
# Replacements:                               4950
# Total Samples:                              8395
# Nested Sampling ln(Z):               -465.370190
# Importance Nested Sampling ln(Z):    -408.687912 +/-  0.380708
# Acceptance Rate:                        0.586717
# Replacements:                               5000
# Total Samples:                              8522
# Nested Sampling ln(Z):               -462.670496
# Importance Nested Sampling ln(Z):    -408.742396 +/-  0.371099
# Acceptance Rate:                        0.583748
# Replacements:                               5050
# Total Samples:                              8651
# Nested Sampling ln(Z):               -460.394886
# Importance Nested Sampling ln(Z):    -408.079826 +/-  0.553828
# Acceptance Rate:                        0.582059
# Replacements:                               5100
# Total Samples:                              8762
# Nested Sampling ln(Z):               -457.394080
# Importance Nested Sampling ln(Z):    -408.075942 +/-  0.512465
# Acceptance Rate:                        0.580216
# Replacements:                               5150
# Total Samples:                              8876
# Nested Sampling ln(Z):               -454.421968
# Importance Nested Sampling ln(Z):    -408.158939 +/-  0.512395
# Acceptance Rate:                        0.578871
# Replacements:                               5200
# Total Samples:                              8983
# Nested Sampling ln(Z):               -451.850286
# Importance Nested Sampling ln(Z):    -408.203406 +/-  0.494082
# Acceptance Rate:                        0.578321
# Replacements:                               5250
# Total Samples:                              9078
# Nested Sampling ln(Z):               -449.665357
# Importance Nested Sampling ln(Z):    -408.250813 +/-  0.483720
# Acceptance Rate:                        0.576275
# Replacements:                               5300
# Total Samples:                              9197
# Nested Sampling ln(Z):               -447.544838
# Importance Nested Sampling ln(Z):    -407.672755 +/-  0.408510
# Acceptance Rate:                        0.573850
# Replacements:                               5350
# Total Samples:                              9323
# Nested Sampling ln(Z):               -445.935175
# Importance Nested Sampling ln(Z):    -407.765108 +/-  0.407009
# Acceptance Rate:                        0.571429
# Replacements:                               5400
# Total Samples:                              9450
# Nested Sampling ln(Z):               -444.397459
# Importance Nested Sampling ln(Z):    -407.816134 +/-  0.393235
# Acceptance Rate:                        0.569726
# Replacements:                               5450
# Total Samples:                              9566
# Nested Sampling ln(Z):               -442.819074
# Importance Nested Sampling ln(Z):    -407.835754 +/-  0.375177
# Acceptance Rate:                        0.566310
# Replacements:                               5500
# Total Samples:                              9712
# Nested Sampling ln(Z):               -441.167073
# Importance Nested Sampling ln(Z):    -407.860884 +/-  0.354821
# Acceptance Rate:                        0.564598
# Replacements:                               5550
# Total Samples:                              9830
# Nested Sampling ln(Z):               -439.604516
# Importance Nested Sampling ln(Z):    -407.858608 +/-  0.332278
# Acceptance Rate:                        0.560954
# Replacements:                               5600
# Total Samples:                              9983
# Nested Sampling ln(Z):               -438.095115
# Importance Nested Sampling ln(Z):    -407.919134 +/-  0.321295
# Acceptance Rate:                        0.558025
# Replacements:                               5650
# Total Samples:                             10125
# Nested Sampling ln(Z):               -436.685159
# Importance Nested Sampling ln(Z):    -407.871000 +/-  0.298606
# Acceptance Rate:                        0.554853
# Replacements:                               5700
# Total Samples:                             10273
# Nested Sampling ln(Z):               -435.418443
# Importance Nested Sampling ln(Z):    -407.884876 +/-  0.284760
# Acceptance Rate:                        0.552460
# Replacements:                               5750
# Total Samples:                             10408
# Nested Sampling ln(Z):               -434.154286
# Importance Nested Sampling ln(Z):    -407.820418 +/-  0.279798
# Acceptance Rate:                        0.552486
# Replacements:                               5800
# Total Samples:                             10498
# Nested Sampling ln(Z):               -432.906579
# Importance Nested Sampling ln(Z):    -407.845074 +/-  0.272697
# Acceptance Rate:                        0.550847
# Replacements:                               5850
# Total Samples:                             10620
# Nested Sampling ln(Z):               -431.725564
# Importance Nested Sampling ln(Z):    -407.721529 +/-  0.247408
# Acceptance Rate:                        0.547158
# Replacements:                               5900
# Total Samples:                             10783
# Nested Sampling ln(Z):               -430.596331
# Importance Nested Sampling ln(Z):    -407.806628 +/-  0.250081
# Acceptance Rate:                        0.544872
# Replacements:                               5950
# Total Samples:                             10920
# Nested Sampling ln(Z):               -429.509178
# Importance Nested Sampling ln(Z):    -407.855384 +/-  0.247387
# Acceptance Rate:                        0.543626
# Replacements:                               6000
# Total Samples:                             11037
# Nested Sampling ln(Z):               -428.546887
# Importance Nested Sampling ln(Z):    -407.841522 +/-  0.242673
# Acceptance Rate:                        0.541629
# Replacements:                               6050
# Total Samples:                             11170
# Nested Sampling ln(Z):               -427.614367
# Importance Nested Sampling ln(Z):    -407.833834 +/-  0.230121
# Acceptance Rate:                        0.540158
# Replacements:                               6100
# Total Samples:                             11293
# Nested Sampling ln(Z):               -426.562762
# Importance Nested Sampling ln(Z):    -407.747797 +/-  0.216477
# Acceptance Rate:                        0.539332
# Replacements:                               6150
# Total Samples:                             11403
# Nested Sampling ln(Z):               -425.603764
# Importance Nested Sampling ln(Z):    -407.754871 +/-  0.209918
# Acceptance Rate:                        0.537774
# Replacements:                               6200
# Total Samples:                             11529
# Nested Sampling ln(Z):               -424.781203
# Importance Nested Sampling ln(Z):    -407.709379 +/-  0.201964
# Acceptance Rate:                        0.535607
# Replacements:                               6250
# Total Samples:                             11669
# Nested Sampling ln(Z):               -424.062433
# Importance Nested Sampling ln(Z):    -407.640018 +/-  0.196519
# Acceptance Rate:                        0.532544
# Replacements:                               6300
# Total Samples:                             11830
# Nested Sampling ln(Z):               -423.333403
# Importance Nested Sampling ln(Z):    -407.610628 +/-  0.186917
# Acceptance Rate:                        0.530227
# Replacements:                               6350
# Total Samples:                             11976
# Nested Sampling ln(Z):               -422.611170
# Importance Nested Sampling ln(Z):    -407.640546 +/-  0.184742
# Acceptance Rate:                        0.528489
# Replacements:                               6400
# Total Samples:                             12110
# Nested Sampling ln(Z):               -421.910618
# Importance Nested Sampling ln(Z):    -407.684162 +/-  0.184307
# Acceptance Rate:                        0.527607
# Replacements:                               6450
# Total Samples:                             12225
# Nested Sampling ln(Z):               -421.263734
# Importance Nested Sampling ln(Z):    -407.704441 +/-  0.181540
# Acceptance Rate:                        0.526444
# Replacements:                               6500
# Total Samples:                             12347
# Nested Sampling ln(Z):               -420.693786
# Importance Nested Sampling ln(Z):    -407.706696 +/-  0.181006
# Acceptance Rate:                        0.525724
# Replacements:                               6550
# Total Samples:                             12459
# Nested Sampling ln(Z):               -420.160896
# Importance Nested Sampling ln(Z):    -407.738962 +/-  0.180650
# Acceptance Rate:                        0.524559
# Replacements:                               6600
# Total Samples:                             12582
# Nested Sampling ln(Z):               -419.585845
# Importance Nested Sampling ln(Z):    -407.732712 +/-  0.176824
# Acceptance Rate:                        0.522593
# Replacements:                               6650
# Total Samples:                             12725
# Nested Sampling ln(Z):               -419.020541
# Importance Nested Sampling ln(Z):    -407.674431 +/-  0.165218
# Acceptance Rate:                        0.521076
# Replacements:                               6700
# Total Samples:                             12858
# Nested Sampling ln(Z):               -418.480345
# Importance Nested Sampling ln(Z):    -407.722669 +/-  0.166396
# Acceptance Rate:                        0.520151
# Replacements:                               6750
# Total Samples:                             12977
# Nested Sampling ln(Z):               -417.901255
# Importance Nested Sampling ln(Z):    -407.771175 +/-  0.167949
# Acceptance Rate:                        0.519282
# Replacements:                               6800
# Total Samples:                             13095
# Nested Sampling ln(Z):               -417.344324
# Importance Nested Sampling ln(Z):    -407.789969 +/-  0.166927
# Acceptance Rate:                        0.517841
# Replacements:                               6850
# Total Samples:                             13228
# Nested Sampling ln(Z):               -416.840399
# Importance Nested Sampling ln(Z):    -407.836161 +/-  0.168928
# Acceptance Rate:                        0.517048
# Replacements:                               6900
# Total Samples:                             13345
# Nested Sampling ln(Z):               -416.384628
# Importance Nested Sampling ln(Z):    -407.723369 +/-  0.158359
# Acceptance Rate:                        0.515617
# Replacements:                               6950
# Total Samples:                             13479
# Nested Sampling ln(Z):               -415.955192
# Importance Nested Sampling ln(Z):    -407.694465 +/-  0.152032
# Acceptance Rate:                        0.515464
# Replacements:                               7000
# Total Samples:                             13580
# Nested Sampling ln(Z):               -415.535553
# Importance Nested Sampling ln(Z):    -407.667111 +/-  0.146815
# Acceptance Rate:                        0.515464
# Replacements:                               7050
# Total Samples:                             13677
# Nested Sampling ln(Z):               -415.148553
# Importance Nested Sampling ln(Z):    -407.669183 +/-  0.144542
# Acceptance Rate:                        0.514605
# Replacements:                               7100
# Total Samples:                             13797
# Nested Sampling ln(Z):               -414.776743
# Importance Nested Sampling ln(Z):    -407.699896 +/-  0.145727
# Acceptance Rate:                        0.513649
# Replacements:                               7150
# Total Samples:                             13920
# Nested Sampling ln(Z):               -414.421930
# Importance Nested Sampling ln(Z):    -407.659135 +/-  0.140897
# Acceptance Rate:                        0.513332
# Replacements:                               7200
# Total Samples:                             14026
# Nested Sampling ln(Z):               -414.071055
# Importance Nested Sampling ln(Z):    -407.686673 +/-  0.141540
# Acceptance Rate:                        0.512911
# Replacements:                               7250
# Total Samples:                             14135
# Nested Sampling ln(Z):               -413.746790
# Importance Nested Sampling ln(Z):    -407.706059 +/-  0.141193
# Acceptance Rate:                        0.511742
# Replacements:                               7300
# Total Samples:                             14265
# Nested Sampling ln(Z):               -413.445495
# Importance Nested Sampling ln(Z):    -407.699709 +/-  0.139450
# Acceptance Rate:                        0.510736
# Replacements:                               7350
# Total Samples:                             14391
# Nested Sampling ln(Z):               -413.156146
# Importance Nested Sampling ln(Z):    -407.722748 +/-  0.139768
# Acceptance Rate:                        0.509572
# Replacements:                               7400
# Total Samples:                             14522
# Nested Sampling ln(Z):               -412.882937
# Importance Nested Sampling ln(Z):    -407.733624 +/-  0.139623
# Acceptance Rate:                        0.508810
# Replacements:                               7450
# Total Samples:                             14642
# Nested Sampling ln(Z):               -412.616662
# Importance Nested Sampling ln(Z):    -407.708351 +/-  0.136067
# Acceptance Rate:                        0.507134
# Replacements:                               7500
# Total Samples:                             14789
# Nested Sampling ln(Z):               -412.356617
# Importance Nested Sampling ln(Z):    -407.703006 +/-  0.133889
# Acceptance Rate:                        0.506134
# Replacements:                               7550
# Total Samples:                             14917
# Nested Sampling ln(Z):               -412.108624
# Importance Nested Sampling ln(Z):    -407.664831 +/-  0.129021
# Acceptance Rate:                        0.505655
# Replacements:                               7600
# Total Samples:                             15030
# Nested Sampling ln(Z):               -411.866906
# Importance Nested Sampling ln(Z):    -407.652578 +/-  0.127396
# Acceptance Rate:                        0.505251
# Replacements:                               7650
# Total Samples:                             15141
# Nested Sampling ln(Z):               -411.632076
# Importance Nested Sampling ln(Z):    -407.665936 +/-  0.127409
# Acceptance Rate:                        0.503663
# Replacements:                               7700
# Total Samples:                             15288
# Nested Sampling ln(Z):               -411.405623
# Importance Nested Sampling ln(Z):    -407.685041 +/-  0.128674
# Acceptance Rate:                        0.503279
# Replacements:                               7750
# Total Samples:                             15399
# Nested Sampling ln(Z):               -411.194183
# Importance Nested Sampling ln(Z):    -407.689670 +/-  0.128266
# Acceptance Rate:                        0.502577
# Replacements:                               7800
# Total Samples:                             15520
# Nested Sampling ln(Z):               -410.994484
# Importance Nested Sampling ln(Z):    -407.676690 +/-  0.125871
# Acceptance Rate:                        0.502047
# Replacements:                               7850
# Total Samples:                             15636
# Nested Sampling ln(Z):               -410.800416
# Importance Nested Sampling ln(Z):    -407.678782 +/-  0.125462
# Acceptance Rate:                        0.502289
# Replacements:                               7900
# Total Samples:                             15728
# Nested Sampling ln(Z):               -410.614908
# Importance Nested Sampling ln(Z):    -407.674995 +/-  0.124336
# Acceptance Rate:                        0.500756
# Replacements:                               7950
# Total Samples:                             15876
# Nested Sampling ln(Z):               -410.438228
# Importance Nested Sampling ln(Z):    -407.695647 +/-  0.125603
# Acceptance Rate:                        0.499500
# Replacements:                               8000
# Total Samples:                             16016
# Nested Sampling ln(Z):               -410.274822
# Importance Nested Sampling ln(Z):    -407.715172 +/-  0.126915
# Acceptance Rate:                        0.498792
# Replacements:                               8050
# Total Samples:                             16139
# Nested Sampling ln(Z):               -410.116774
# Importance Nested Sampling ln(Z):    -407.724589 +/-  0.127405
# Acceptance Rate:                        0.498462
# Replacements:                               8100
# Total Samples:                             16250
# Nested Sampling ln(Z):               -409.970391
# Importance Nested Sampling ln(Z):    -407.705302 +/-  0.124856
# Acceptance Rate:                        0.498014
# Replacements:                               8150
# Total Samples:                             16365
# Nested Sampling ln(Z):               -409.835200
# Importance Nested Sampling ln(Z):    -407.726479 +/-  0.126693
# Acceptance Rate:                        0.497694
# Replacements:                               8200
# Total Samples:                             16476
# Nested Sampling ln(Z):               -409.707826
# Importance Nested Sampling ln(Z):    -407.714633 +/-  0.124801
# Acceptance Rate:                        0.497347
# Replacements:                               8250
# Total Samples:                             16588
# Nested Sampling ln(Z):               -409.585007
# Importance Nested Sampling ln(Z):    -407.725396 +/-  0.125629
# Acceptance Rate:                        0.496233
# Replacements:                               8300
# Total Samples:                             16726
# Nested Sampling ln(Z):               -409.465960
# Importance Nested Sampling ln(Z):    -407.739180 +/-  0.126739
# Acceptance Rate:                        0.494815
# Replacements:                               8350
# Total Samples:                             16875
# Nested Sampling ln(Z):               -409.354706
# Importance Nested Sampling ln(Z):    -407.729646 +/-  0.125244
# Acceptance Rate:                        0.493566
# Replacements:                               8400
# Total Samples:                             17019
# Nested Sampling ln(Z):               -409.249660
# Importance Nested Sampling ln(Z):    -407.741294 +/-  0.126182
# Acceptance Rate:                        0.492453
# Replacements:                               8450
# Total Samples:                             17159
# Nested Sampling ln(Z):               -409.152184
# Importance Nested Sampling ln(Z):    -407.748049 +/-  0.126640
# Acceptance Rate:                        0.491386
# Replacements:                               8500
# Total Samples:                             17298
# Nested Sampling ln(Z):               -409.059416
# Importance Nested Sampling ln(Z):    -407.759279 +/-  0.127586
# Acceptance Rate:                        0.491295
# Replacements:                               8550
# Total Samples:                             17403
# Nested Sampling ln(Z):               -408.971537
# Importance Nested Sampling ln(Z):    -407.749388 +/-  0.126173
# Acceptance Rate:                        0.489777
# Replacements:                               8600
# Total Samples:                             17559
# Nested Sampling ln(Z):               -408.888783
# Importance Nested Sampling ln(Z):    -407.754772 +/-  0.126455
# Acceptance Rate:                        0.488645
# Replacements:                               8650
# Total Samples:                             17702
# Nested Sampling ln(Z):               -408.808321
# Importance Nested Sampling ln(Z):    -407.756394 +/-  0.126402
# Acceptance Rate:                        0.488407
# Replacements:                               8700
# Total Samples:                             17813
# Nested Sampling ln(Z):               -408.731502
# Importance Nested Sampling ln(Z):    -407.750128 +/-  0.125451
# Acceptance Rate:                        0.488063
# Replacements:                               8750
# Total Samples:                             17928
# Nested Sampling ln(Z):               -408.658007
# Importance Nested Sampling ln(Z):    -407.752679 +/-  0.125556
# Acceptance Rate:                        0.487346
# Replacements:                               8800
# Total Samples:                             18057
# Nested Sampling ln(Z):               -408.589262
# Importance Nested Sampling ln(Z):    -407.735795 +/-  0.123391
# Acceptance Rate:                        0.487040
# Replacements:                               8850
# Total Samples:                             18171
# Nested Sampling ln(Z):               -408.523720
# Importance Nested Sampling ln(Z):    -407.733233 +/-  0.122887
# Acceptance Rate:                        0.485994
# Replacements:                               8900
# Total Samples:                             18313
# Nested Sampling ln(Z):               -408.461492
# Importance Nested Sampling ln(Z):    -407.736127 +/-  0.123029
# Acceptance Rate:                        0.485279
# Replacements:                               8950
# Total Samples:                             18443
# Nested Sampling ln(Z):               -408.401360
# Importance Nested Sampling ln(Z):    -407.738347 +/-  0.123142
# Acceptance Rate:                        0.484731
# Replacements:                               9000
# Total Samples:                             18567
# Nested Sampling ln(Z):               -408.343816
# Importance Nested Sampling ln(Z):    -407.736280 +/-  0.122774
# Acceptance Rate:                        0.484683
# Replacements:                               9050
# Total Samples:                             18672
# Nested Sampling ln(Z):               -408.289193
# Importance Nested Sampling ln(Z):    -407.735675 +/-  0.122586
# Acceptance Rate:                        0.484532
# Replacements:                               9100
# Total Samples:                             18781
# Nested Sampling ln(Z):               -408.236430
# Importance Nested Sampling ln(Z):    -407.736280 +/-  0.122531
# Acceptance Rate:                        0.483615
# Replacements:                               9150
# Total Samples:                             18920
# Nested Sampling ln(Z):               -408.186373
# Importance Nested Sampling ln(Z):    -407.740636 +/-  0.122928
# Acceptance Rate:                        0.482509
# Replacements:                               9200
# Total Samples:                             19067
# Nested Sampling ln(Z):               -408.139625
# Importance Nested Sampling ln(Z):    -407.745499 +/-  0.123394
# Acceptance Rate:                        0.481019
# Replacements:                               9250
# Total Samples:                             19230
# Nested Sampling ln(Z):               -408.095705
# Importance Nested Sampling ln(Z):    -407.755365 +/-  0.124467
# Acceptance Rate:                        0.480297
# Replacements:                               9300
# Total Samples:                             19363
# Nested Sampling ln(Z):               -408.054422
# Importance Nested Sampling ln(Z):    -407.753857 +/-  0.124199
# Acceptance Rate:                        0.479463
# Replacements:                               9350
# Total Samples:                             19501
# Nested Sampling ln(Z):               -408.015291
# Importance Nested Sampling ln(Z):    -407.758302 +/-  0.124654
# Acceptance Rate:                        0.478566
# Replacements:                               9400
# Total Samples:                             19642
# Nested Sampling ln(Z):               -407.977981
# Importance Nested Sampling ln(Z):    -407.759519 +/-  0.124732
# Acceptance Rate:                        0.477924
# Replacements:                               9450
# Total Samples:                             19773
# Nested Sampling ln(Z):               -407.942470
# Importance Nested Sampling ln(Z):    -407.764608 +/-  0.125297
# Acceptance Rate:                        0.477555
# Replacements:                               9500
# Total Samples:                             19893
# Nested Sampling ln(Z):               -407.909018
# Importance Nested Sampling ln(Z):    -407.768039 +/-  0.125667
# Acceptance Rate:                        0.477261
# Replacements:                               9550
# Total Samples:                             20010
# Nested Sampling ln(Z):               -407.877414
# Importance Nested Sampling ln(Z):    -407.771936 +/-  0.126105
# Acceptance Rate:                        0.477185
# Replacements:                               9600
# Total Samples:                             20118
# Nested Sampling ln(Z):               -407.847460
# Importance Nested Sampling ln(Z):    -407.775343 +/-  0.126489
# Acceptance Rate:                        0.476237
# Replacements:                               9650
# Total Samples:                             20263
# Nested Sampling ln(Z):               -407.819328
# Importance Nested Sampling ln(Z):    -407.778376 +/-  0.126822
# Acceptance Rate:                        0.475653
# Replacements:                               9700
# Total Samples:                             20393
# Nested Sampling ln(Z):               -407.792884
# Importance Nested Sampling ln(Z):    -407.779251 +/-  0.126895
# Acceptance Rate:                        0.474360
# Replacements:                               9750
# Total Samples:                             20554
# Nested Sampling ln(Z):               -407.767873
# Importance Nested Sampling ln(Z):    -407.783912 +/-  0.127442
# Acceptance Rate:                        0.473842
# Replacements:                               9800
# Total Samples:                             20682
# Nested Sampling ln(Z):               -407.744501
# Importance Nested Sampling ln(Z):    -407.784913 +/-  0.127541
# Acceptance Rate:                        0.472989
# Replacements:                               9850
# Total Samples:                             20825
# Nested Sampling ln(Z):               -407.722507
# Importance Nested Sampling ln(Z):    -407.785515 +/-  0.127590
# Acceptance Rate:                        0.471271
# Replacements:                               9900
# Total Samples:                             21007
# Nested Sampling ln(Z):               -407.701719
# Importance Nested Sampling ln(Z):    -407.790431 +/-  0.128185
# Acceptance Rate:                        0.470984
# Replacements:                               9950
# Total Samples:                             21126
# Nested Sampling ln(Z):               -407.682240
# Importance Nested Sampling ln(Z):    -407.790820 +/-  0.128217
# Acceptance Rate:                        0.470455
# Replacements:                              10000
# Total Samples:                             21256
# Nested Sampling ln(Z):               -407.663849
# Importance Nested Sampling ln(Z):    -407.791213 +/-  0.128250
# Acceptance Rate:                        0.469451
# Replacements:                              10050
# Total Samples:                             21408
# Nested Sampling ln(Z):               -407.646493
# Importance Nested Sampling ln(Z):    -407.792031 +/-  0.128337
# Acceptance Rate:                        0.469156
# Replacements:                              10100
# Total Samples:                             21528
# Nested Sampling ln(Z):               -407.630039
# Importance Nested Sampling ln(Z):    -407.792674 +/-  0.128406
# Acceptance Rate:                        0.468419
# Replacements:                              10123
# Total Samples:                             21611
# Nested Sampling ln(Z):               -407.622750
# Importance Nested Sampling ln(Z):    -407.794558 +/-  0.128639
#   analysing data from /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_5nestHII/hii_.txt
#  ln(ev)=  -407.38911169909380      +/-  0.14578211813981723
#  Total Likelihood Evaluations:        21611
#  Sampling finished. Exiting MultiNest

# %%
print("\nEvidence lnZ = %.3f ± %.3f" % (result["logZ"], result["logZerr"]))

samples = result["samples"]   # shape = (Nsamples, 5)
parameters = [r"\alpha", r"\beta", r"h",r"\Omega_m",r"w_{DE}"]
print("Posterior means/stdev:")
for name, col in zip(parameters, samples.T):
    print(f"{name:>6s}: {col.mean():.3f} ± {col.std():.3f}")

# Guarda nombres para scripts auxiliares
with open(prefix + "params.json", "w") as f:
    json.dump(parameters, f, indent=2)


fig = corner.corner(
    samples,
    labels=[r"$\alpha$", r"$\beta$", r"$h$",r"\Omega_m",r"w_{DE}"],
    show_titles=True,
    title_fmt=".3f",
    quantiles=[0.16, 0.5, 0.84]
)
fig.savefig(prefix + "corner.png", dpi=150, bbox_inches="tight")
plt.close(fig)
print("Corner guardado en:", prefix + "corner.png")
# Out:
# Evidence lnZ = -407.389 ± 0.146
# Posterior means/stdev:
# \alpha: 33.231 ± 0.139
#  \beta: 5.034 ± 0.114
#      h: 0.718 ± 0.040
# \Omega_m: 0.271 ± 0.112
# w_{DE}: -0.997 ± 0.406
# Corner guardado en: /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_5nestHII/hii_corner.png

# %%
gds = MCSamples(
    samples=samples,
    names=["alpha", "beta", "h","Om","wDE"],
    labels=[r"\alpha", r"\beta", r"h",r"\Omega_m",r"w_{DE}"]  # SIN '$', GetDist los añade
)
g = plots.getSubplotPlotter()
g.settings.num_plot_contours = 3
g.triangle_plot([gds], filled=True, title_limit=1)
g.export(prefix + "triangle_getdist.png")
print("GetDist triangle en:", prefix + "triangle_getdist.png")

print("\nListo. Archivos en:", outdir)
# Out:
# Removed no burn in
# GetDist triangle en: /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_5nestHII/hii_triangle_getdist.png
#
# Listo. Archivos en: /home/holman//MCMC/ZEUS/h0wsh2023/dat/results_5nestHII
