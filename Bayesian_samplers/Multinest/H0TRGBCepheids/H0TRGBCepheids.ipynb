# %%
from astroquery.ipac.ned import Ned as NED
result_table = NED.get_table("LMC", table='positions')
#print(result_table)
result_table
# Out:
# <Table length=34>
#  No.        RA       ... Published Frequence Mode     Qualifiers
#                      ...
# int32     object     ...          object                object
# ----- -------------- ... ------------------------ ------------------
#     0   05h23m34.60s ...
#     1 05h23m34.5300s ...                            Uncertain origin
#     2 05h23m34.5300s ...                            Uncertain origin
#     3 05h23m34.6000s ...                            Uncertain origin
#     4 05h23m34.6000s ...                            Uncertain origin
#     5 05h23m34.6000s ...                            Uncertain origin
#     6 05h23m34.6000s ...                            Uncertain origin
#     7 05h23m34.0000s ...                            Uncertain origin
#     8 05h23m34.4000s ...                            Uncertain origin
#   ...            ... ...                      ...                ...
#    24   05h23m34.50s ...                            Uncertain origin
#    25   05h23m34.52s ...   Broad-band measurement From new, raw data
#    26    05h23m34.6s ...                            Uncertain origin
#    27    05h23m34.5s ...                            Uncertain origin
#    28    05h23m34.6s ...                            Uncertain origin
#    29    05h23m34.6s ...                            Uncertain origin
#    30    05h23m34.6s ...                            Uncertain origin
#    31    05h23m34.6s ...                            Uncertain origin
#    32    05h23m34.5s ...                            Uncertain origin
#    33      05h23m34s ...                            Uncertain origin

# %%
#!pip install pyfiglet
#!pip install colorama


from colorama import Fore
import pyfiglet

font = pyfiglet.figlet_format("EVOL")
print(Fore.RED+font)

ascii_art = pyfiglet.figlet_format("STARLIGHT")
print(ascii_art)
# Out:
#  _______     _____  _
# | ____\ \   / / _ \| |
# |  _|  \ \ / / | | | |
# | |___  \ V /| |_| | |___
# |_____|  \_/  \___/|_____|
#
#
#  ____ _____  _    ____  _     ___ ____ _   _ _____
# / ___|_   _|/ \  |  _ \| |   |_ _/ ___| | | |_   _|
# \___ \ | | / _ \ | |_) | |    | | |  _| |_| | | |
#  ___) || |/ ___ \|  _ <| |___ | | |_| |  _  | | |
# |____/ |_/_/   \_\_| \_\_____|___\____|_| |_| |_|
