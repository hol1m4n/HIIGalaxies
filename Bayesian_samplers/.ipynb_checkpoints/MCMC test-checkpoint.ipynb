# %% [markdown]
# ## Import libraries

# %%
import matplotlib
#matplotlib.use('Agg')
import matplotlib.pyplot as plt

import os
from astropy.table import Table
from astropy.cosmology import FlatwCDM
import emcee
import numpy as np
import corner
import scipy.optimize as op
import pandas as pd

# %% [markdown]
# ## Data adquisition

# %%
def h2gdat(dpath):
    tpath = dpath + 'indat/h2data.dat'
    data = Table.read(tpath, format='ascii')

    vx = data['col4']
    vxErr = data['col5']
    vy = data['col6']
    vyErr = data['col7']
    vz = data['col2']
    vzErr = data['col3']
    return vx, vxErr, vy, vyErr, vz, vzErr

# %%
# Main Code
#mcd = os.path.dirname(os.path.abspath(__file__))

mcd = os.getcwd()

dpath = mcd + '/dat/'

# Reading Data
vx, vxErr, vy, vyErr, vz, vzErr = h2gdat(dpath)

# %%
data = {'Id': np.arange(0,189,1),
        r'F(H$\beta$)': vy,
        r'Error F(H$\beta$)': vyErr,
        r'$\sigma$': vx,
        r'Error $\sigma$': vxErr,
        r'$z$': vz,
        r'Error $z$': vzErr}
DF = pd.DataFrame(data)
DF[r'We $z$'] = (DF[r'Error $z$'] / DF[r'$z$'] ) * 100

#plt.hist(DF['$z$'], bins = 100)
GEHR = DF[DF['$z$'] > 10]
len(GEHR)
HIIG = DF[DF['$z$'] < 10]
#plt.hist(HIIG['$z$'], bins = 100)
len(HIIG)
#plt.bar(np.arange(1,154,1),HIIG[r'Error $z$'])
# Out:
# 153

# %%
'''

plt.errorbar( x = HIIG[r'$\sigma$'][HIIG['$z$'] < 0.5] ,
             y = HIIG[r'F(H$\beta$)'][HIIG['$z$'] <0.5], 
             xerr = HIIG[r'Error $\sigma$'][HIIG['$z$'] < 0.5] , 
             yerr = HIIG[r'Error F(H$\beta$)'][HIIG['$z$'] < 0.5],
            fmt = '.')
plt.errorbar( x = HIIG[r'$\sigma$'][HIIG['$z$'] > 0.5] ,
             y = HIIG[r'F(H$\beta$)'][HIIG['$z$']  > 0.5], 
             xerr = HIIG[r'Error $\sigma$'][HIIG['$z$'] > 0.5] , 
             yerr = HIIG[r'Error F(H$\beta$)'][HIIG['$z$'] > 0.5],
            fmt = '.')
plt.errorbar( x = GEHR[r'$\sigma$'] ,
             y = GEHR[r'F(H$\beta$)'], 
             xerr = GEHR[r'Error $\sigma$'] , 
             yerr = GEHR[r'Error F(H$\beta$)'],
            fmt = '.')

'''
# Out:
# "\n\nplt.errorbar( x = HIIG[r'$\\sigma$'][HIIG['$z$'] < 0.5] ,\n             y = HIIG[r'L(H$\x08eta$)'][HIIG['$z$'] <0.5], \n             xerr = HIIG[r'Error $\\sigma$'][HIIG['$z$'] < 0.5] , \n             yerr = HIIG[r'Error L(H$\x08eta$)'][HIIG['$z$'] < 0.5],\n            fmt = '.')\nplt.errorbar( x = HIIG[r'$\\sigma$'][HIIG['$z$'] > 0.5] ,\n             y = HIIG[r'L(H$\x08eta$)'][HIIG['$z$']  > 0.5], \n             xerr = HIIG[r'Error $\\sigma$'][HIIG['$z$'] > 0.5] , \n             yerr = HIIG[r'Error L(H$\x08eta$)'][HIIG['$z$'] > 0.5],\n            fmt = '.')\nplt.errorbar( x = GEHR[r'$\\sigma$'] ,\n             y = GEHR[r'L(H$\x08eta$)'], \n             xerr = GEHR[r'Error $\\sigma$'] , \n             yerr = GEHR[r'Error L(H$\x08eta$)'],\n            fmt = '.')\n\n"

# %% [markdown]
# ## F(x)'s

# %%
def lnlike(theta, x, y, z, xerr, yerr, zerr):
    alpha, beta, h0, Om, w0 = theta

    cosmo = FlatwCDM(H0=h0*100, Om0=Om, w0=w0)
    ixG = np.where(z > 10)
    ixH = np.where(z < 10)

    Mum = z*0.0
    MumErr = z*0.0

    Mum[ixG] = z[ixG]
    MumErr[ixG] = zerr[ixG]

    Mum[ixH] = 5.0*np.log10(cosmo.luminosity_distance(z[ixH]).value) + 25.0
    MumErr[ixH] = (5.0/np.log(10.0))*(zerr[ixH]/z[ixH])

    Mu = 2.5*(beta*x + alpha) - 2.5*y - 100.195
    MuErr = 2.5*np.sqrt((yerr)**2 + beta**2*(xerr)**2)

    R = (Mu - Mum)
    W = 1.0/(MuErr**2 + MumErr**2)

    xsq = np.sum(R**2*W)
    llq = -0.5*xsq
    return (llq, xsq, R, Mum)
def lnprior(theta):
    alpha, beta, h0, Om, w0 = theta
    if (0.0 <= beta <= 10.0 and 20.0 <= alpha <= 40.0 and 0.5 <= h0 <= 1.0
            and 0.0 <= Om <= 1.0 and -2.0 <= w0 <= 0.0):
        return 0.0
    return -np.inf
def lnprob(theta, x, y, z, xerr, yerr, zerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, x, y, z, xerr, yerr, zerr)[0]

# %% [markdown]
# ## Sample

# %%
sample = DF[((DF['$z$'] >= 0.0) & (DF['$z$'] <= 0.5)) | (DF['$z$'] > 10)] # Redshift para HIIG menor a 0.5
plt.hist(DF['$z$'], bins = 100, range = [0,2.5])
plt.title('Solo HIIG')
plt.xlabel(r'$z$')
plt.ylabel(r'N')
plt.show()

# %%
new_sample = Table.from_pandas(sample) #Definicion de la muestra que tomara MCMC

# %%
# First guess
ialpha = 33.0
ibeta = 5.0
ih0 = 0.7
iOm = 0.3
iw0 = -1.0

# %%
# Maximum Likelihood
nll = lambda *args: -lnlike(*args)[0]
result = op.minimize(nll, [ialpha, ibeta, ih0,iOm,iw0],
                    args=(new_sample[r'$\sigma$'],
                        new_sample[r'F(H$\beta$)'],
                        new_sample[r'$z$'],
                        new_sample[r'Error $\sigma$'],
                        new_sample[r'Error F(H$\beta$)'],
                        new_sample[r'Error $z$']))
alpha_ml, beta_ml, h0_ml, iOm_ml, iw0_ml = result["x"]

print('max llq')
print(alpha_ml)
print(beta_ml)
print(h0_ml)
print(iOm_ml)
print(iw0_ml)
# Out:
# /tmp/ipykernel_43937/47896359.py:14: RuntimeWarning: invalid value encountered in log10
#   Mum[ixH] = 5.0*np.log10(cosmo.luminosity_distance(z[ixH]).value) + 25.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Maximum Likelihood
#       2 nll = lambda *args: -lnlike(*args)[0]
# ----> 3 result = op.minimize(nll, [ialpha, ibeta, ih0,iOm,iw0],
#       4                     args=(new_sample[r'$\sigma$'],
#       5                         new_sample[r'F(H$\beta$)'],
#       6                         new_sample[r'$z$'],
#       7                         new_sample[r'Error $\sigma$'],
#       8                         new_sample[r'Error F(H$\beta$)'],
#       9                         new_sample[r'Error $z$']))
#      10 alpha_ml, beta_ml, h0_ml, iOm_ml, iw0_ml = result["x"]
#      12 print('max llq')
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_minimize.py:705, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704 elif meth == 'bfgs':
# --> 705     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     706 elif meth == 'newton-cg':
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1445, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1442 pk = -np.dot(Hk, gfk)
#    1443 try:
#    1444     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1445              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1446                                   old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1447 except _LineSearchError:
#    1448     # Line search failed to find a better solution.
#    1449     warnflag = 2
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1215, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1201 """
#    1202 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1203 suitable step length is not found, and raise an exception if a
#    (...)
#    1210
#    1211 """
#    1213 extra_condition = kwargs.pop('extra_condition', None)
# -> 1215 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1216                          old_fval, old_old_fval,
#    1217                          **kwargs)
#    1219 if ret[0] is not None and extra_condition is not None:
#    1220     xp1 = xk + ret[0] * pk
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:84, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      80     return np.dot(gval[0], pk)
#      82 derphi0 = np.dot(gfk, pk)
# ---> 84 stp, fval, old_fval = scalar_search_wolfe1(
#      85         phi, derphi, old_fval, old_old_fval, derphi0,
#      86         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      88 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:160, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     158 if task[:2] == b'FG':
#     159     alpha1 = stp
# --> 160     phi1 = phi(stp)
#     161     derphi1 = derphi(stp)
#     162 else:
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:75, in line_search_wolfe1.<locals>.phi(s)
#      73 def phi(s):
#      74     fc[0] += 1
# ---> 75     return f(xk + s*pk, *args)
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction.fun(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 return self.f
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# Cell In[11], line 2, in <lambda>(*args)
#       1 # Maximum Likelihood
# ----> 2 nll = lambda *args: -lnlike(*args)[0]
#       3 result = op.minimize(nll, [ialpha, ibeta, ih0,iOm,iw0],
#       4                     args=(new_sample[r'$\sigma$'],
#       5                         new_sample[r'F(H$\beta$)'],
#    (...)
#       8                         new_sample[r'Error F(H$\beta$)'],
#       9                         new_sample[r'Error $z$']))
#      10 alpha_ml, beta_ml, h0_ml, iOm_ml, iw0_ml = result["x"]
#
# Cell In[7], line 4, in lnlike(theta, x, y, z, xerr, yerr, zerr)
#       1 def lnlike(theta, x, y, z, xerr, yerr, zerr):
#       2     alpha, beta, h0, Om, w0 = theta
# ----> 4     cosmo = FlatwCDM(H0=h0*100, Om0=Om, w0=w0)
#       5     ixG = np.where(z > 10)
#       6     ixH = np.where(z < 10)
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/flrw/w0cdm.py:317, in FlatwCDM.__init__(self, H0, Om0, w0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#     304 def __init__(
#     305     self,
#     306     H0,
#    (...)
#     315     meta=None
#     316 ):
# --> 317     super().__init__(
#     318         H0=H0,
#     319         Om0=Om0,
#     320         Ode0=0.0,
#     321         w0=w0,
#     322         Tcmb0=Tcmb0,
#     323         Neff=Neff,
#     324         m_nu=m_nu,
#     325         Ob0=Ob0,
#     326         name=name,
#     327         meta=meta,
#     328     )
#     330     # Please see :ref:`astropy-cosmology-fast-integrals` for discussion
#     331     # about what is being done here.
#     332     if self._Tcmb0.value == 0:
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/flrw/base.py:1495, in FlatFLRWMixin.__init__(self, *args, **kw)
#    1494 def __init__(self, *args, **kw):
# -> 1495     super().__init__(*args, **kw)  # guaranteed not to have `Ode0`
#    1496     # Do some twiddling after the fact to get flatness
#    1497     self._Ok0 = 0.0
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/flrw/w0cdm.py:97, in wCDM.__init__(self, H0, Om0, Ode0, w0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#      83 def __init__(
#      84     self,
#      85     H0,
#    (...)
#      95     meta=None
#      96 ):
# ---> 97     super().__init__(
#      98         H0=H0,
#      99         Om0=Om0,
#     100         Ode0=Ode0,
#     101         Tcmb0=Tcmb0,
#     102         Neff=Neff,
#     103         m_nu=m_nu,
#     104         Ob0=Ob0,
#     105         name=name,
#     106         meta=meta,
#     107     )
#     108     self.w0 = w0
#     110     # Please see :ref:`astropy-cosmology-fast-integrals` for discussion
#     111     # about what is being done here.
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/flrw/base.py:174, in FLRW.__init__(self, H0, Om0, Ode0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#     172 # Assign (and validate) Parameters
#     173 self.H0 = H0
# --> 174 self.Om0 = Om0
#     175 self.Ode0 = Ode0
#     176 self.Tcmb0 = Tcmb0
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/parameter.py:138, in Parameter.__set__(self, cosmology, value)
#     135     raise AttributeError(f"can't set attribute {self._attr_name} again")
#     137 # Validate value, generally setting units if present
# --> 138 value = self.validate(cosmology, copy.deepcopy(value))
#     140 # Make the value read-only, if ndarray-like
#     141 if hasattr(value, "setflags"):
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/parameter.py:186, in Parameter.validate(self, cosmology, value)
#     171 def validate(self, cosmology, value):
#     172     """Run the validator on this Parameter.
#     173
#     174     Parameters
#    (...)
#     184         (yes, that parameter order).
#     185     """
# --> 186     return self.fvalidate(cosmology, self, value)
#
# File ~/miniconda3/envs/cosmos/lib/python3.11/site-packages/astropy/cosmology/parameter.py:373, in _validate_non_negative(cosmology, param, value)
#     371 value = _validate_to_float(cosmology, param, value)
#     372 if value < 0.0:
# --> 373     raise ValueError(f"{param.name} cannot be negative.")
#     374 return value
#
# ValueError: Om0 cannot be negative.

# %% [markdown]
# ## MCMC

# %%
# MCMC
ndim, nwalkers = 5, 100
pos = [[ialpha, ibeta, ih0, iOm, iw0] + 1e-5*np.random.randn(ndim)
       for i in range(nwalkers)]

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob,
                                args=(new_sample[r'$\sigma$'], 
                                      new_sample[r'F(H$\beta$)'],
                                      new_sample[r'$z$'],
                                      new_sample[r'Error $\sigma$'],
                                      new_sample[r'Error F(H$\beta$)'],
                                      new_sample[r'Error $z$']),
                                threads=16)

# %%
# Run 100 steps as a burn-in.
pos, prob, state = sampler.run_mcmc(pos, 100)

# %%
# Reset the chain to remove the burn-in samples.
sampler.reset()

# Starting from the final position in the burn-in chain
sampler.run_mcmc(pos, 1000, rstate0=state)

print("Mean acceptance fraction: {0:.3f}"
      .format(np.mean(sampler.acceptance_fraction)))

samples = sampler.flatchain
lnprob = sampler.flatlnprobability
# Out:
# Mean acceptance fraction: 0.459

# %%
alpha_mcmc, beta_mcmc, h0_mcmc, Om_mcmc, w0_mcmc = map(
                                 lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                                 zip(*np.percentile(samples, [16, 50, 84],
                                                    axis=0)))

# %% [markdown]
# ## Corner

# %%
print('mcmc')
print(alpha_mcmc)
print(beta_mcmc)
print(h0_mcmc)
print(Om_mcmc)
print(w0_mcmc)
print(len(vx))

# Plot
path = dpath+'results/trploth0.pdf'
# Out:
# mcmc
# (33.33178359806128, 0.14124966347908696, 0.14555869527661258)
# (4.950748897381324, 0.12013613948174484, 0.11584792924346754)
# (0.7303139099364612, 0.04268049676849561, 0.040400064970599114)
# (0.6368245550508466, 0.2589854221304133, 0.3798086933370598)
# (-0.7918304749719398, 0.5751462590336631, 0.763521589665459)
# 189

# %%
fig = corner.corner(samples,
                    labels=["$\\alpha$", "$\\beta$", "$h_0$", "$\Omega_m$",
                            "$w_0$"],
                    truths=[alpha_mcmc[0],  beta_mcmc[0], h0_mcmc[0],
                            Om_mcmc[0], w0_mcmc[0]],
                    quantiles=[0.16, 0.50, 0.84],
                    plot_contours='true',
                    levels=1.0 - np.exp(
                        -0.5 * np.arange(1.0, 3.1, 1.0) ** 2),
                    smooth=1.0,
                    bins=100,
                    color='black',
                    show_titles=1)
plt.savefig(path)
