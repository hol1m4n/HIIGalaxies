# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
#import emcee

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import getdist
import IPython
from getdist import plots, MCSamples
from getdist import loadMCSamples

font = {'size'   : 15, 'family':'sans-serif'}
axislabelfontsize='large'
matplotlib.rc('font', **font)
matplotlib.rc('text', usetex=True)

np.infty = np.inf 

plt.rcParams["text.usetex"] = False  # Desactiva LaTeX externo

# %%
# Aqui, keys es como vamos a llamar a cada modelo en el codigo, 
# dirs el directorio de las cadenas, y legends lo que aparecera en las graficas
root_path = '/home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/'
keys=['test'] 
list_of_dirs=['chains/desi_bao/desi_theta',
              ]
list_of_legends = ['desi'
                   ]
dirs=dict(zip(keys,list_of_dirs))
legends = dict(zip(keys,list_of_legends))

# %%
model_name = ['desi']

samples = {}
params = {}
for model in keys:
    if model != model_name:
        samples[model] = loadMCSamples(root_path + dirs[model],
                                       settings={'ignore_rows':0.3,'smooth_scale_2D':0.6,'smooth_scale_1D':0.6},
                                       no_cache=True)

        params[model] = samples[model].getParams()

        # Agregar parametros derivados comunes
        #samples[model].addDerived(params[model].sfdm_parameters__1, name='m_sfd', label=r'$m_{\phi}$')
        #samples[model].addDerived(params[model].Omega_sfdm_1, name='O_sfdm', label=r'$\Omega_{sfdm}$')
       
        samples[model].addDerived(params[model].H0, name='Hdot', label=r'$H_0$', range=[67.2,None])
# Out:
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.1.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.2.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.3.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.4.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.5.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.6.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.7.txt
# /home/holman/HIIGalaxies/Bayesian_samplers/Cobaya/chains/desi_bao/desi_theta.8.txt
# Removed 0.3 as burn in

# %%
#Aqui escribo a una tabla
print(samples['test'].getTable(limit=1,paramList=['H0','omega_cdm','Omega_m',
                                                  'n_s', 'Omega_Lambda']).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$n_\mathrm{s}   $} & $0.9704\pm 0.0034          $\\
#
# {\boldmath$\Omega_\mathrm{c} h^2$} & $0.11761\pm 0.00064        $\\
#
# $H_0                       $ & $68.44\pm 0.29             $\\
#
# $\Omega_\mathrm{m}         $ & $0.3006\pm 0.0037          $\\
#
# $\Omega_\Lambda            $ & $0.6993\pm 0.0037          $\\
# \hline
# \end{tabular}

# %%
g = plots.get_subplot_plotter()
#g.set_legend(param1,param2)
subkey=['test']
subsample=[samples[model] for model in subkey]
sublegend = [legends[model] for model in subkey]
g.triangle_plot(subsample,['H0', 'Omega_m', 'Omega_Lambda'],colored_text=True
                ,filled=True, shaded=False,legend_labels=sublegend,
               contour_colors=['#A020F0'],contour_lws=1.6)
plt.savefig('test.pdf')
# Out:
# WARNING:root:Parameters are 100% correlated: Omega_m, Omega_Lambda

# %%
print(samples['test'].getLikeStats())
# Out:
# Best fit sample -log(Like) = 1415.972500
# Ln(mean 1/like) = 1435.111655
# mean(-Ln(like)) = 1426.297692
# -Ln(mean like)  = 1422.309484
# 2*Var(Ln(like)) = 25.619781
#
# parameter                             bestfit        lower1         upper1         lower2         upper2
# logA                                  3.0539672E+00  3.0033882E+00  3.1013586E+00  3.0028803E+00  3.1047647E+00   \log(10^{10} A_\mathrm{s})
# n_s                                   9.7172601E-01  9.5852345E-01  9.8127132E-01  9.5802272E-01  9.8259859E-01   n_\mathrm{s}
# theta_s_100                           1.0420549E+00  1.0412083E+00  1.0429821E+00  1.0410411E+00  1.0430861E+00   100\theta_\mathrm{s}
# omega_b                               2.2569250E-02  2.2101644E-02  2.2959617E-02  2.2101644E-02  2.3006176E-02   \Omega_\mathrm{b} h^2
# omega_cdm                             1.1777250E-01  1.1564418E-01  1.2019443E-01  1.1536526E-01  1.2029609E-01   \Omega_\mathrm{c} h^2
# tau_reio                              6.2019426E-02  3.3386042E-02  8.6802575E-02  3.3386042E-02  8.7498733E-02   \tau_\mathrm{reio}
# A_planck                              9.9977278E-01  9.9356811E-01  1.0078133E+00  9.9192476E-01  1.0093188E+00   y_\mathrm{cal}
# calib_100T                            9.9997507E-01  9.9752986E-01  1.0013342E+00  9.9752986E-01  1.0019351E+00   c_{100}
# calib_217T                            9.9806470E-01  9.9564173E-01  1.0004287E+00  9.9564173E-01  1.0004612E+00   c_{217}
# A_cib_217                             3.9625776E+01  2.6717610E+01  6.7828567E+01  2.0386818E+01  6.8813473E+01   A^\mathrm{CIB}_{217}
# xi_sz_cib                             9.5425097E-01  6.8870669E-05  9.9992892E-01  6.8870669E-05  9.9992892E-01   \xi^{\mathrm{tSZ}\times\mathrm{CIB}}
# A_sz                                  7.2451939E+00  1.5892872E-01  9.9974686E+00  9.9764723E-03  9.9974686E+00   A^\mathrm{tSZ}_{143}
# ksz_norm                              1.0261961E+00  1.1015367E-03  9.9674225E+00  1.1015367E-03  9.9674225E+00   A^\mathrm{kSZ}
# gal545_A_100                          8.5847614E+00  3.3866292E+00  1.5387696E+01  1.4171500E+00  1.5602423E+01   A^\mathrm{dustTT}_{100}
# gal545_A_143                          9.5174697E+00  5.4591761E+00  1.6132104E+01  4.8440252E+00  1.6409959E+01   A^\mathrm{dustTT}_{143}
# gal545_A_143_217                      1.9191262E+01  8.4427894E+00  2.8160349E+01  5.6359215E+00  2.9684979E+01   A^\mathrm{dustTT}_{\mathrm{143}\times\mathrm{217}}
# gal545_A_217                          9.6832030E+01  6.5760703E+01  1.1494347E+02  6.5760703E+01  1.2392210E+02   A^\mathrm{dustTT}_{217}
# ps_A_100_100                          2.5280864E+02  1.6801762E+02  3.5296732E+02  1.6304776E+02  3.5675008E+02   A^\mathrm{PS}_{100}
# ps_A_143_143                          4.9061736E+01  1.8092033E+01  6.7157375E+01  1.3992549E+01  6.8632144E+01   A^\mathrm{PS}_{143}
# ps_A_143_217                          5.8717720E+01  1.6813354E+01  6.6842849E+01  1.1900559E+01  7.1699410E+01   A^\mathrm{PS}_{\mathrm{143}\times\mathrm{217}}
# ps_A_217_217                          1.2681118E+02  8.2527012E+01  1.4767176E+02  7.8498922E+01  1.4981657E+02   A^\mathrm{PS}_{217}
# galf_TE_A_100                         7.4440086E-02 -1.3177456E-02  2.2646479E-01 -3.9796250E-02  2.6451948E-01   A^\mathrm{dustTE}_{100}
# galf_TE_A_100_143                     1.2958839E-01  3.9139797E-02  2.4609719E-01  2.6883385E-02  2.4609719E-01   A^\mathrm{dustTE}_{\mathrm{100}\times\mathrm{143}}
# galf_TE_A_100_217                     4.6699167E-01  1.9848098E-01  7.6018566E-01  1.6229931E-01  7.6359886E-01   A^\mathrm{dustTE}_{\mathrm{100}\times\mathrm{217}}
# galf_TE_A_143                         2.4261639E-01  4.5366157E-02  3.9818768E-01  2.3203358E-02  4.2304315E-01   A^\mathrm{dustTE}_{143}
# galf_TE_A_143_217                     7.1533538E-01  4.1091303E-01  8.9949785E-01  3.5429049E-01  9.8089442E-01   A^\mathrm{dustTE}_{\mathrm{143}\times\mathrm{217}}
# galf_TE_A_217                         2.1147003E+00  1.2177044E+00  2.9077818E+00  1.0229008E+00  2.9306260E+00   A^\mathrm{dustTE}_{217}
# A_s*                                  2.1199280E-09  2.0153707E-09  2.2228129E-09  2.0143472E-09  2.2303971E-09   A_\mathrm{s}
# H0*                                   6.8401616E+01  6.7319203E+01  6.9337617E+01  6.7317142E+01  6.9426766E+01   H_0
# Omega_m*                              3.0133037E-01  2.8918481E-01  3.1573376E-01  2.8874616E-01  3.1573376E-01   \Omega_\mathrm{m}
# Omega_Lambda*                         6.9859224E-01  6.8418633E-01  7.1073977E-01  6.8418633E-01  7.1117856E-01   \Omega_\Lambda
# YHe*                                  2.4538724E-01  2.4518931E-01  2.4555232E-01  2.4518931E-01  2.4557003E-01   Y_\mathrm{P}
# z_reio*                               8.3628387E+00  5.3285065E+00  1.0586823E+01  5.3285065E+00  1.0734222E+01   z_\mathrm{re}
# rs_drag*                              1.4746861E+02  1.4694472E+02  1.4819345E+02  1.4687627E+02  1.4819345E+02   r_\mathrm{drag}
# chi2__BAO*                            1.2097091E+01  1.0285548E+01  2.9153262E+01  1.0284957E+01  3.0416587E+01   \chi^2_\mathrm{BAO}
# chi2__CMB*                            2.7783163E+03  2.7756649E+03  2.8027959E+03  2.7756649E+03  2.8106991E+03   \chi^2_\mathrm{CMB}
# minuslogprior*                        2.0765775E+01  1.9613722E+01  3.0974197E+01  1.9613722E+01  3.5952617E+01   -\log\pi
# minuslogprior__0*                     1.8207942E+01  1.7434240E+01  2.8103100E+01  1.7434240E+01  3.1607707E+01   -\log\pi_\mathrm{0}
# minuslogprior__SZ*                    2.5578331E+00  2.0175508E+00  8.3961976E+00  2.0175508E+00  9.7661897E+00   -\log\pi_\mathrm{SZ}
# chi2*                                 2.7904134E+03  2.7884462E+03  2.8141641E+03  2.7884462E+03  2.8217255E+03   \chi^2
# chi2__bao.desi_dr2*                   1.2097091E+01  1.0285548E+01  2.9153262E+01  1.0284957E+01  3.0416587E+01   \chi^2_\mathrm{bao.desi\ dr2}
# chi2__planck_2018_lowl.TT*            2.2403289E+01  2.0814049E+01  2.5397175E+01  2.0522020E+01  2.5795293E+01   \chi^2_\mathrm{planck\ 2018\ lowl.TT}
# chi2__planck_2018_lowl.EE*            3.9794729E+02  3.9563850E+02  4.1269344E+02  3.9563850E+02  4.1404572E+02   \chi^2_\mathrm{planck\ 2018\ lowl.EE}
# chi2__planck_2018_highl_plik.TTTEEE*  2.3491559E+03  2.3448205E+03  2.3748024E+03  2.3448205E+03  2.3812954E+03   \chi^2_\mathrm{planck\ 2018\ highl\ plik.TTTEEE}
# chi2__planck_2018_lensing.clik*       8.8098698E+00  8.1762343E+00  1.3737024E+01  8.1388112E+00  1.6467833E+01   \chi^2_\mathrm{planck\ 2018\ lensing.clik}
# Hdot*                                 6.8401616E+01  6.7319203E+01  6.9337617E+01  6.7317142E+01  6.9426766E+01   $H_0$
